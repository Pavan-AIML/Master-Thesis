# %% [markdown]
# Connected to .venvn (3.9.22) (Python 3.9.22)

# %%
Final_Data_Train_latlong_AOD_PM25 = Final_Air_Quality_Dataset_pipeline(
    config=config, geospatial_encoder, flag="Train", input_type=1, output_type=1
)
# Out:
#   Cell In[1], line 3
#     )
#     ^
# SyntaxError: positional argument follows keyword argument

# %%
Final_Data_Train_latlong_AOD_PM25 = Final_Air_Quality_Dataset_pipeline(
    config=config, geospatial_encoder, flag="Train", input_type=1, output_type=1
)
# Out:
#   Cell In[2], line 3
#     )
#     ^
# SyntaxError: positional argument follows keyword argument

# %%
Final_Data_Train_latlong_AOD_PM25 = Final_Air_Quality_Dataset_pipeline(
    config=config, geospatial_encoder, flag="Train", input_type=1, output_type=1
)
# Out:
#   Cell In[3], line 3
#     )
#     ^
# SyntaxError: positional argument follows keyword argument

# %%
Final_Data_Train_latlong_AOD_PM25 = Final_Air_Quality_Dataset_pipeline(
    config=config, geospatial_encoder, flag="Train", input_type=1, output_type=1)
# Out:
#   Cell In[4], line 2
#     config=config, geospatial_encoder, flag="Train", input_type=1, output_type=1)
#                                                                                 ^
# SyntaxError: positional argument follows keyword argument

# %% [markdown]
# Connected to .venvn (3.9.22) (Python 3.9.22)

# %%
"""
Importing the necessary packages.............
"""

import os
import torch
import numpy as np
import pandas as pd
import sys
from pathlib import Path
import os
import matplotlib.pyplot as plt
from glob import glob
from tqdm import tqdm
import arrow
from datetime import datetime

# from utils.config import config
from torch.utils.data import DataLoader

ROOT = Path(__file__).resolve().parents[2]  # tests/ -> project root
sys.path.insert(0, str(ROOT))
print(ROOT)

from configs.utils import config

# -------------************---------------------------------
# loading all the data loaders here we will load the final data in torch.
from Dataloader.Modis_Data_loader.PM25_data_loader_analysis import Modis_data_loader
from Dataloader.Modis_Data_loader.PM25_data_loader_analysis import PM_25_dataloader
from Dataloader.Modis_Data_loader.PM25_data_loader_analysis import (
    combine_the_data_frames,
)
from Dataloader.Modis_Data_loader.PM25_data_loader_analysis import (
    Training_data_loader,
)
from locationencoder.final_location_encoder import Geospatial_Encoder
geospatial_encoder = Geospatial_Encoder(
            config["Geo_spatial_Encoder"]["dim_in"],
            config["Geo_spatial_Encoder"]["dim_hidden"],
            config["Geo_spatial_Encoder"]["dim_out"],
            config["Geo_spatial_Encoder"]["num_layers"],
        )
from Dataloader.Modis_Data_loader.torch_data_loader import Airqualitydataset
from Dataloader.Modis_Data_loader.final_loader import Final_Air_Quality_Dataset_pipeline


"""   For type 1 target_columns = ['AOD', 'PM2.5'] & Training dataset      """


# for type 1 target_columns = ['AOD', 'PM2.5'] & Training dataset

#                       Training data

Final_Data_Train_latlong_AOD_PM25 = Final_Air_Quality_Dataset_pipeline(
    config=config, geospatial_encoder, flag="Train", input_type=1, output_type=1)
# Out:
#   Cell In[1], line 56
#     config=config, geospatial_encoder, flag="Train", input_type=1, output_type=1)
#                                                                                 ^
# SyntaxError: positional argument follows keyword argument

# %%
"""
Importing the necessary packages.............
"""

import os
import torch
import numpy as np
import pandas as pd
import sys
from pathlib import Path
import os
import matplotlib.pyplot as plt
from glob import glob
from tqdm import tqdm
import arrow
from datetime import datetime

# from utils.config import config
from torch.utils.data import DataLoader

ROOT = Path(__file__).resolve().parents[2]  # tests/ -> project root
sys.path.insert(0, str(ROOT))
print(ROOT)

from configs.utils import config

# -------------************---------------------------------
# loading all the data loaders here we will load the final data in torch.
from Dataloader.Modis_Data_loader.PM25_data_loader_analysis import Modis_data_loader
from Dataloader.Modis_Data_loader.PM25_data_loader_analysis import PM_25_dataloader
from Dataloader.Modis_Data_loader.PM25_data_loader_analysis import (
    combine_the_data_frames,
)
from Dataloader.Modis_Data_loader.PM25_data_loader_analysis import (
    Training_data_loader,
)
from locationencoder.final_location_encoder import Geospatial_Encoder
geospatial_encoder = Geospatial_Encoder(
            config["Geo_spatial_Encoder"]["dim_in"],
            config["Geo_spatial_Encoder"]["dim_hidden"],
            config["Geo_spatial_Encoder"]["dim_out"],
            config["Geo_spatial_Encoder"]["num_layers"],
        )
from Dataloader.Modis_Data_loader.torch_data_loader import Airqualitydataset
from Dataloader.Modis_Data_loader.final_loader import Final_Air_Quality_Dataset_pipeline


"""   For type 1 target_columns = ['AOD', 'PM2.5'] & Training dataset      """


# for type 1 target_columns = ['AOD', 'PM2.5'] & Training dataset

#                       Training data

Final_Data_Train_latlong_AOD_PM25 = Final_Air_Quality_Dataset_pipeline(
    config=config, geospatial_encoder, flag="Train", input_type=1, output_type=1)
# Out:
#   Cell In[2], line 56
#     config=config, geospatial_encoder, flag="Train", input_type=1, output_type=1)
#                                                                                 ^
# SyntaxError: positional argument follows keyword argument

# %%
"""
Importing the necessary packages.............
"""

import os
import torch
import numpy as np
import pandas as pd
import sys
from pathlib import Path
import os
import matplotlib.pyplot as plt
from glob import glob
from tqdm import tqdm
import arrow
from datetime import datetime

# from utils.config import config
from torch.utils.data import DataLoader

ROOT = Path(__file__).resolve().parents[2]  # tests/ -> project root
sys.path.insert(0, str(ROOT))
print(ROOT)

from configs.utils import config

# -------------************---------------------------------
# loading all the data loaders here we will load the final data in torch.
from Dataloader.Modis_Data_loader.PM25_data_loader_analysis import Modis_data_loader
from Dataloader.Modis_Data_loader.PM25_data_loader_analysis import PM_25_dataloader
from Dataloader.Modis_Data_loader.PM25_data_loader_analysis import (
    combine_the_data_frames,
)
from Dataloader.Modis_Data_loader.PM25_data_loader_analysis import (
    Training_data_loader,
)
from locationencoder.final_location_encoder import Geospatial_Encoder
geospatial_encoder = Geospatial_Encoder(
            config["Geo_spatial_Encoder"]["dim_in"],
            config["Geo_spatial_Encoder"]["dim_hidden"],
            config["Geo_spatial_Encoder"]["dim_out"],
            config["Geo_spatial_Encoder"]["num_layers"],
        )
from Dataloader.Modis_Data_loader.torch_data_loader import Airqualitydataset
from Dataloader.Modis_Data_loader.final_loader import Final_Air_Quality_Dataset_pipeline


"""   For type 1 target_columns = ['AOD', 'PM2.5'] & Training dataset      """


# for type 1 target_columns = ['AOD', 'PM2.5'] & Training dataset

#                       Training data

Final_Data_Train_latlong_AOD_PM25 = Final_Air_Quality_Dataset_pipeline(
    config=config, geospatial_encoder, flag="Train", input_type=1, output_type=1)
# Out:
#   Cell In[3], line 56
#     config=config, geospatial_encoder, flag="Train", input_type=1, output_type=1)
#                                                                                 ^
# SyntaxError: positional argument follows keyword argument

# %%
Final_Data_Train_latlong_AOD_PM25 = Final_Air_Quality_Dataset_pipeline(
    config=config, geospatial_encoder =geospatial_encoder ,flag="Train", input_type=1, output_type=1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# File /Users/pavankumar/Documents/Winter_Thesis/Coding_Learning/Master-Thesis/src/training/trainer_latlon_AOD_PM25.py:1
# ----> 1 Final_Data_Train_latlong_AOD_PM25 = Final_Air_Quality_Dataset_pipeline(
#       2     config=config, geospatial_encoder =geospatial_encoder ,flag="Train", input_type=1, output_type=1)
#
# NameError: name 'Final_Air_Quality_Dataset_pipeline' is not defined

# %%
"""
Importing the necessary packages.............
"""

import os
import torch
import numpy as np
import pandas as pd
import sys
from pathlib import Path
import os
import matplotlib.pyplot as plt
from glob import glob
from tqdm import tqdm
import arrow
from datetime import datetime

# from utils.config import config
from torch.utils.data import DataLoader

ROOT = Path(__file__).resolve().parents[2]  # tests/ -> project root
sys.path.insert(0, str(ROOT))
print(ROOT)

from configs.utils import config

# -------------************---------------------------------
# loading all the data loaders here we will load the final data in torch.
from Dataloader.Modis_Data_loader.PM25_data_loader_analysis import Modis_data_loader
from Dataloader.Modis_Data_loader.PM25_data_loader_analysis import PM_25_dataloader
from Dataloader.Modis_Data_loader.PM25_data_loader_analysis import (
    combine_the_data_frames,
)
from Dataloader.Modis_Data_loader.PM25_data_loader_analysis import (
    Training_data_loader,
)
from locationencoder.final_location_encoder import Geospatial_Encoder
geospatial_encoder = Geospatial_Encoder(
            config["Geo_spatial_Encoder"]["dim_in"],
            config["Geo_spatial_Encoder"]["dim_hidden"],
            config["Geo_spatial_Encoder"]["dim_out"],
            config["Geo_spatial_Encoder"]["num_layers"],
        )
from Dataloader.Modis_Data_loader.torch_data_loader import Airqualitydataset
from Dataloader.Modis_Data_loader.final_loader import Final_Air_Quality_Dataset_pipeline


"""   For type 1 target_columns = ['AOD', 'PM2.5'] & Training dataset      """


# for type 1 target_columns = ['AOD', 'PM2.5'] & Training dataset

#                       Training data

Final_Data_Train_latlong_AOD_PM25 = Final_Air_Quality_Dataset_pipeline(
    config=config, geospatial_encoder =geospatial_encoder ,flag="Train", input_type=1, output_type=1)
# Out:
# /Users/pavankumar/Documents/Winter_Thesis/Coding_Learning/Master-Thesis
# /Users/pavankumar/Documents/Winter_Thesis/Coding_Learning
# {'dataset_num_1': 1, 'dataset_num_2': 2, 'dataset_num_3': 3, 'exp_name': 'aod_pm25_prediction', 'input_type_1': 1, 'input_type_2': 2, 'input_type_3': 3, 'input_type_4': 4, 'target_type': ['AOD', 'PM2.5'], 'input_vars': {1: ['latitude', 'longitude', 'AOD', 'PM2.5'], 2: ['latitude', 'longitude', 'AOD'], 3: ['latitude', 'longitude', 'PM2.5'], 4: ['latitude', 'longitude']}, 'output_vars': {1: ['AOD', 'PM2.5'], 2: ['AOD'], 3: ['PM2.5']}}
# /Users/pavankumar/Documents/Winter_Thesis/Coding_Learning/Master-Thesis
# /Users/pavankumar/Documents/Winter_Thesis/Coding_Learning/Master-Thesis

# %%
"""
Importing the necessary packages.............
"""

import os
import torch
import numpy as np
import pandas as pd
import sys
from pathlib import Path
import os
import matplotlib.pyplot as plt
from glob import glob
from tqdm import tqdm
import arrow
from datetime import datetime

# from utils.config import config
from torch.utils.data import DataLoader

ROOT = Path(__file__).resolve().parents[2]  # tests/ -> project root
sys.path.insert(0, str(ROOT))
print(ROOT)

from configs.utils import config

# -------------************---------------------------------
# loading all the data loaders here we will load the final data in torch.
from Dataloader.Modis_Data_loader.PM25_data_loader_analysis import Modis_data_loader
from Dataloader.Modis_Data_loader.PM25_data_loader_analysis import PM_25_dataloader
from Dataloader.Modis_Data_loader.PM25_data_loader_analysis import (
    combine_the_data_frames,
)
from Dataloader.Modis_Data_loader.PM25_data_loader_analysis import (
    Training_data_loader,
)
from locationencoder.final_location_encoder import Geospatial_Encoder
geospatial_encoder = Geospatial_Encoder(
            config["Geo_spatial_Encoder"]["dim_in"],
            config["Geo_spatial_Encoder"]["dim_hidden"],
            config["Geo_spatial_Encoder"]["dim_out"],
            config["Geo_spatial_Encoder"]["num_layers"],
        )
from Dataloader.Modis_Data_loader.torch_data_loader import Airqualitydataset
from Dataloader.Modis_Data_loader.final_loader import Final_Air_Quality_Dataset_pipeline


""" In the belowmethod it is hard to make these many types of combinations so we will make a loop of input, output types and flags to create the final datasets."""


"""
  input_vars:
    1: ['latitude', 'longitude','AOD', 'PM2.5']
    2: ['latitude', 'longitude','AOD']
    3: ['latitude', 'longitude','PM2.5']
    4: ['latitude', 'longitude']

# feature_sets

  output_vars:
    1: ['AOD', 'PM2.5']
    2: ['AOD']
    3: ['PM2.5']

"""

input_type = [1,2,3,4]
output_type = [1,2,3]
flag = ["Train", "Val", "Test"]

# Now we will loop over all the combinations to create the final datasets.

for i in input_type:
    if i == "":
        print("Invalid input type")
    for j in output_type:
        if j == "":
            print("Invalid output type")
        for k in flag:
            if k == "":
                print("Invalid flag")
            else:
                print(f"Creating dataset for input type{config["experiments"]["input_vars"][{i}]}, {i}, output type {config["experiments"]["output_vars"][{j}]} {j} and flag {k}")
                Final_Data = Final_Air_Quality_Dataset_pipeline(
                    config=config, flag=k, input_type=i, output_type=j
                )
                Final_Data = Final_Data.full_pipeline()
                print(Final_Data[0].shape)
# Out:
#   Cell In[6], line 83
#     print(f"Creating dataset for input type{config["experiments"]["input_vars"][{i}]}, {i}, output type {config["experiments"]["output_vars"][{j}]} {j} and flag {k}")
#                                                     ^
# SyntaxError: f-string: unmatched '['

# %%
for i in input_type:
    if i == "":
        print("Invalid input type")
    for j in output_type:
        if j == "":
            print("Invalid output type")
        for k in flag:
            if k == "":
                print("Invalid flag")
            else:
                print(f"Creating dataset for input type{config["experiments"]["input_vars"][{i}]}, {i}, output type {config["experiments"]["output_vars"][{j}]} {j} and flag {k}")
                Final_Data = Final_Air_Quality_Dataset_pipeline(
                    config=config, flag=k, input_type=i, output_type=j
                )
                Final_Data = Final_Data.full_pipeline()
                print(Final_Data[0].shape)
# Out:
#   Cell In[7], line 11
#     print(f"Creating dataset for input type{config["experiments"]["input_vars"][{i}]}, {i}, output type {config["experiments"]["output_vars"][{j}]} {j} and flag {k}")
#                                                     ^
# SyntaxError: f-string: unmatched '['

# %%
"""
Importing the necessary packages.............
"""

import os
import torch
import numpy as np
import pandas as pd
import sys
from pathlib import Path
import os
import matplotlib.pyplot as plt
from glob import glob
from tqdm import tqdm
import arrow
from datetime import datetime

# from utils.config import config
from torch.utils.data import DataLoader

ROOT = Path(__file__).resolve().parents[2]  # tests/ -> project root
sys.path.insert(0, str(ROOT))
print(ROOT)

from configs.utils import config

# -------------************---------------------------------
# loading all the data loaders here we will load the final data in torch.
from Dataloader.Modis_Data_loader.PM25_data_loader_analysis import Modis_data_loader
from Dataloader.Modis_Data_loader.PM25_data_loader_analysis import PM_25_dataloader
from Dataloader.Modis_Data_loader.PM25_data_loader_analysis import (
    combine_the_data_frames,
)
from Dataloader.Modis_Data_loader.PM25_data_loader_analysis import (
    Training_data_loader,
)
from locationencoder.final_location_encoder import Geospatial_Encoder
geospatial_encoder = Geospatial_Encoder(
            config["Geo_spatial_Encoder"]["dim_in"],
            config["Geo_spatial_Encoder"]["dim_hidden"],
            config["Geo_spatial_Encoder"]["dim_out"],
            config["Geo_spatial_Encoder"]["num_layers"],
        )
from Dataloader.Modis_Data_loader.torch_data_loader import Airqualitydataset
from Dataloader.Modis_Data_loader.final_loader import Final_Air_Quality_Dataset_pipeline


""" In the belowmethod it is hard to make these many types of combinations so we will make a loop of input, output types and flags to create the final datasets."""


"""
  input_vars:
    1: ['latitude', 'longitude','AOD', 'PM2.5']
    2: ['latitude', 'longitude','AOD']
    3: ['latitude', 'longitude','PM2.5']
    4: ['latitude', 'longitude']

# feature_sets

  output_vars:
    1: ['AOD', 'PM2.5']
    2: ['AOD']
    3: ['PM2.5']

"""

input_type = [1,2,3,4]
output_type = [1,2,3]
flag = ["Train", "Val", "Test"]

# Now we will loop over all the combinations to create the final datasets.

for i in input_type:
    if i == "":
        print("Invalid input type")
    for j in output_type:
        if j == "":
            print("Invalid output type")
        for k in flag:
            if k == "":
                print("Invalid flag")
            else:
                print(f"Creating dataset for input type{config["experiments"]["input_vars"][{i}]}, {i}, output type {config["experiments"]["output_vars"][{j}]} {j} and flag {k}")
                Final_Data = Final_Air_Quality_Dataset_pipeline(
                    config=config, flag=k, input_type=i, output_type=j
                )
                Final_Data = Final_Data.full_pipeline()
                print(Final_Data[0].shape)
# Out:
#   Cell In[8], line 83
#     print(f"Creating dataset for input type{config["experiments"]["input_vars"][{i}]}, {i}, output type {config["experiments"]["output_vars"][{j}]} {j} and flag {k}")
#                                                     ^
# SyntaxError: f-string: unmatched '['

# %%
"""
Importing the necessary packages.............
"""

import os
import torch
import numpy as np
import pandas as pd
import sys
from pathlib import Path
import os
import matplotlib.pyplot as plt
from glob import glob
from tqdm import tqdm
import arrow
from datetime import datetime

# from utils.config import config
from torch.utils.data import DataLoader

ROOT = Path(__file__).resolve().parents[2]  # tests/ -> project root
sys.path.insert(0, str(ROOT))
print(ROOT)

from configs.utils import config

# -------------************---------------------------------
# loading all the data loaders here we will load the final data in torch.
from Dataloader.Modis_Data_loader.PM25_data_loader_analysis import Modis_data_loader
from Dataloader.Modis_Data_loader.PM25_data_loader_analysis import PM_25_dataloader
from Dataloader.Modis_Data_loader.PM25_data_loader_analysis import (
    combine_the_data_frames,
)
from Dataloader.Modis_Data_loader.PM25_data_loader_analysis import (
    Training_data_loader,
)
from locationencoder.final_location_encoder import Geospatial_Encoder
geospatial_encoder = Geospatial_Encoder(
            config["Geo_spatial_Encoder"]["dim_in"],
            config["Geo_spatial_Encoder"]["dim_hidden"],
            config["Geo_spatial_Encoder"]["dim_out"],
            config["Geo_spatial_Encoder"]["num_layers"],
        )
from Dataloader.Modis_Data_loader.torch_data_loader import Airqualitydataset
from Dataloader.Modis_Data_loader.final_loader import Final_Air_Quality_Dataset_pipeline


""" In the belowmethod it is hard to make these many types of combinations so we will make a loop of input, output types and flags to create the final datasets."""


"""
  input_vars:
    1: ['latitude', 'longitude','AOD', 'PM2.5']
    2: ['latitude', 'longitude','AOD']
    3: ['latitude', 'longitude','PM2.5']
    4: ['latitude', 'longitude']

# feature_sets

  output_vars:
    1: ['AOD', 'PM2.5']
    2: ['AOD']
    3: ['PM2.5']

"""

input_type = [1,2,3,4]
output_type = [1,2,3]
flag = ["Train", "Val", "Test"]

# Now we will loop over all the combinations to create the final datasets.

for i in input_type:
    if i == "":
        print("Invalid input type")
    for j in output_type:
        if j == "":
            print("Invalid output type")
        for k in flag:
            if k == "":
                print("Invalid flag")
            else:
                print(f"Creating dataset for input type{config["experiments"]["input_vars"][{i}]}, {i}, output type {config["experiments"]["output_vars"][{j}]}, {j} and flag {k}")
                Final_Data = Final_Air_Quality_Dataset_pipeline(
                    config=config, flag=k, input_type=i, output_type=j
                )
                Final_Data = Final_Data.full_pipeline()
                print(Final_Data[0].shape)
# Out:
#   Cell In[9], line 83
#     print(f"Creating dataset for input type{config["experiments"]["input_vars"][{i}]}, {i}, output type {config["experiments"]["output_vars"][{j}]}, {j} and flag {k}")
#                                                     ^
# SyntaxError: f-string: unmatched '['

# %%
"""
Importing the necessary packages.............
"""

import os
import torch
import numpy as np
import pandas as pd
import sys
from pathlib import Path
import os
import matplotlib.pyplot as plt
from glob import glob
from tqdm import tqdm
import arrow
from datetime import datetime

# from utils.config import config
from torch.utils.data import DataLoader

ROOT = Path(__file__).resolve().parents[2]  # tests/ -> project root
sys.path.insert(0, str(ROOT))
print(ROOT)

from configs.utils import config

# -------------************---------------------------------
# loading all the data loaders here we will load the final data in torch.
from Dataloader.Modis_Data_loader.PM25_data_loader_analysis import Modis_data_loader
from Dataloader.Modis_Data_loader.PM25_data_loader_analysis import PM_25_dataloader
from Dataloader.Modis_Data_loader.PM25_data_loader_analysis import (
    combine_the_data_frames,
)
from Dataloader.Modis_Data_loader.PM25_data_loader_analysis import (
    Training_data_loader,
)
from locationencoder.final_location_encoder import Geospatial_Encoder
geospatial_encoder = Geospatial_Encoder(
            config["Geo_spatial_Encoder"]["dim_in"],
            config["Geo_spatial_Encoder"]["dim_hidden"],
            config["Geo_spatial_Encoder"]["dim_out"],
            config["Geo_spatial_Encoder"]["num_layers"],
        )
from Dataloader.Modis_Data_loader.torch_data_loader import Airqualitydataset
from Dataloader.Modis_Data_loader.final_loader import Final_Air_Quality_Dataset_pipeline


""" In the belowmethod it is hard to make these many types of combinations so we will make a loop of input, output types and flags to create the final datasets."""


"""
  input_vars:
    1: ['latitude', 'longitude','AOD', 'PM2.5']
    2: ['latitude', 'longitude','AOD']
    3: ['latitude', 'longitude','PM2.5']
    4: ['latitude', 'longitude']

# feature_sets

  output_vars:
    1: ['AOD', 'PM2.5']
    2: ['AOD']
    3: ['PM2.5']

"""

input_type = [1,2,3,4]
output_type = [1,2,3]
flag = ["Train", "Val", "Test"]

# Now we will loop over all the combinations to create the final datasets.

for i in input_type:
    if i == "":
        print("Invalid input type")
    for j in output_type:
        if j == "":
            print("Invalid output type")
        for k in flag:
            if k == "":
                print("Invalid flag")
            else:
                print(f"Creating dataset for input type{config["experiments"]["input_vars"][{i}]}, {i}, output type {config["experiments"]["output_vars"][{j}]}, {j} and flag {k}")
                Final_Data = Final_Air_Quality_Dataset_pipeline(
                    config=config, geospatial_encoder =geospatial_encoder ,flag= k, input_type=i, output_type=j
                )
                Final_Data = Final_Data.full_pipeline()
                print(Final_Data[0].shape)
# Out:
#   Cell In[10], line 83
#     print(f"Creating dataset for input type{config["experiments"]["input_vars"][{i}]}, {i}, output type {config["experiments"]["output_vars"][{j}]}, {j} and flag {k}")
#                                                     ^
# SyntaxError: f-string: unmatched '['

# %%
"""
Importing the necessary packages.............
"""

import os
import torch
import numpy as np
import pandas as pd
import sys
from pathlib import Path
import os
import matplotlib.pyplot as plt
from glob import glob
from tqdm import tqdm
import arrow
from datetime import datetime

# from utils.config import config
from torch.utils.data import DataLoader

ROOT = Path(__file__).resolve().parents[2]  # tests/ -> project root
sys.path.insert(0, str(ROOT))
print(ROOT)

from configs.utils import config

# -------------************---------------------------------
# loading all the data loaders here we will load the final data in torch.
from Dataloader.Modis_Data_loader.PM25_data_loader_analysis import Modis_data_loader
from Dataloader.Modis_Data_loader.PM25_data_loader_analysis import PM_25_dataloader
from Dataloader.Modis_Data_loader.PM25_data_loader_analysis import (
    combine_the_data_frames,
)
from Dataloader.Modis_Data_loader.PM25_data_loader_analysis import (
    Training_data_loader,
)
from locationencoder.final_location_encoder import Geospatial_Encoder
geospatial_encoder = Geospatial_Encoder(
            config["Geo_spatial_Encoder"]["dim_in"],
            config["Geo_spatial_Encoder"]["dim_hidden"],
            config["Geo_spatial_Encoder"]["dim_out"],
            config["Geo_spatial_Encoder"]["num_layers"],
        )
from Dataloader.Modis_Data_loader.torch_data_loader import Airqualitydataset
from Dataloader.Modis_Data_loader.final_loader import Final_Air_Quality_Dataset_pipeline


""" In the belowmethod it is hard to make these many types of combinations so we will make a loop of input, output types and flags to create the final datasets."""


"""
  input_vars:
    1: ['latitude', 'longitude','AOD', 'PM2.5']
    2: ['latitude', 'longitude','AOD']
    3: ['latitude', 'longitude','PM2.5']
    4: ['latitude', 'longitude']

# feature_sets

  output_vars:
    1: ['AOD', 'PM2.5']
    2: ['AOD']
    3: ['PM2.5']

"""

input_type = [1,2,3,4]
output_type = [1,2,3]
flag = ["Train", "Val", "Test"]

# Now we will loop over all the combinations to create the final datasets.
datasets ={}
for i in input_type:
    if i == "":
        print("Invalid input type")
    for j in output_type:
        if j == "":
            print("Invalid output type")
        for k in flag:
            if k == "":
                print("Invalid flag")
            else:
                
                # From here we will do the proper string formatting. 
                
                input_name = config["experiments"]["input_vars"][i]
                output_name = config["experiments"]["output_vars"][j]
                print("Creating the dataset for Input:{input_name} ({i}) | Output: {output_name} ({j}) | Flag: {k}")
                Final_Data = Final_Air_Quality_Dataset_pipeline(
                    config=config, geospatial_encoder =geospatial_encoder ,flag= k, input_type=i, output_type=j
                )
                current_inputs, current_outputs = Final_Data.full_pipeline()
                
                datasets[(i,j,k)] = {
                    "inputs" : current_inputs,
                    "outputs" : current_outputs
                }
# Out:
# /Users/pavankumar/Documents/Winter_Thesis/Coding_Learning/Master-Thesis
# Creating the dataset for Input:{input_name} ({i}) | Output: {output_name} ({j}) | Flag: {k}
# Extracting daily Pm2.5 data..
#  daily_PM_data shape: (40, 1095)
# Fusing AOD data from multiple years...
#  AOD_final shape: (1350, 1098)
# Finding nearest neighbours for PM2.5 stations...
# nearest_neighbours shape: (40, 1098)
# Cleaning data and handling missing values...
# Cleaned nearest_neighbours shape: (40, 1097)
# Preparing final training data...
# final_training_data shape: (15667, 5)
# Creating the dataset for Input:{input_name} ({i}) | Output: {output_name} ({j}) | Flag: {k}
# Extracting daily Pm2.5 data..
#  daily_PM_data shape: (40, 1095)
# Fusing AOD data from multiple years...
#  AOD_final shape: (1350, 1098)
# Finding nearest neighbours for PM2.5 stations...
# nearest_neighbours shape: (40, 1098)
# Cleaning data and handling missing values...
# Cleaned nearest_neighbours shape: (40, 1097)
# Preparing final training data...
# final_training_data shape: (15667, 5)
# Creating the dataset for Input:{input_name} ({i}) | Output: {output_name} ({j}) | Flag: {k}
# Extracting daily Pm2.5 data..
#  daily_PM_data shape: (40, 1095)
# Fusing AOD data from multiple years...
#  AOD_final shape: (1350, 1098)
# Finding nearest neighbours for PM2.5 stations...
# nearest_neighbours shape: (40, 1098)
# Cleaning data and handling missing values...
# Cleaned nearest_neighbours shape: (40, 1097)
# Preparing final training data...
# final_training_data shape: (15667, 5)
# Creating the dataset for Input:{input_name} ({i}) | Output: {output_name} ({j}) | Flag: {k}
# Extracting daily Pm2.5 data..
#  daily_PM_data shape: (40, 1095)
# Fusing AOD data from multiple years...
#  AOD_final shape: (1350, 1098)
# Finding nearest neighbours for PM2.5 stations...
# nearest_neighbours shape: (40, 1098)
# Cleaning data and handling missing values...
# Cleaned nearest_neighbours shape: (40, 1097)
# Preparing final training data...
# final_training_data shape: (15667, 5)
# Creating the dataset for Input:{input_name} ({i}) | Output: {output_name} ({j}) | Flag: {k}
# Extracting daily Pm2.5 data..
#  daily_PM_data shape: (40, 1095)
# Fusing AOD data from multiple years...
#  AOD_final shape: (1350, 1098)
# Finding nearest neighbours for PM2.5 stations...
# nearest_neighbours shape: (40, 1098)
# Cleaning data and handling missing values...
# Cleaned nearest_neighbours shape: (40, 1097)
# Preparing final training data...
# final_training_data shape: (15667, 5)
# Creating the dataset for Input:{input_name} ({i}) | Output: {output_name} ({j}) | Flag: {k}
# Extracting daily Pm2.5 data..
#  daily_PM_data shape: (40, 1095)
# Fusing AOD data from multiple years...
#  AOD_final shape: (1350, 1098)
# Finding nearest neighbours for PM2.5 stations...
# nearest_neighbours shape: (40, 1098)
# Cleaning data and handling missing values...
# Cleaned nearest_neighbours shape: (40, 1097)
# Preparing final training data...
# final_training_data shape: (15667, 5)
# Creating the dataset for Input:{input_name} ({i}) | Output: {output_name} ({j}) | Flag: {k}
# Extracting daily Pm2.5 data..
#  daily_PM_data shape: (40, 1095)
# Fusing AOD data from multiple years...
#  AOD_final shape: (1350, 1098)
# Finding nearest neighbours for PM2.5 stations...
# nearest_neighbours shape: (40, 1098)
# Cleaning data and handling missing values...
# Cleaned nearest_neighbours shape: (40, 1097)
# Preparing final training data...
# final_training_data shape: (15667, 5)
# Creating the dataset for Input:{input_name} ({i}) | Output: {output_name} ({j}) | Flag: {k}
# Extracting daily Pm2.5 data..
#  daily_PM_data shape: (40, 1095)
# Fusing AOD data from multiple years...
#  AOD_final shape: (1350, 1098)
# Finding nearest neighbours for PM2.5 stations...
# nearest_neighbours shape: (40, 1098)
# Cleaning data and handling missing values...
# Cleaned nearest_neighbours shape: (40, 1097)
# Preparing final training data...
# final_training_data shape: (15667, 5)
# Creating the dataset for Input:{input_name} ({i}) | Output: {output_name} ({j}) | Flag: {k}
# Extracting daily Pm2.5 data..
#  daily_PM_data shape: (40, 1095)
# Fusing AOD data from multiple years...
#  AOD_final shape: (1350, 1098)
# Finding nearest neighbours for PM2.5 stations...
# nearest_neighbours shape: (40, 1098)
# Cleaning data and handling missing values...
# Cleaned nearest_neighbours shape: (40, 1097)
# Preparing final training data...
# final_training_data shape: (15667, 5)
# Creating the dataset for Input:{input_name} ({i}) | Output: {output_name} ({j}) | Flag: {k}
# Extracting daily Pm2.5 data..
#  daily_PM_data shape: (40, 1095)
# Fusing AOD data from multiple years...
#  AOD_final shape: (1350, 1098)
# Finding nearest neighbours for PM2.5 stations...
# nearest_neighbours shape: (40, 1098)
# Cleaning data and handling missing values...
# Cleaned nearest_neighbours shape: (40, 1097)
# Preparing final training data...
# final_training_data shape: (15667, 5)
# Creating the dataset for Input:{input_name} ({i}) | Output: {output_name} ({j}) | Flag: {k}
# Extracting daily Pm2.5 data..
#  daily_PM_data shape: (40, 1095)
# Fusing AOD data from multiple years...
#  AOD_final shape: (1350, 1098)
# Finding nearest neighbours for PM2.5 stations...
# nearest_neighbours shape: (40, 1098)
# Cleaning data and handling missing values...
# Cleaned nearest_neighbours shape: (40, 1097)
# Preparing final training data...
# final_training_data shape: (15667, 5)
# Creating the dataset for Input:{input_name} ({i}) | Output: {output_name} ({j}) | Flag: {k}
# Extracting daily Pm2.5 data..
#  daily_PM_data shape: (40, 1095)
# Fusing AOD data from multiple years...
#  AOD_final shape: (1350, 1098)
# Finding nearest neighbours for PM2.5 stations...
# nearest_neighbours shape: (40, 1098)
# Cleaning data and handling missing values...
# Cleaned nearest_neighbours shape: (40, 1097)
# Preparing final training data...
# final_training_data shape: (15667, 5)
# Creating the dataset for Input:{input_name} ({i}) | Output: {output_name} ({j}) | Flag: {k}
# Extracting daily Pm2.5 data..
#  daily_PM_data shape: (40, 1095)
# Fusing AOD data from multiple years...
#  AOD_final shape: (1350, 1098)
# Finding nearest neighbours for PM2.5 stations...
# nearest_neighbours shape: (40, 1098)
# Cleaning data and handling missing values...
# Cleaned nearest_neighbours shape: (40, 1097)
# Preparing final training data...
# final_training_data shape: (15667, 5)
# Creating the dataset for Input:{input_name} ({i}) | Output: {output_name} ({j}) | Flag: {k}
# Extracting daily Pm2.5 data..
#  daily_PM_data shape: (40, 1095)
# Fusing AOD data from multiple years...
#  AOD_final shape: (1350, 1098)
# Finding nearest neighbours for PM2.5 stations...
# nearest_neighbours shape: (40, 1098)
# Cleaning data and handling missing values...
# Cleaned nearest_neighbours shape: (40, 1097)
# Preparing final training data...
# final_training_data shape: (15667, 5)
# Creating the dataset for Input:{input_name} ({i}) | Output: {output_name} ({j}) | Flag: {k}
# Extracting daily Pm2.5 data..
#  daily_PM_data shape: (40, 1095)
# Fusing AOD data from multiple years...
#  AOD_final shape: (1350, 1098)
# Finding nearest neighbours for PM2.5 stations...
# nearest_neighbours shape: (40, 1098)
# Cleaning data and handling missing values...
# Cleaned nearest_neighbours shape: (40, 1097)
# Preparing final training data...
# final_training_data shape: (15667, 5)
# Creating the dataset for Input:{input_name} ({i}) | Output: {output_name} ({j}) | Flag: {k}
# Extracting daily Pm2.5 data..
#  daily_PM_data shape: (40, 1095)
# Fusing AOD data from multiple years...
#  AOD_final shape: (1350, 1098)
# Finding nearest neighbours for PM2.5 stations...
# nearest_neighbours shape: (40, 1098)
# Cleaning data and handling missing values...
# Cleaned nearest_neighbours shape: (40, 1097)
# Preparing final training data...
# final_training_data shape: (15667, 5)
# Creating the dataset for Input:{input_name} ({i}) | Output: {output_name} ({j}) | Flag: {k}
# Extracting daily Pm2.5 data..
#  daily_PM_data shape: (40, 1095)
# Fusing AOD data from multiple years...
#  AOD_final shape: (1350, 1098)
# Finding nearest neighbours for PM2.5 stations...
# nearest_neighbours shape: (40, 1098)
# Cleaning data and handling missing values...
# Cleaned nearest_neighbours shape: (40, 1097)
# Preparing final training data...
# final_training_data shape: (15667, 5)
# Creating the dataset for Input:{input_name} ({i}) | Output: {output_name} ({j}) | Flag: {k}
# Extracting daily Pm2.5 data..
#  daily_PM_data shape: (40, 1095)
# Fusing AOD data from multiple years...
#  AOD_final shape: (1350, 1098)
# Finding nearest neighbours for PM2.5 stations...
# nearest_neighbours shape: (40, 1098)
# Cleaning data and handling missing values...
# Cleaned nearest_neighbours shape: (40, 1097)
# Preparing final training data...
# final_training_data shape: (15667, 5)
# Creating the dataset for Input:{input_name} ({i}) | Output: {output_name} ({j}) | Flag: {k}
# Extracting daily Pm2.5 data..
#  daily_PM_data shape: (40, 1095)
# Fusing AOD data from multiple years...
#  AOD_final shape: (1350, 1098)
# Finding nearest neighbours for PM2.5 stations...
# nearest_neighbours shape: (40, 1098)
# Cleaning data and handling missing values...
# Cleaned nearest_neighbours shape: (40, 1097)
# Preparing final training data...
# final_training_data shape: (15667, 5)
# Creating the dataset for Input:{input_name} ({i}) | Output: {output_name} ({j}) | Flag: {k}
# Extracting daily Pm2.5 data..
#  daily_PM_data shape: (40, 1095)
# Fusing AOD data from multiple years...
#  AOD_final shape: (1350, 1098)
# Finding nearest neighbours for PM2.5 stations...
# nearest_neighbours shape: (40, 1098)
# Cleaning data and handling missing values...
# Cleaned nearest_neighbours shape: (40, 1097)
# Preparing final training data...
# final_training_data shape: (15667, 5)
# Creating the dataset for Input:{input_name} ({i}) | Output: {output_name} ({j}) | Flag: {k}
# Extracting daily Pm2.5 data..
#  daily_PM_data shape: (40, 1095)
# Fusing AOD data from multiple years...
#  AOD_final shape: (1350, 1098)
# Finding nearest neighbours for PM2.5 stations...
# nearest_neighbours shape: (40, 1098)
# Cleaning data and handling missing values...
# Cleaned nearest_neighbours shape: (40, 1097)
# Preparing final training data...
# final_training_data shape: (15667, 5)
# Creating the dataset for Input:{input_name} ({i}) | Output: {output_name} ({j}) | Flag: {k}
# Extracting daily Pm2.5 data..
#  daily_PM_data shape: (40, 1095)
# Fusing AOD data from multiple years...
#  AOD_final shape: (1350, 1098)
# Finding nearest neighbours for PM2.5 stations...
# nearest_neighbours shape: (40, 1098)
# Cleaning data and handling missing values...
# Cleaned nearest_neighbours shape: (40, 1097)
# Preparing final training data...
# final_training_data shape: (15667, 5)
# Creating the dataset for Input:{input_name} ({i}) | Output: {output_name} ({j}) | Flag: {k}
# Extracting daily Pm2.5 data..
#  daily_PM_data shape: (40, 1095)
# Fusing AOD data from multiple years...
#  AOD_final shape: (1350, 1098)
# Finding nearest neighbours for PM2.5 stations...
# nearest_neighbours shape: (40, 1098)
# Cleaning data and handling missing values...
# Cleaned nearest_neighbours shape: (40, 1097)
# Preparing final training data...
# final_training_data shape: (15667, 5)
# Creating the dataset for Input:{input_name} ({i}) | Output: {output_name} ({j}) | Flag: {k}
# Extracting daily Pm2.5 data..
#  daily_PM_data shape: (40, 1095)
# Fusing AOD data from multiple years...
#  AOD_final shape: (1350, 1098)
# Finding nearest neighbours for PM2.5 stations...
# nearest_neighbours shape: (40, 1098)
# Cleaning data and handling missing values...
# Cleaned nearest_neighbours shape: (40, 1097)
# Preparing final training data...
# final_training_data shape: (15667, 5)
# Creating the dataset for Input:{input_name} ({i}) | Output: {output_name} ({j}) | Flag: {k}
# Extracting daily Pm2.5 data..
#  daily_PM_data shape: (40, 1095)
# Fusing AOD data from multiple years...
#  AOD_final shape: (1350, 1098)
# Finding nearest neighbours for PM2.5 stations...
# nearest_neighbours shape: (40, 1098)
# Cleaning data and handling missing values...
# Cleaned nearest_neighbours shape: (40, 1097)
# Preparing final training data...
# final_training_data shape: (15667, 5)
# Creating the dataset for Input:{input_name} ({i}) | Output: {output_name} ({j}) | Flag: {k}
# Extracting daily Pm2.5 data..
#  daily_PM_data shape: (40, 1095)
# Fusing AOD data from multiple years...
#  AOD_final shape: (1350, 1098)
# Finding nearest neighbours for PM2.5 stations...
# nearest_neighbours shape: (40, 1098)
# Cleaning data and handling missing values...
# Cleaned nearest_neighbours shape: (40, 1097)
# Preparing final training data...
# final_training_data shape: (15667, 5)
# Creating the dataset for Input:{input_name} ({i}) | Output: {output_name} ({j}) | Flag: {k}
# Extracting daily Pm2.5 data..
#  daily_PM_data shape: (40, 1095)
# Fusing AOD data from multiple years...
#  AOD_final shape: (1350, 1098)
# Finding nearest neighbours for PM2.5 stations...
# nearest_neighbours shape: (40, 1098)
# Cleaning data and handling missing values...
# Cleaned nearest_neighbours shape: (40, 1097)
# Preparing final training data...
# final_training_data shape: (15667, 5)
# Creating the dataset for Input:{input_name} ({i}) | Output: {output_name} ({j}) | Flag: {k}
# Extracting daily Pm2.5 data..
#  daily_PM_data shape: (40, 1095)
# Fusing AOD data from multiple years...
#  AOD_final shape: (1350, 1098)
# Finding nearest neighbours for PM2.5 stations...
# nearest_neighbours shape: (40, 1098)
# Cleaning data and handling missing values...
# Cleaned nearest_neighbours shape: (40, 1097)
# Preparing final training data...
# final_training_data shape: (15667, 5)
# Creating the dataset for Input:{input_name} ({i}) | Output: {output_name} ({j}) | Flag: {k}
# Extracting daily Pm2.5 data..
#  daily_PM_data shape: (40, 1095)
# Fusing AOD data from multiple years...
#  AOD_final shape: (1350, 1098)
# Finding nearest neighbours for PM2.5 stations...
# nearest_neighbours shape: (40, 1098)
# Cleaning data and handling missing values...
# Cleaned nearest_neighbours shape: (40, 1097)
# Preparing final training data...
# final_training_data shape: (15667, 5)
# Creating the dataset for Input:{input_name} ({i}) | Output: {output_name} ({j}) | Flag: {k}
# Extracting daily Pm2.5 data..
#  daily_PM_data shape: (40, 1095)
# Fusing AOD data from multiple years...
#  AOD_final shape: (1350, 1098)
# Finding nearest neighbours for PM2.5 stations...
# nearest_neighbours shape: (40, 1098)
# Cleaning data and handling missing values...
# Cleaned nearest_neighbours shape: (40, 1097)
# Preparing final training data...
# final_training_data shape: (15667, 5)
# Creating the dataset for Input:{input_name} ({i}) | Output: {output_name} ({j}) | Flag: {k}
# Extracting daily Pm2.5 data..
#  daily_PM_data shape: (40, 1095)
# Fusing AOD data from multiple years...
#  AOD_final shape: (1350, 1098)
# Finding nearest neighbours for PM2.5 stations...
# nearest_neighbours shape: (40, 1098)
# Cleaning data and handling missing values...
# Cleaned nearest_neighbours shape: (40, 1097)
# Preparing final training data...
# final_training_data shape: (15667, 5)
# Creating the dataset for Input:{input_name} ({i}) | Output: {output_name} ({j}) | Flag: {k}
# Extracting daily Pm2.5 data..
#  daily_PM_data shape: (40, 1095)
# Fusing AOD data from multiple years...
#  AOD_final shape: (1350, 1098)
# Finding nearest neighbours for PM2.5 stations...
# nearest_neighbours shape: (40, 1098)
# Cleaning data and handling missing values...
# Cleaned nearest_neighbours shape: (40, 1097)
# Preparing final training data...
# final_training_data shape: (15667, 5)
# Creating the dataset for Input:{input_name} ({i}) | Output: {output_name} ({j}) | Flag: {k}
# Extracting daily Pm2.5 data..
#  daily_PM_data shape: (40, 1095)
# Fusing AOD data from multiple years...
#  AOD_final shape: (1350, 1098)
# Finding nearest neighbours for PM2.5 stations...
# nearest_neighbours shape: (40, 1098)
# Cleaning data and handling missing values...
# Cleaned nearest_neighbours shape: (40, 1097)
# Preparing final training data...
# final_training_data shape: (15667, 5)
# Creating the dataset for Input:{input_name} ({i}) | Output: {output_name} ({j}) | Flag: {k}
# Extracting daily Pm2.5 data..
#  daily_PM_data shape: (40, 1095)
# Fusing AOD data from multiple years...
#  AOD_final shape: (1350, 1098)
# Finding nearest neighbours for PM2.5 stations...
# nearest_neighbours shape: (40, 1098)
# Cleaning data and handling missing values...
# Cleaned nearest_neighbours shape: (40, 1097)
# Preparing final training data...
# final_training_data shape: (15667, 5)
# Creating the dataset for Input:{input_name} ({i}) | Output: {output_name} ({j}) | Flag: {k}
# Extracting daily Pm2.5 data..
#  daily_PM_data shape: (40, 1095)
# Fusing AOD data from multiple years...
#  AOD_final shape: (1350, 1098)
# Finding nearest neighbours for PM2.5 stations...
# nearest_neighbours shape: (40, 1098)
# Cleaning data and handling missing values...
# Cleaned nearest_neighbours shape: (40, 1097)
# Preparing final training data...
# final_training_data shape: (15667, 5)
# Creating the dataset for Input:{input_name} ({i}) | Output: {output_name} ({j}) | Flag: {k}
# Extracting daily Pm2.5 data..
#  daily_PM_data shape: (40, 1095)
# Fusing AOD data from multiple years...
#  AOD_final shape: (1350, 1098)
# Finding nearest neighbours for PM2.5 stations...
# nearest_neighbours shape: (40, 1098)
# Cleaning data and handling missing values...
# Cleaned nearest_neighbours shape: (40, 1097)
# Preparing final training data...
# final_training_data shape: (15667, 5)

# %%
datasets[(1,1,"Train")]
# Out:
# {'inputs': tensor([[ 0.2875, -1.3133,  0.3943,  ...,  1.5133,  0.9654,  1.2592],
#          [ 0.2875, -1.3133,  0.3943,  ...,  1.5133, -0.7220, -0.0482],
#          [ 0.2875, -1.3133,  0.3943,  ...,  1.5133, -0.3033, -0.1231],
#          ...,
#          [ 0.2884, -1.3129,  0.3950,  ...,  1.5133, -0.5858, -0.2545],
#          [ 0.2884, -1.3129,  0.3950,  ...,  1.5133,  0.4649, -0.3712],
#          [ 0.2884, -1.3129,  0.3950,  ...,  1.5133, -0.4296,  0.0278]],
#         grad_fn=<CatBackward0>),
#  'outputs': tensor([[ 0.9654,  1.2592],
#          [-0.7220, -0.0482],
#          [-0.3033, -0.1231],
#          ...,
#          [-0.5858, -0.2545],
#          [ 0.4649, -0.3712],
#          [-0.4296,  0.0278]])}

# %%
datasets[(1,1,"Train")]["inputs"]
# Out:
# tensor([[ 0.2875, -1.3133,  0.3943,  ...,  1.5133,  0.9654,  1.2592],
#         [ 0.2875, -1.3133,  0.3943,  ...,  1.5133, -0.7220, -0.0482],
#         [ 0.2875, -1.3133,  0.3943,  ...,  1.5133, -0.3033, -0.1231],
#         ...,
#         [ 0.2884, -1.3129,  0.3950,  ...,  1.5133, -0.5858, -0.2545],
#         [ 0.2884, -1.3129,  0.3950,  ...,  1.5133,  0.4649, -0.3712],
#         [ 0.2884, -1.3129,  0.3950,  ...,  1.5133, -0.4296,  0.0278]],
#        grad_fn=<CatBackward0>)

# %%
datasets[(1,1,"Train")]["inputs"].shape
# Out:
# torch.Size([12307, 128])

# %%
datasets[(1,1,"Train")]["outputs"].shape
# Out:
# torch.Size([12307, 2])

# %%
datasets[(1,2,"Train")]["inputs"].shape
# Out:
# torch.Size([12307, 128])

# %%
datasets[(1,2,"Train")]["outputs"].shape
# Out:
# torch.Size([12307, 1])

# %%
from optimizer_utils import NPTrainer

# %%
from lossfunctions import LossFunctions
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# File /Users/pavankumar/Documents/Winter_Thesis/Coding_Learning/Master-Thesis/src/training/trainer_latlon_AOD_PM25.py:1
# ----> 1 from lossfunctions import LossFunctions
#
# ModuleNotFoundError: No module named 'lossfunctions'

# %%
from loss_functions import LossFunctions
# Out:
# /Users/pavankumar/Documents/Winter_Thesis/Coding_Learning/Master-Thesis

# %%
config["experiments"]["input_vars"][1]
# Out:
# ['latitude', 'longitude', 'AOD', 'PM2.5']

# %%
len(config["experiments"]["input_vars"][1])
# Out:
# 4

# %%
from torch.optimizer import optim
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# File /Users/pavankumar/Documents/Winter_Thesis/Coding_Learning/Master-Thesis/src/training/trainer_latlon_AOD_PM25.py:1
# ----> 1 from torch.optimizer import optim
#
# ModuleNotFoundError: No module named 'torch.optimizer'

# %%
from torch import optim

# %%
"""
Importing the necessary packages.............
"""

import os
import torch
import numpy as np
import pandas as pd
import sys
from pathlib import Path
import os
import matplotlib.pyplot as plt
from glob import glob
from tqdm import tqdm
import arrow
from datetime import datetime
from torch import optim

# from utils.config import config
from torch.utils.data import DataLoader

ROOT = Path(__file__).resolve().parents[2]  # tests/ -> project root
sys.path.insert(0, str(ROOT))
print(ROOT)
# Out:
# /Users/pavankumar/Documents/Winter_Thesis/Coding_Learning/Master-Thesis

# %%
Loss = LossFunctions()

# %%
from loss_functions import LossFunctions
Loss = LossFunctions()

# %%
from optimizer_utils import NPTrainer

# %%
from optimizer_utils import neural_process_data

# %%
NeuralProcessData_latlon_PM25
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# File /Users/pavankumar/Documents/Winter_Thesis/Coding_Learning/Master-Thesis/src/training/trainer_latlon_AOD_PM25.py:1
# ----> 1 NeuralProcessData_latlon_PM25
#
# NameError: name 'NeuralProcessData_latlon_PM25' is not defined

# %%
NeuralProcessData_latlon_AOD_PM25_val = neural_process_data(
    final_data_latlong_AOD_PM25_val[0],
    final_data_latlong_AOD_PM25_val[1],
    num_points_per_task=200,
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# File /Users/pavankumar/Documents/Winter_Thesis/Coding_Learning/Master-Thesis/src/training/trainer_latlon_AOD_PM25.py:2
#       1 NeuralProcessData_latlon_AOD_PM25_val = neural_process_data(
# ----> 2     final_data_latlong_AOD_PM25_val[0],
#       3     final_data_latlong_AOD_PM25_val[1],
#       4     num_points_per_task=200,
#       5 )
#
# NameError: name 'final_data_latlong_AOD_PM25_val' is not defined

# %%
from optimizer_utils import validation_function

# %%
from optimizer_utils import validation_function

# %%
datasets[(1, 2, "Val")]["inputs"].shape
# Out:
# torch.Size([1363, 128])

# %%
datasets[(1, 2, "Val")]["outputs"].shape
# Out:
# torch.Size([1363, 1])

# %%
datasets[(1, 1, "Val")]["outputs"].shape
# Out:
# torch.Size([1363, 2])

# %%
input_type = [1, 2, 3, 4]
output_type = [1, 2, 3]
flag = ["Train", "Val", "Test"]

# Now we will loop over all the combinations to create the final datasets.
datasets = {}
for i in input_type:
    if i == "":
        print("Invalid input type")
        continue
    for j in output_type:
        if j == "":
            print("Invalid output type")
            continue
        for k in flag:
            if k == "":
                print("Invalid flag")
                continue
            else:
                # From here we will do the proper string formatting.
                # Here these are the column names below has been mentioned.
                input_name = config["experiments"]["input_vars"][i]
                output_name = config["experiments"]["output_vars"][j]
                print(
                    f"Creating the dataset for Input:{input_name}({i}) | Output: {output_name} ({j}) | Flag: {k}"
                )
                Final_Data = Final_Air_Quality_Dataset_pipeline(
                    config=config,
                    geospatial_encoder=geospatial_encoder,
                    flag=k,
                    input_type=i,
                    output_type=j,
                )
                current_inputs, current_outputs = Final_Data.full_pipeline()

                datasets[(i, j, k)] = {
                    "inputs": current_inputs,
                    "outputs": current_outputs,
                }

# Checking the datsets sizes.
datasets[(1, 2, "Train")]["inputs"].shape
datasets[(1, 2, "Train")]["outputs"].shape
datasets[(1, 2, "Val")]["outputs"].shape
datasets[(1, 1, "Val")]["outputs"].shape
# Out:
# Creating the dataset for Input:['latitude', 'longitude', 'AOD', 'PM2.5'](1) | Output: ['AOD', 'PM2.5'] (1) | Flag: Train
# Extracting daily Pm2.5 data..
#  daily_PM_data shape: (40, 1095)
# Fusing AOD data from multiple years...
#  AOD_final shape: (1350, 1098)
# Finding nearest neighbours for PM2.5 stations...
# nearest_neighbours shape: (40, 1098)
# Cleaning data and handling missing values...
# Cleaned nearest_neighbours shape: (40, 1097)
# Preparing final training data...
# final_training_data shape: (15667, 5)
# Creating the dataset for Input:['latitude', 'longitude', 'AOD', 'PM2.5'](1) | Output: ['AOD', 'PM2.5'] (1) | Flag: Val
# Extracting daily Pm2.5 data..
#  daily_PM_data shape: (40, 1095)
# Fusing AOD data from multiple years...
#  AOD_final shape: (1350, 1098)
# Finding nearest neighbours for PM2.5 stations...
# nearest_neighbours shape: (40, 1098)
# Cleaning data and handling missing values...
# Cleaned nearest_neighbours shape: (40, 1097)
# Preparing final training data...
# final_training_data shape: (15667, 5)
# Creating the dataset for Input:['latitude', 'longitude', 'AOD', 'PM2.5'](1) | Output: ['AOD', 'PM2.5'] (1) | Flag: Test
# Extracting daily Pm2.5 data..
#  daily_PM_data shape: (40, 1095)
# Fusing AOD data from multiple years...
#  AOD_final shape: (1350, 1098)
# Finding nearest neighbours for PM2.5 stations...
# nearest_neighbours shape: (40, 1098)
# Cleaning data and handling missing values...
# Cleaned nearest_neighbours shape: (40, 1097)
# Preparing final training data...
# final_training_data shape: (15667, 5)
# Creating the dataset for Input:['latitude', 'longitude', 'AOD', 'PM2.5'](1) | Output: ['AOD'] (2) | Flag: Train
# Extracting daily Pm2.5 data..
#  daily_PM_data shape: (40, 1095)
# Fusing AOD data from multiple years...
#  AOD_final shape: (1350, 1098)
# Finding nearest neighbours for PM2.5 stations...
# nearest_neighbours shape: (40, 1098)
# Cleaning data and handling missing values...
# Cleaned nearest_neighbours shape: (40, 1097)
# Preparing final training data...
# final_training_data shape: (15667, 5)
# Creating the dataset for Input:['latitude', 'longitude', 'AOD', 'PM2.5'](1) | Output: ['AOD'] (2) | Flag: Val
# Extracting daily Pm2.5 data..
#  daily_PM_data shape: (40, 1095)
# Fusing AOD data from multiple years...
#  AOD_final shape: (1350, 1098)
# Finding nearest neighbours for PM2.5 stations...
# nearest_neighbours shape: (40, 1098)
# Cleaning data and handling missing values...
# Cleaned nearest_neighbours shape: (40, 1097)
# Preparing final training data...
# final_training_data shape: (15667, 5)
# Creating the dataset for Input:['latitude', 'longitude', 'AOD', 'PM2.5'](1) | Output: ['AOD'] (2) | Flag: Test
# Extracting daily Pm2.5 data..
#  daily_PM_data shape: (40, 1095)
# Fusing AOD data from multiple years...
#  AOD_final shape: (1350, 1098)
# Finding nearest neighbours for PM2.5 stations...
# nearest_neighbours shape: (40, 1098)
# Cleaning data and handling missing values...
# Cleaned nearest_neighbours shape: (40, 1097)
# Preparing final training data...
# final_training_data shape: (15667, 5)
# Creating the dataset for Input:['latitude', 'longitude', 'AOD', 'PM2.5'](1) | Output: ['PM2.5'] (3) | Flag: Train
# Extracting daily Pm2.5 data..
#  daily_PM_data shape: (40, 1095)
# Fusing AOD data from multiple years...
#  AOD_final shape: (1350, 1098)
# Finding nearest neighbours for PM2.5 stations...
# nearest_neighbours shape: (40, 1098)
# Cleaning data and handling missing values...
# Cleaned nearest_neighbours shape: (40, 1097)
# Preparing final training data...
# final_training_data shape: (15667, 5)
# Creating the dataset for Input:['latitude', 'longitude', 'AOD', 'PM2.5'](1) | Output: ['PM2.5'] (3) | Flag: Val
# Extracting daily Pm2.5 data..
#  daily_PM_data shape: (40, 1095)
# Fusing AOD data from multiple years...
#  AOD_final shape: (1350, 1098)
# Finding nearest neighbours for PM2.5 stations...
# nearest_neighbours shape: (40, 1098)
# Cleaning data and handling missing values...
# Cleaned nearest_neighbours shape: (40, 1097)
# Preparing final training data...
# final_training_data shape: (15667, 5)
# Creating the dataset for Input:['latitude', 'longitude', 'AOD', 'PM2.5'](1) | Output: ['PM2.5'] (3) | Flag: Test
# Extracting daily Pm2.5 data..
#  daily_PM_data shape: (40, 1095)
# Fusing AOD data from multiple years...
#  AOD_final shape: (1350, 1098)
# Finding nearest neighbours for PM2.5 stations...
# nearest_neighbours shape: (40, 1098)
# Cleaning data and handling missing values...
# Cleaned nearest_neighbours shape: (40, 1097)
# Preparing final training data...
# final_training_data shape: (15667, 5)
# Creating the dataset for Input:['latitude', 'longitude', 'AOD'](2) | Output: ['AOD', 'PM2.5'] (1) | Flag: Train
# Extracting daily Pm2.5 data..
#  daily_PM_data shape: (40, 1095)
# Fusing AOD data from multiple years...
#  AOD_final shape: (1350, 1098)
# Finding nearest neighbours for PM2.5 stations...
# nearest_neighbours shape: (40, 1098)
# Cleaning data and handling missing values...
# Cleaned nearest_neighbours shape: (40, 1097)
# Preparing final training data...
# final_training_data shape: (15667, 5)
# Creating the dataset for Input:['latitude', 'longitude', 'AOD'](2) | Output: ['AOD', 'PM2.5'] (1) | Flag: Val
# Extracting daily Pm2.5 data..
#  daily_PM_data shape: (40, 1095)
# Fusing AOD data from multiple years...
#  AOD_final shape: (1350, 1098)
# Finding nearest neighbours for PM2.5 stations...
# nearest_neighbours shape: (40, 1098)
# Cleaning data and handling missing values...
# Cleaned nearest_neighbours shape: (40, 1097)
# Preparing final training data...
# final_training_data shape: (15667, 5)
# Creating the dataset for Input:['latitude', 'longitude', 'AOD'](2) | Output: ['AOD', 'PM2.5'] (1) | Flag: Test
# Extracting daily Pm2.5 data..
#  daily_PM_data shape: (40, 1095)
# Fusing AOD data from multiple years...
#  AOD_final shape: (1350, 1098)
# Finding nearest neighbours for PM2.5 stations...
# nearest_neighbours shape: (40, 1098)
# Cleaning data and handling missing values...
# Cleaned nearest_neighbours shape: (40, 1097)
# Preparing final training data...
# final_training_data shape: (15667, 5)
# Creating the dataset for Input:['latitude', 'longitude', 'AOD'](2) | Output: ['AOD'] (2) | Flag: Train
# Extracting daily Pm2.5 data..
#  daily_PM_data shape: (40, 1095)
# Fusing AOD data from multiple years...
#  AOD_final shape: (1350, 1098)
# Finding nearest neighbours for PM2.5 stations...
# nearest_neighbours shape: (40, 1098)
# Cleaning data and handling missing values...
# Cleaned nearest_neighbours shape: (40, 1097)
# Preparing final training data...
# final_training_data shape: (15667, 5)
# Creating the dataset for Input:['latitude', 'longitude', 'AOD'](2) | Output: ['AOD'] (2) | Flag: Val
# Extracting daily Pm2.5 data..
#  daily_PM_data shape: (40, 1095)
# Fusing AOD data from multiple years...
#  AOD_final shape: (1350, 1098)
# Finding nearest neighbours for PM2.5 stations...
# nearest_neighbours shape: (40, 1098)
# Cleaning data and handling missing values...
# Cleaned nearest_neighbours shape: (40, 1097)
# Preparing final training data...
# final_training_data shape: (15667, 5)
# Creating the dataset for Input:['latitude', 'longitude', 'AOD'](2) | Output: ['AOD'] (2) | Flag: Test
# Extracting daily Pm2.5 data..
#  daily_PM_data shape: (40, 1095)
# Fusing AOD data from multiple years...
#  AOD_final shape: (1350, 1098)
# Finding nearest neighbours for PM2.5 stations...
# nearest_neighbours shape: (40, 1098)
# Cleaning data and handling missing values...
# Cleaned nearest_neighbours shape: (40, 1097)
# Preparing final training data...
# final_training_data shape: (15667, 5)
# Creating the dataset for Input:['latitude', 'longitude', 'AOD'](2) | Output: ['PM2.5'] (3) | Flag: Train
# Extracting daily Pm2.5 data..
#  daily_PM_data shape: (40, 1095)
# Fusing AOD data from multiple years...
#  AOD_final shape: (1350, 1098)
# Finding nearest neighbours for PM2.5 stations...
# nearest_neighbours shape: (40, 1098)
# Cleaning data and handling missing values...
# Cleaned nearest_neighbours shape: (40, 1097)
# Preparing final training data...
# final_training_data shape: (15667, 5)
# Creating the dataset for Input:['latitude', 'longitude', 'AOD'](2) | Output: ['PM2.5'] (3) | Flag: Val
# Extracting daily Pm2.5 data..
#  daily_PM_data shape: (40, 1095)
# Fusing AOD data from multiple years...
#  AOD_final shape: (1350, 1098)
# Finding nearest neighbours for PM2.5 stations...
# nearest_neighbours shape: (40, 1098)
# Cleaning data and handling missing values...
# Cleaned nearest_neighbours shape: (40, 1097)
# Preparing final training data...
# final_training_data shape: (15667, 5)
# Creating the dataset for Input:['latitude', 'longitude', 'AOD'](2) | Output: ['PM2.5'] (3) | Flag: Test
# Extracting daily Pm2.5 data..
#  daily_PM_data shape: (40, 1095)
# Fusing AOD data from multiple years...
#  AOD_final shape: (1350, 1098)
# Finding nearest neighbours for PM2.5 stations...
# nearest_neighbours shape: (40, 1098)
# Cleaning data and handling missing values...
# Cleaned nearest_neighbours shape: (40, 1097)
# Preparing final training data...
# final_training_data shape: (15667, 5)
# Creating the dataset for Input:['latitude', 'longitude', 'PM2.5'](3) | Output: ['AOD', 'PM2.5'] (1) | Flag: Train
# Extracting daily Pm2.5 data..
#  daily_PM_data shape: (40, 1095)
# Fusing AOD data from multiple years...
#  AOD_final shape: (1350, 1098)
# Finding nearest neighbours for PM2.5 stations...
# nearest_neighbours shape: (40, 1098)
# Cleaning data and handling missing values...
# Cleaned nearest_neighbours shape: (40, 1097)
# Preparing final training data...
# final_training_data shape: (15667, 5)
# Creating the dataset for Input:['latitude', 'longitude', 'PM2.5'](3) | Output: ['AOD', 'PM2.5'] (1) | Flag: Val
# Extracting daily Pm2.5 data..
#  daily_PM_data shape: (40, 1095)
# Fusing AOD data from multiple years...
#  AOD_final shape: (1350, 1098)
# Finding nearest neighbours for PM2.5 stations...
# nearest_neighbours shape: (40, 1098)
# Cleaning data and handling missing values...
# Cleaned nearest_neighbours shape: (40, 1097)
# Preparing final training data...
# final_training_data shape: (15667, 5)
# Creating the dataset for Input:['latitude', 'longitude', 'PM2.5'](3) | Output: ['AOD', 'PM2.5'] (1) | Flag: Test
# Extracting daily Pm2.5 data..
#  daily_PM_data shape: (40, 1095)
# Fusing AOD data from multiple years...
#  AOD_final shape: (1350, 1098)
# Finding nearest neighbours for PM2.5 stations...
# nearest_neighbours shape: (40, 1098)
# Cleaning data and handling missing values...
# Cleaned nearest_neighbours shape: (40, 1097)
# Preparing final training data...
# final_training_data shape: (15667, 5)
# Creating the dataset for Input:['latitude', 'longitude', 'PM2.5'](3) | Output: ['AOD'] (2) | Flag: Train
# Extracting daily Pm2.5 data..
#  daily_PM_data shape: (40, 1095)
# Fusing AOD data from multiple years...
#  AOD_final shape: (1350, 1098)
# Finding nearest neighbours for PM2.5 stations...
# nearest_neighbours shape: (40, 1098)
# Cleaning data and handling missing values...
# Cleaned nearest_neighbours shape: (40, 1097)
# Preparing final training data...
# final_training_data shape: (15667, 5)
# Creating the dataset for Input:['latitude', 'longitude', 'PM2.5'](3) | Output: ['AOD'] (2) | Flag: Val
# Extracting daily Pm2.5 data..
#  daily_PM_data shape: (40, 1095)
# Fusing AOD data from multiple years...
#  AOD_final shape: (1350, 1098)
# Finding nearest neighbours for PM2.5 stations...
# nearest_neighbours shape: (40, 1098)
# Cleaning data and handling missing values...
# Cleaned nearest_neighbours shape: (40, 1097)
# Preparing final training data...
# final_training_data shape: (15667, 5)
# Creating the dataset for Input:['latitude', 'longitude', 'PM2.5'](3) | Output: ['AOD'] (2) | Flag: Test
# Extracting daily Pm2.5 data..
#  daily_PM_data shape: (40, 1095)
# Fusing AOD data from multiple years...
#  AOD_final shape: (1350, 1098)
# Finding nearest neighbours for PM2.5 stations...
# nearest_neighbours shape: (40, 1098)
# Cleaning data and handling missing values...
# Cleaned nearest_neighbours shape: (40, 1097)
# Preparing final training data...
# final_training_data shape: (15667, 5)
# Creating the dataset for Input:['latitude', 'longitude', 'PM2.5'](3) | Output: ['PM2.5'] (3) | Flag: Train
# Extracting daily Pm2.5 data..
#  daily_PM_data shape: (40, 1095)
# Fusing AOD data from multiple years...
#  AOD_final shape: (1350, 1098)
# Finding nearest neighbours for PM2.5 stations...
# nearest_neighbours shape: (40, 1098)
# Cleaning data and handling missing values...
# Cleaned nearest_neighbours shape: (40, 1097)
# Preparing final training data...
# final_training_data shape: (15667, 5)
# Creating the dataset for Input:['latitude', 'longitude', 'PM2.5'](3) | Output: ['PM2.5'] (3) | Flag: Val
# Extracting daily Pm2.5 data..
#  daily_PM_data shape: (40, 1095)
# Fusing AOD data from multiple years...
#  AOD_final shape: (1350, 1098)
# Finding nearest neighbours for PM2.5 stations...
# nearest_neighbours shape: (40, 1098)
# Cleaning data and handling missing values...
# Cleaned nearest_neighbours shape: (40, 1097)
# Preparing final training data...
# final_training_data shape: (15667, 5)
# Creating the dataset for Input:['latitude', 'longitude', 'PM2.5'](3) | Output: ['PM2.5'] (3) | Flag: Test
# Extracting daily Pm2.5 data..
#  daily_PM_data shape: (40, 1095)
# Fusing AOD data from multiple years...
#  AOD_final shape: (1350, 1098)
# Finding nearest neighbours for PM2.5 stations...
# nearest_neighbours shape: (40, 1098)
# Cleaning data and handling missing values...
# Cleaned nearest_neighbours shape: (40, 1097)
# Preparing final training data...
# final_training_data shape: (15667, 5)
# Creating the dataset for Input:['latitude', 'longitude'](4) | Output: ['AOD', 'PM2.5'] (1) | Flag: Train
# Extracting daily Pm2.5 data..
#  daily_PM_data shape: (40, 1095)
# Fusing AOD data from multiple years...
#  AOD_final shape: (1350, 1098)
# Finding nearest neighbours for PM2.5 stations...
# nearest_neighbours shape: (40, 1098)
# Cleaning data and handling missing values...
# Cleaned nearest_neighbours shape: (40, 1097)
# Preparing final training data...
# final_training_data shape: (15667, 5)
# Creating the dataset for Input:['latitude', 'longitude'](4) | Output: ['AOD', 'PM2.5'] (1) | Flag: Val
# Extracting daily Pm2.5 data..
#  daily_PM_data shape: (40, 1095)
# Fusing AOD data from multiple years...
#  AOD_final shape: (1350, 1098)
# Finding nearest neighbours for PM2.5 stations...
# nearest_neighbours shape: (40, 1098)
# Cleaning data and handling missing values...
# Cleaned nearest_neighbours shape: (40, 1097)
# Preparing final training data...
# final_training_data shape: (15667, 5)
# Creating the dataset for Input:['latitude', 'longitude'](4) | Output: ['AOD', 'PM2.5'] (1) | Flag: Test
# Extracting daily Pm2.5 data..
#  daily_PM_data shape: (40, 1095)
# Fusing AOD data from multiple years...
#  AOD_final shape: (1350, 1098)
# Finding nearest neighbours for PM2.5 stations...
# nearest_neighbours shape: (40, 1098)
# Cleaning data and handling missing values...
# Cleaned nearest_neighbours shape: (40, 1097)
# Preparing final training data...
# final_training_data shape: (15667, 5)
# Creating the dataset for Input:['latitude', 'longitude'](4) | Output: ['AOD'] (2) | Flag: Train
# Extracting daily Pm2.5 data..
#  daily_PM_data shape: (40, 1095)
# Fusing AOD data from multiple years...
#  AOD_final shape: (1350, 1098)
# Finding nearest neighbours for PM2.5 stations...
# nearest_neighbours shape: (40, 1098)
# Cleaning data and handling missing values...
# Cleaned nearest_neighbours shape: (40, 1097)
# Preparing final training data...
# final_training_data shape: (15667, 5)
# Creating the dataset for Input:['latitude', 'longitude'](4) | Output: ['AOD'] (2) | Flag: Val
# Extracting daily Pm2.5 data..
#  daily_PM_data shape: (40, 1095)
# Fusing AOD data from multiple years...
#  AOD_final shape: (1350, 1098)
# Finding nearest neighbours for PM2.5 stations...
# nearest_neighbours shape: (40, 1098)
# Cleaning data and handling missing values...
# Cleaned nearest_neighbours shape: (40, 1097)
# Preparing final training data...
# final_training_data shape: (15667, 5)
# Creating the dataset for Input:['latitude', 'longitude'](4) | Output: ['AOD'] (2) | Flag: Test
# Extracting daily Pm2.5 data..
#  daily_PM_data shape: (40, 1095)
# Fusing AOD data from multiple years...
#  AOD_final shape: (1350, 1098)
# Finding nearest neighbours for PM2.5 stations...
# nearest_neighbours shape: (40, 1098)
# Cleaning data and handling missing values...
# Cleaned nearest_neighbours shape: (40, 1097)
# Preparing final training data...
# final_training_data shape: (15667, 5)
# Creating the dataset for Input:['latitude', 'longitude'](4) | Output: ['PM2.5'] (3) | Flag: Train
# Extracting daily Pm2.5 data..
#  daily_PM_data shape: (40, 1095)
# Fusing AOD data from multiple years...
#  AOD_final shape: (1350, 1098)
# Finding nearest neighbours for PM2.5 stations...
# nearest_neighbours shape: (40, 1098)
# Cleaning data and handling missing values...
# Cleaned nearest_neighbours shape: (40, 1097)
# Preparing final training data...
# final_training_data shape: (15667, 5)
# Creating the dataset for Input:['latitude', 'longitude'](4) | Output: ['PM2.5'] (3) | Flag: Val
# Extracting daily Pm2.5 data..
#  daily_PM_data shape: (40, 1095)
# Fusing AOD data from multiple years...
#  AOD_final shape: (1350, 1098)
# Finding nearest neighbours for PM2.5 stations...
# nearest_neighbours shape: (40, 1098)
# Cleaning data and handling missing values...
# Cleaned nearest_neighbours shape: (40, 1097)
# Preparing final training data...
# final_training_data shape: (15667, 5)
# Creating the dataset for Input:['latitude', 'longitude'](4) | Output: ['PM2.5'] (3) | Flag: Test
# Extracting daily Pm2.5 data..
#  daily_PM_data shape: (40, 1095)
# Fusing AOD data from multiple years...
#  AOD_final shape: (1350, 1098)
# Finding nearest neighbours for PM2.5 stations...
# nearest_neighbours shape: (40, 1098)
# Cleaning data and handling missing values...
# Cleaned nearest_neighbours shape: (40, 1097)
# Preparing final training data...
# final_training_data shape: (15667, 5)
# torch.Size([1363, 2])

# %%
datasets[(1, 2, "Train")]["inputs"].shape
# Out:
# torch.Size([12307, 128])

# %%
datasets[(1, 2, "Train")]["outputs"].shape
# Out:
# torch.Size([12307, 1])

# %%
datasets[(1, 1, "Val")]["outputs"].shape
# Out:
# torch.Size([1363, 2])

# %%
datasets[(1, 2, "Val")]["outputs"].shape
# Out:
# torch.Size([1363, 1])

# %%
datasets[(1, 2, "Test")]["outputs"].shape
datasets[(1, 1, "Test")]["outputs"].shape
# Out:
# torch.Size([1997, 2])

# %%
datasets[(1, 2, "Train")]["inputs"].shape
datasets[(1, 2, "Train")]["outputs"].shape
datasets[(1, 2, "Val")]["outputs"].shape
datasets[(1, 1, "Val")]["outputs"].shape
datasets[(1, 2, "Test")]["outputs"].shape
datasets[(1, 1, "Test")]["outputs"].shape
# Out:
# torch.Size([1997, 2])

# %%
datasets[(1, 2, "Test")]["outputs"].shape
# Out:
# torch.Size([1997, 1])

# %%
datasets[(1, 1, "Val")]["outputs"].shape
# Out:
# torch.Size([1363, 2])

# %%
from loss_functions import LossFunctions

Loss = LossFunctions()
from optimizer_utils import NPTrainer
from optimizer_utils import neural_process_data
from optimizer_utils import validation_function
# importing the packages for the optimization.


for input_key in input_type:
    if input_key == "":
        print("Please check the input keys")
        continue
    for output_key in output_type:
        if output_key == "":
            print("Please check the output keys")
            continue
        print(f" Start Training of Input: {input_key} | Output : {output_key}")
        # the current inputs and current outputs are:
        current_inputs = config["experiments"]["input_vars"][input_key]
        in_name = "_".join(current_inputs)
        current_outputs = config["experiments"]["output_vars"][output_key]
        out_name = "_".join(current_outputs)
        # We can calculate the dimensions of the inputs and putputs to decide the number of model's layers.

        x_dim = len(current_inputs)
        y_dim = len(current_outputs)
        # In this model the inputs and outputs are.
        model = NeuralProcess(x_dim, y_dim, x_dim, y_dim, 128, 128).to("cpu")
        # Defining the current check points and log directories.
        current_log_dir = f"./Master-Thesis/cpu_logs/{in_name}_{out_name}"
        current_checkpoint_dir = f"./Master-Thesis/cpu_checkpoints/{in_name}_{out_name}"
        # defining the optimizer
        Optimizer = optim.Adam(
            model.parameters(), lr=float(config["experiments"]["train"]["lr"])
        )
        # Defining the training class
        Training = NPTrainer(
            model=model,
            optimizer=Optimizer,
            loss_fn=Loss,
            device="cpu",
            log_dir=current_log_dir,
            checkpoint_dir=current_checkpoint_dir,
        )
        # To check the model's accuracy in validation data set we will use this.
        best_val_loss = float("inf")
        # these are the training data sets

        NeuralProcess_Train_data = neural_process_data(
            datasets[(input_key, output_key, "Train")]["inputs"],
            datasets[(input_key, output_key, "Train")]["outputs"],
            num_points_per_task=200,
        )

        NeuralProcess_Train_dataloader = DataLoader(
            NeuralProcess_Train_data,
            batch_size=16,
            shuffle=True,
            num_workers=0,
        )
        # Now we will define the validation datasets as well as validation dataloasers
        # NeuralProcess_Val_datasets = {}
        NeuralProcess_Val_data = neural_process_data(
            datasets[(input_key, output_key, "Val")]["inputs"],
            datasets[(input_key, output_key, "Val")]["outputs"],
            num_points_per_task=200,
        )

        # NeuralProcess_Val_dataloaders = {}
        NeuralProcess_Val_dataloader = DataLoader(
            NeuralProcess_Val_data,
            batch_size=16,
            shuffle=True,
            num_workers=0,
        )

        for epoch in range(100):
            # Train
            train_loss = Training.train_epoch(NeuralProcess_Train_dataloader, epoch)
            val_loss = validation_function(
                model=model,
                val_dataloader=NeuralProcess_Val_dataloader,
                loss=Loss,
                device="cpu",
            )
            print(
                f"Epoch:{epoch} | Val_loss:{val_loss:.4f} | Train_loss:{train_loss:.4f}"
            )
            if val_loss < best_val_loss:
                best_val_loss = val_loss
                Training.save_checkpoint(epoch)
                print(f" >>> Saved New Best Model found! ")
# Out:
#  Start Training of Input: 1 | Output : 1
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# File /Users/pavankumar/Documents/Winter_Thesis/Coding_Learning/Master-Thesis/src/training/trainer_latlon_AOD_PM25.py:29
#      27 y_dim = len(current_outputs)
#      28 # In this model the inputs and outputs are.
# ---> 29 model = NeuralProcess(x_dim, y_dim, x_dim, y_dim, 128, 128).to("cpu")
#      30 # Defining the current check points and log directories.
#      31 current_log_dir = f"./Master-Thesis/cpu_logs/{in_name}_{out_name}"
#
# NameError: name 'NeuralProcess' is not defined

# %%
from loss_functions import LossFunctions

Loss = LossFunctions()
from optimizer_utils import NPTrainer
from optimizer_utils import neural_process_data
from optimizer_utils import validation_function
# importing the packages for the optimization.
from Dataloader.Modis_Data_loader.torch_data_loader import Airqualitydataset
from Dataloader.Modis_Data_loader.final_loader import Final_Air_Quality_Dataset_pipeline
from src.Models.neural_process import NeuralProcess

for input_key in input_type:
    if input_key == "":
        print("Please check the input keys")
        continue
    for output_key in output_type:
        if output_key == "":
            print("Please check the output keys")
            continue
        print(f" Start Training of Input: {input_key} | Output : {output_key}")
        # the current inputs and current outputs are:
        current_inputs = config["experiments"]["input_vars"][input_key]
        in_name = "_".join(current_inputs)
        current_outputs = config["experiments"]["output_vars"][output_key]
        out_name = "_".join(current_outputs)
        # We can calculate the dimensions of the inputs and putputs to decide the number of model's layers.

        x_dim = len(current_inputs)
        y_dim = len(current_outputs)
        # In this model the inputs and outputs are.
        model = NeuralProcess(x_dim, y_dim, x_dim, y_dim, 128, 128).to("cpu")
        # Defining the current check points and log directories.
        current_log_dir = f"./Master-Thesis/cpu_logs/{in_name}_{out_name}"
        current_checkpoint_dir = f"./Master-Thesis/cpu_checkpoints/{in_name}_{out_name}"
        # defining the optimizer
        Optimizer = optim.Adam(
            model.parameters(), lr=float(config["experiments"]["train"]["lr"])
        )
        # Defining the training class
        Training = NPTrainer(
            model=model,
            optimizer=Optimizer,
            loss_fn=Loss,
            device="cpu",
            log_dir=current_log_dir,
            checkpoint_dir=current_checkpoint_dir,
        )
        # To check the model's accuracy in validation data set we will use this.
        best_val_loss = float("inf")
        # these are the training data sets

        NeuralProcess_Train_data = neural_process_data(
            datasets[(input_key, output_key, "Train")]["inputs"],
            datasets[(input_key, output_key, "Train")]["outputs"],
            num_points_per_task=200,
        )

        NeuralProcess_Train_dataloader = DataLoader(
            NeuralProcess_Train_data,
            batch_size=16,
            shuffle=True,
            num_workers=0,
        )
        # Now we will define the validation datasets as well as validation dataloasers
        # NeuralProcess_Val_datasets = {}
        NeuralProcess_Val_data = neural_process_data(
            datasets[(input_key, output_key, "Val")]["inputs"],
            datasets[(input_key, output_key, "Val")]["outputs"],
            num_points_per_task=200,
        )

        # NeuralProcess_Val_dataloaders = {}
        NeuralProcess_Val_dataloader = DataLoader(
            NeuralProcess_Val_data,
            batch_size=16,
            shuffle=True,
            num_workers=0,
        )

        for epoch in range(100):
            # Train
            train_loss = Training.train_epoch(NeuralProcess_Train_dataloader, epoch)
            val_loss = validation_function(
                model=model,
                val_dataloader=NeuralProcess_Val_dataloader,
                loss=Loss,
                device="cpu",
            )
            print(
                f"Epoch:{epoch} | Val_loss:{val_loss:.4f} | Train_loss:{train_loss:.4f}"
            )
            if val_loss < best_val_loss:
                best_val_loss = val_loss
                Training.save_checkpoint(epoch)
                print(f" >>> Saved New Best Model found! ")
# Out:
# /Users/pavankumar/Documents/Winter_Thesis/Coding_Learning/Master-Thesis
#  Start Training of Input: 1 | Output : 1
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /Users/pavankumar/Documents/Winter_Thesis/Coding_Learning/Master-Thesis/src/training/trainer_latlon_AOD_PM25.py:37
#      34 current_checkpoint_dir = f"./Master-Thesis/cpu_checkpoints/{in_name}_{out_name}"
#      35 # defining the optimizer
#      36 Optimizer = optim.Adam(
# ---> 37     model.parameters(), lr=float(config["experiments"]["train"]["lr"])
#      38 )
#      39 # Defining the training class
#      40 Training = NPTrainer(
#      41     model=model,
#      42     optimizer=Optimizer,
#    (...)
#      46     checkpoint_dir=current_checkpoint_dir,
#      47 )
#
# KeyError: 'train'

# %%
"""
Importing the necessary packages.............
"""

import os
import torch
import numpy as np
import pandas as pd
import sys
from pathlib import Path
import os
import matplotlib.pyplot as plt
from glob import glob
from tqdm import tqdm
import arrow
from datetime import datetime
from torch import optim

# from utils.config import config
from torch.utils.data import DataLoader

ROOT = Path(__file__).resolve().parents[2]  # tests/ -> project root
sys.path.insert(0, str(ROOT))
print(ROOT)

from configs.utils import config

# -------------************---------------------------------
# loading all the data loaders here we will load the final data in torch.
from Dataloader.Modis_Data_loader.PM25_data_loader_analysis import Modis_data_loader
from Dataloader.Modis_Data_loader.PM25_data_loader_analysis import PM_25_dataloader
from Dataloader.Modis_Data_loader.PM25_data_loader_analysis import (
    combine_the_data_frames,
)
from Dataloader.Modis_Data_loader.PM25_data_loader_analysis import (
    Training_data_loader,
)
from locationencoder.final_location_encoder import Geospatial_Encoder

geospatial_encoder = Geospatial_Encoder(
    config["Geo_spatial_Encoder"]["dim_in"],
    config["Geo_spatial_Encoder"]["dim_hidden"],
    config["Geo_spatial_Encoder"]["dim_out"],
    config["Geo_spatial_Encoder"]["num_layers"],
)
from Dataloader.Modis_Data_loader.torch_data_loader import Airqualitydataset
from Dataloader.Modis_Data_loader.final_loader import Final_Air_Quality_Dataset_pipeline
from src.Models.neural_process import NeuralProcess
from loss_functions import LossFunctions

Loss = LossFunctions()
from optimizer_utils import NPTrainer
from optimizer_utils import neural_process_data
from optimizer_utils import validation_function
# importing the packages for the optimization.
from Dataloader.Modis_Data_loader.torch_data_loader import Airqualitydataset
from Dataloader.Modis_Data_loader.final_loader import Final_Air_Quality_Dataset_pipeline
from src.Models.neural_process import NeuralProcess
# Out:
# /Users/pavankumar/Documents/Winter_Thesis/Coding_Learning/Master-Thesis

# %%
putput keys are different but the flag is same.
from loss_functions import LossFunctions

Loss = LossFunctions()
from optimizer_utils import NPTrainer
from optimizer_utils import neural_process_data
from optimizer_utils import validation_function
# importing the packages for the optimization.
from Dataloader.Modis_Data_loader.torch_data_loader import Airqualitydataset
from Dataloader.Modis_Data_loader.final_loader import Final_Air_Quality_Dataset_pipeline
from src.Models.neural_process import NeuralProcess

for input_key in input_type:
    if input_key == "":
        print("Please check the input keys")
        continue
    for output_key in output_type:
        if output_key == "":
            print("Please check the output keys")
            continue
        print(f" Start Training of Input: {input_key} | Output : {output_key}")
        # the current inputs and current outputs are:
        current_inputs = config["experiments"]["input_vars"][input_key]
        in_name = "_".join(current_inputs)
        current_outputs = config["experiments"]["output_vars"][output_key]
        out_name = "_".join(current_outputs)
        # We can calculate the dimensions of the inputs and putputs to decide the number of model's layers.

        x_dim = len(current_inputs)
        y_dim = len(current_outputs)
        # In this model the inputs and outputs are.
        model = NeuralProcess(x_dim, y_dim, x_dim, y_dim, 128, 128).to("cpu")
        # Defining the current check points and log directories.
        current_log_dir = f"./Master-Thesis/cpu_logs/{in_name}_{out_name}"
        current_checkpoint_dir = f"./Master-Thesis/cpu_checkpoints/{in_name}_{out_name}"
        # defining the optimizer
        Optimizer = optim.Adam(
            model.parameters(), lr=float(config["experiments"]["train"]["lr"])
        )
        # Defining the training class
        Training = NPTrainer(
            model=model,
            optimizer=Optimizer,
            loss_fn=Loss,
            device="cpu",
            log_dir=current_log_dir,
            checkpoint_dir=current_checkpoint_dir,
        )
        # To check the model's accuracy in validation data set we will use this.
        best_val_loss = float("inf")
        # these are the training data sets

        NeuralProcess_Train_data = neural_process_data(
            datasets[(input_key, output_key, "Train")]["inputs"],
            datasets[(input_key, output_key, "Train")]["outputs"],
            num_points_per_task=200,
        )

        NeuralProcess_Train_dataloader = DataLoader(
            NeuralProcess_Train_data,
            batch_size=16,
            shuffle=True,
            num_workers=0,
        )
        # Now we will define the validation datasets as well as validation dataloasers
        # NeuralProcess_Val_datasets = {}
        NeuralProcess_Val_data = neural_process_data(
            datasets[(input_key, output_key, "Val")]["inputs"],
            datasets[(input_key, output_key, "Val")]["outputs"],
            num_points_per_task=200,
        )

        # NeuralProcess_Val_dataloaders = {}
        NeuralProcess_Val_dataloader = DataLoader(
            NeuralProcess_Val_data,
            batch_size=16,
            shuffle=True,
            num_workers=0,
        )

        for epoch in range(100):
            # Train
            train_loss = Training.train_epoch(NeuralProcess_Train_dataloader, epoch)
            val_loss = validation_function(
                model=model,
                val_dataloader=NeuralProcess_Val_dataloader,
                loss=Loss,
                device="cpu",
            )
            print(
                f"Epoch:{epoch} | Val_loss:{val_loss:.4f} | Train_loss:{train_loss:.4f}"
            )
            if val_loss < best_val_loss:
                best_val_loss = val_loss
                Training.save_checkpoint(epoch)
                print(f" >>> Saved New Best Model found! ")
# Out:
#   Cell In[49], line 1
#     putput keys are different but the flag is same.
#            ^
# SyntaxError: invalid syntax

# %%
for input_key in input_type:
    if input_key == "":
        print("Please check the input keys")
        continue
    for output_key in output_type:
        if output_key == "":
            print("Please check the output keys")
            continue
        print(f" Start Training of Input: {input_key} | Output : {output_key}")
        # the current inputs and current outputs are:
        current_inputs = config["experiments"]["input_vars"][input_key]
        in_name = "_".join(current_inputs)
        current_outputs = config["experiments"]["output_vars"][output_key]
        out_name = "_".join(current_outputs)
        # We can calculate the dimensions of the inputs and putputs to decide the number of model's layers.

        x_dim = len(current_inputs)
        y_dim = len(current_outputs)
        # In this model the inputs and outputs are.
        model = NeuralProcess(x_dim, y_dim, x_dim, y_dim, 128, 128).to("cpu")
        # Defining the current check points and log directories.
        current_log_dir = f"./Master-Thesis/cpu_logs/{in_name}_{out_name}"
        current_checkpoint_dir = f"./Master-Thesis/cpu_checkpoints/{in_name}_{out_name}"
        # defining the optimizer
        Optimizer = optim.Adam(
            model.parameters(), lr=float(config["experiments"]["train"]["lr"])
        )
        # Defining the training class
        Training = NPTrainer(
            model=model,
            optimizer=Optimizer,
            loss_fn=Loss,
            device="cpu",
            log_dir=current_log_dir,
            checkpoint_dir=current_checkpoint_dir,
        )
        # To check the model's accuracy in validation data set we will use this.
        best_val_loss = float("inf")
        # these are the training data sets

        NeuralProcess_Train_data = neural_process_data(
            datasets[(input_key, output_key, "Train")]["inputs"],
            datasets[(input_key, output_key, "Train")]["outputs"],
            num_points_per_task=200,
        )

        NeuralProcess_Train_dataloader = DataLoader(
            NeuralProcess_Train_data,
            batch_size=16,
            shuffle=True,
            num_workers=0,
        )
        # Now we will define the validation datasets as well as validation dataloasers
        # NeuralProcess_Val_datasets = {}
        NeuralProcess_Val_data = neural_process_data(
            datasets[(input_key, output_key, "Val")]["inputs"],
            datasets[(input_key, output_key, "Val")]["outputs"],
            num_points_per_task=200,
        )

        # NeuralProcess_Val_dataloaders = {}
        NeuralProcess_Val_dataloader = DataLoader(
            NeuralProcess_Val_data,
            batch_size=16,
            shuffle=True,
            num_workers=0,
        )

        for epoch in range(100):
            # Train
            train_loss = Training.train_epoch(NeuralProcess_Train_dataloader, epoch)
            val_loss = validation_function(
                model=model,
                val_dataloader=NeuralProcess_Val_dataloader,
                loss=Loss,
                device="cpu",
            )
            print(
                f"Epoch:{epoch} | Val_loss:{val_loss:.4f} | Train_loss:{train_loss:.4f}"
            )
            if val_loss < best_val_loss:
                best_val_loss = val_loss
                Training.save_checkpoint(epoch)
                print(f" >>> Saved New Best Model found! ")
# Out:
#  Start Training of Input: 1 | Output : 1
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /Users/pavankumar/Documents/Winter_Thesis/Coding_Learning/Master-Thesis/src/training/trainer_latlon_AOD_PM25.py:26
#      23 current_checkpoint_dir = f"./Master-Thesis/cpu_checkpoints/{in_name}_{out_name}"
#      24 # defining the optimizer
#      25 Optimizer = optim.Adam(
# ---> 26     model.parameters(), lr=float(config["experiments"]["train"]["lr"])
#      27 )
#      28 # Defining the training class
#      29 Training = NPTrainer(
#      30     model=model,
#      31     optimizer=Optimizer,
#    (...)
#      35     checkpoint_dir=current_checkpoint_dir,
#      36 )
#
# KeyError: 'train'

# %%
config["experiments"]["train"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /Users/pavankumar/Documents/Winter_Thesis/Coding_Learning/Master-Thesis/src/training/trainer_latlon_AOD_PM25.py:1
# ----> 1 config["experiments"]["train"]
#
# KeyError: 'train'

# %%
config["train"]["lr"]
# Out:
# '1e-5'

# %%
float(config["train"]["lr"])
# Out:
# 1e-05

# %%
for input_key in input_type:
    if input_key == "":
        print("Please check the input keys")
        continue
    for output_key in output_type:
        if output_key == "":
            print("Please check the output keys")
            continue
        print(f" Start Training of Input: {input_key} | Output : {output_key}")
        # the current inputs and current outputs are:
        current_inputs = config["experiments"]["input_vars"][input_key]
        in_name = "_".join(current_inputs)
        current_outputs = config["experiments"]["output_vars"][output_key]
        out_name = "_".join(current_outputs)
        # We can calculate the dimensions of the inputs and putputs to decide the number of model's layers.

        x_dim = len(current_inputs)
        y_dim = len(current_outputs)
        # In this model the inputs and outputs are.
        model = NeuralProcess(x_dim, y_dim, x_dim, y_dim, 128, 128).to("cpu")
        # Defining the current check points and log directories.
        current_log_dir = f"./Master-Thesis/cpu_logs/{in_name}_{out_name}"
        current_checkpoint_dir = f"./Master-Thesis/cpu_checkpoints/{in_name}_{out_name}"
        # defining the optimizer
        Optimizer = optim.Adam(
            model.parameters(), lr=float(config["train"]["lr"])
        )
        # Defining the training class
        Training = NPTrainer(
            model=model,
            optimizer=Optimizer,
            loss_fn=Loss,
            device="cpu",
            log_dir=current_log_dir,
            checkpoint_dir=current_checkpoint_dir,
        )
        # To check the model's accuracy in validation data set we will use this.
        best_val_loss = float("inf")
        # these are the training data sets

        NeuralProcess_Train_data = neural_process_data(
            datasets[(input_key, output_key, "Train")]["inputs"],
            datasets[(input_key, output_key, "Train")]["outputs"],
            num_points_per_task=200,
        )

        NeuralProcess_Train_dataloader = DataLoader(
            NeuralProcess_Train_data,
            batch_size=16,
            shuffle=True,
            num_workers=0,
        )
        # Now we will define the validation datasets as well as validation dataloasers
        # NeuralProcess_Val_datasets = {}
        NeuralProcess_Val_data = neural_process_data(
            datasets[(input_key, output_key, "Val")]["inputs"],
            datasets[(input_key, output_key, "Val")]["outputs"],
            num_points_per_task=200,
        )

        # NeuralProcess_Val_dataloaders = {}
        NeuralProcess_Val_dataloader = DataLoader(
            NeuralProcess_Val_data,
            batch_size=16,
            shuffle=True,
            num_workers=0,
        )

        for epoch in range(100):
            # Train
            train_loss = Training.train_epoch(NeuralProcess_Train_dataloader, epoch)
            val_loss = validation_function(
                model=model,
                val_dataloader=NeuralProcess_Val_dataloader,
                loss=Loss,
                device="cpu",
            )
            print(
                f"Epoch:{epoch} | Val_loss:{val_loss:.4f} | Train_loss:{train_loss:.4f}"
            )
            if val_loss < best_val_loss:
                best_val_loss = val_loss
                Training.save_checkpoint(epoch)
                print(f" >>> Saved New Best Model found! ")
# Out:
#  Start Training of Input: 1 | Output : 1
# Epoch 0:   0%|          | 0/770 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# File /Users/pavankumar/Documents/Winter_Thesis/Coding_Learning/Master-Thesis/src/training/trainer_latlon_AOD_PM25.py:71
#      62 NeuralProcess_Val_dataloader = DataLoader(
#      63     NeuralProcess_Val_data,
#      64     batch_size=16,
#      65     shuffle=True,
#      66     num_workers=0,
#      67 )
#      69 for epoch in range(100):
#      70     # Train
# ---> 71     train_loss = Training.train_epoch(NeuralProcess_Train_dataloader, epoch)
#      72     val_loss = validation_function(
#      73         model=model,
#      74         val_dataloader=NeuralProcess_Val_dataloader,
#      75         loss=Loss,
#      76         device="cpu",
#      77     )
#      78     print(
#      79         f"Epoch:{epoch} | Val_loss:{val_loss:.4f} | Train_loss:{train_loss:.4f}"
#      80     )
#
# File ~/Documents/Winter_Thesis/Coding_Learning/Master-Thesis/src/training/optimizer_utils.py:142, in NPTrainer.train_epoch(self, dataloader, epoch_idx)
#     135 self.optimizer.zero_grad()
#     137 # --- FORWARD PASS ---
#     138
#     139 # model inputs -->
#     140
#     141 # Returns: (mu_y, var_y, mu_zc, log_var_zc, mu_zct, log_var_zct)
# --> 142 outs = self.model(xc, yc, xt, yt)
#     143 mu_y, var_y, mu_zc, log_var_zc, mu_zct, log_var_zct = outs
#     145 # self, mu_y, var_y, y_target, mu_zc, mu_zct, log_var_zc, log_var_zct
#     146 # --- LOSS CALCULATION ---
#
# File ~/Documents/Winter_Thesis/Coding_Learning/Master-Thesis/.venvn/lib/python3.9/site-packages/torch/nn/modules/module.py:1501, in Module._call_impl(self, *args, **kwargs)
#    1496 # If we don't have any hooks, we want to skip the rest of the logic in
#    1497 # this function, and just call forward.
#    1498 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1499         or _global_backward_pre_hooks or _global_backward_hooks
#    1500         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501     return forward_call(*args, **kwargs)
#    1502 # Do not call functions when jit is used
#    1503 full_backward_hooks, non_full_backward_hooks = [], []
#
# File ~/Documents/Winter_Thesis/Coding_Learning/Master-Thesis/src/Models/neural_process.py:51, in NeuralProcess.forward(self, x_context, y_context, x_target, y_target)
#      49 def forward(self, x_context, y_context, x_target, y_target):
#      50     # Step 1: Pass the context points through the encoder to get r
# ---> 51     rc = self.encoder(x_context, y_context)
#      52     rt = self.encoder(x_target, y_target)
#      53     # here we are
#
# File ~/Documents/Winter_Thesis/Coding_Learning/Master-Thesis/.venvn/lib/python3.9/site-packages/torch/nn/modules/module.py:1501, in Module._call_impl(self, *args, **kwargs)
#    1496 # If we don't have any hooks, we want to skip the rest of the logic in
#    1497 # this function, and just call forward.
#    1498 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1499         or _global_backward_pre_hooks or _global_backward_hooks
#    1500         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501     return forward_call(*args, **kwargs)
#    1502 # Do not call functions when jit is used
#    1503 full_backward_hooks, non_full_backward_hooks = [], []
#
# File ~/Documents/Winter_Thesis/Coding_Learning/Master-Thesis/src/Models/Encoder.py:26, in Encoder.forward(self, x, y)
#      24 combined_input = torch.cat([x, y], dim=-1)
#      25 # Now we will pass this combined input through a linear layer to reduce its dimension.
# ---> 26 r_i = self.net(combined_input)
#      27 r = torch.mean(r_i, dim=1)
#      28 # vector of dim = hidden dimension
#
# File ~/Documents/Winter_Thesis/Coding_Learning/Master-Thesis/.venvn/lib/python3.9/site-packages/torch/nn/modules/module.py:1501, in Module._call_impl(self, *args, **kwargs)
#    1496 # If we don't have any hooks, we want to skip the rest of the logic in
#    1497 # this function, and just call forward.
#    1498 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1499         or _global_backward_pre_hooks or _global_backward_hooks
#    1500         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501     return forward_call(*args, **kwargs)
#    1502 # Do not call functions when jit is used
#    1503 full_backward_hooks, non_full_backward_hooks = [], []
#
# File ~/Documents/Winter_Thesis/Coding_Learning/Master-Thesis/.venvn/lib/python3.9/site-packages/torch/nn/modules/container.py:217, in Sequential.forward(self, input)
#     215 def forward(self, input):
#     216     for module in self:
# --> 217         input = module(input)
#     218     return input
#
# File ~/Documents/Winter_Thesis/Coding_Learning/Master-Thesis/.venvn/lib/python3.9/site-packages/torch/nn/modules/module.py:1501, in Module._call_impl(self, *args, **kwargs)
#    1496 # If we don't have any hooks, we want to skip the rest of the logic in
#    1497 # this function, and just call forward.
#    1498 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1499         or _global_backward_pre_hooks or _global_backward_hooks
#    1500         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501     return forward_call(*args, **kwargs)
#    1502 # Do not call functions when jit is used
#    1503 full_backward_hooks, non_full_backward_hooks = [], []
#
# File ~/Documents/Winter_Thesis/Coding_Learning/Master-Thesis/.venvn/lib/python3.9/site-packages/torch/nn/modules/linear.py:114, in Linear.forward(self, input)
#     113 def forward(self, input: Tensor) -> Tensor:
# --> 114     return F.linear(input, self.weight, self.bias)
#
# RuntimeError: mat1 and mat2 shapes cannot be multiplied (448x130 and 6x128)

# %%
len([1`,2`])
# Out:
#   Cell In[55], line 1
#     len([1`,2`])
#           ^
# SyntaxError: invalid syntax

# %%
len([1,2`])
# Out:
#   Cell In[56], line 1
#     len([1,2`])
#             ^
# SyntaxError: invalid syntax

# %%
len([1,2])
# Out:
# 2

# %%
for input_key in input_type:
    if input_key == "":
        print("Please check the input keys")
        continue
    for output_key in output_type:
        if output_key == "":
            print("Please check the output keys")
            continue
        print(f" Start Training of Input: {input_key} | Output : {output_key}")
        # the current inputs and current outputs are:
        current_inputs = config["experiments"]["input_vars"][input_key]
        in_name = "_".join(current_inputs)
        current_outputs = config["experiments"]["output_vars"][output_key]
        out_name = "_".join(current_outputs)
        # We can calculate the dimensions of the inputs and putputs to decide the number of model's layers.

        x_dim = len(current_inputs)
        y_dim = len(current_outputs)
        # In this model the inputs and outputs are.
        model = NeuralProcess(x_dim, y_dim, x_dim, y_dim, 128, 128).to("cpu")
        # Defining the current check points and log directories.
        current_log_dir = f"./Master-Thesis/cpu_logs/{in_name}_{out_name}"
        current_checkpoint_dir = f"./Master-Thesis/cpu_checkpoints/{in_name}_{out_name}"
        # defining the optimizer
        Optimizer = optim.Adam(model.parameters(), lr=float(config["train"]["lr"]))
        # Defining the training class
        Training = NPTrainer(
            model=model,
            optimizer=Optimizer,
            loss_fn=Loss,
            device="cpu",
            log_dir=current_log_dir,
            checkpoint_dir=current_checkpoint_dir,
        )
        # To check the model's accuracy in validation data set we will use this.
        best_val_loss = float("inf")
        # these are the training data sets

        NeuralProcess_Train_data = neural_process_data(
            datasets[(input_key, output_key, "Train")]["inputs"],
            datasets[(input_key, output_key, "Train")]["outputs"],
            num_points_per_task=200,
        )

        NeuralProcess_Train_dataloader = DataLoader(
            NeuralProcess_Train_data,
            batch_size=16,
            shuffle=True,
            num_workers=0,
        )
        # Now we will define the validation datasets as well as validation dataloasers
        # NeuralProcess_Val_datasets = {}
        NeuralProcess_Val_data = neural_process_data(
            datasets[(input_key, output_key, "Val")]["inputs"],
            datasets[(input_key, output_key, "Val")]["outputs"],
            num_points_per_task=200,
        )

        # NeuralProcess_Val_dataloaders = {}
        NeuralProcess_Val_dataloader = DataLoader(
            NeuralProcess_Val_data,
            batch_size=16,
            shuffle=False,
            num_workers=0,
        )

        for epoch in range(100):
            # Train
            train_loss = Training.train_epoch(NeuralProcess_Train_dataloader, epoch)
            val_loss = validation_function(
                model=model,
                val_dataloader=NeuralProcess_Val_dataloader,
                loss=Loss,
                device="cpu",
            )
            print(
                f"Epoch:{epoch} | Val_loss:{val_loss:.4f} | Train_loss:{train_loss:.4f}"
            )
            if val_loss < best_val_loss:
                best_val_loss = val_loss
                Training.save_checkpoint(epoch)
                print(f" >>> Saved New Best Model found! ")
# Out:
#  Start Training of Input: 1 | Output : 1
# Epoch 0:   0%|          | 0/770 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# File /Users/pavankumar/Documents/Winter_Thesis/Coding_Learning/Master-Thesis/src/training/trainer_latlon_AOD_PM25.py:69
#      60 NeuralProcess_Val_dataloader = DataLoader(
#      61     NeuralProcess_Val_data,
#      62     batch_size=16,
#      63     shuffle=False,
#      64     num_workers=0,
#      65 )
#      67 for epoch in range(100):
#      68     # Train
# ---> 69     train_loss = Training.train_epoch(NeuralProcess_Train_dataloader, epoch)
#      70     val_loss = validation_function(
#      71         model=model,
#      72         val_dataloader=NeuralProcess_Val_dataloader,
#      73         loss=Loss,
#      74         device="cpu",
#      75     )
#      76     print(
#      77         f"Epoch:{epoch} | Val_loss:{val_loss:.4f} | Train_loss:{train_loss:.4f}"
#      78     )
#
# File ~/Documents/Winter_Thesis/Coding_Learning/Master-Thesis/src/training/optimizer_utils.py:142, in NPTrainer.train_epoch(self, dataloader, epoch_idx)
#     135 self.optimizer.zero_grad()
#     137 # --- FORWARD PASS ---
#     138
#     139 # model inputs -->
#     140
#     141 # Returns: (mu_y, var_y, mu_zc, log_var_zc, mu_zct, log_var_zct)
# --> 142 outs = self.model(xc, yc, xt, yt)
#     143 mu_y, var_y, mu_zc, log_var_zc, mu_zct, log_var_zct = outs
#     145 # self, mu_y, var_y, y_target, mu_zc, mu_zct, log_var_zc, log_var_zct
#     146 # --- LOSS CALCULATION ---
#
# File ~/Documents/Winter_Thesis/Coding_Learning/Master-Thesis/.venvn/lib/python3.9/site-packages/torch/nn/modules/module.py:1501, in Module._call_impl(self, *args, **kwargs)
#    1496 # If we don't have any hooks, we want to skip the rest of the logic in
#    1497 # this function, and just call forward.
#    1498 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1499         or _global_backward_pre_hooks or _global_backward_hooks
#    1500         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501     return forward_call(*args, **kwargs)
#    1502 # Do not call functions when jit is used
#    1503 full_backward_hooks, non_full_backward_hooks = [], []
#
# File ~/Documents/Winter_Thesis/Coding_Learning/Master-Thesis/src/Models/neural_process.py:51, in NeuralProcess.forward(self, x_context, y_context, x_target, y_target)
#      49 def forward(self, x_context, y_context, x_target, y_target):
#      50     # Step 1: Pass the context points through the encoder to get r
# ---> 51     rc = self.encoder(x_context, y_context)
#      52     rt = self.encoder(x_target, y_target)
#      53     # here we are
#
# File ~/Documents/Winter_Thesis/Coding_Learning/Master-Thesis/.venvn/lib/python3.9/site-packages/torch/nn/modules/module.py:1501, in Module._call_impl(self, *args, **kwargs)
#    1496 # If we don't have any hooks, we want to skip the rest of the logic in
#    1497 # this function, and just call forward.
#    1498 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1499         or _global_backward_pre_hooks or _global_backward_hooks
#    1500         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501     return forward_call(*args, **kwargs)
#    1502 # Do not call functions when jit is used
#    1503 full_backward_hooks, non_full_backward_hooks = [], []
#
# File ~/Documents/Winter_Thesis/Coding_Learning/Master-Thesis/src/Models/Encoder.py:26, in Encoder.forward(self, x, y)
#      24 combined_input = torch.cat([x, y], dim=-1)
#      25 # Now we will pass this combined input through a linear layer to reduce its dimension.
# ---> 26 r_i = self.net(combined_input)
#      27 r = torch.mean(r_i, dim=1)
#      28 # vector of dim = hidden dimension
#
# File ~/Documents/Winter_Thesis/Coding_Learning/Master-Thesis/.venvn/lib/python3.9/site-packages/torch/nn/modules/module.py:1501, in Module._call_impl(self, *args, **kwargs)
#    1496 # If we don't have any hooks, we want to skip the rest of the logic in
#    1497 # this function, and just call forward.
#    1498 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1499         or _global_backward_pre_hooks or _global_backward_hooks
#    1500         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501     return forward_call(*args, **kwargs)
#    1502 # Do not call functions when jit is used
#    1503 full_backward_hooks, non_full_backward_hooks = [], []
#
# File ~/Documents/Winter_Thesis/Coding_Learning/Master-Thesis/.venvn/lib/python3.9/site-packages/torch/nn/modules/container.py:217, in Sequential.forward(self, input)
#     215 def forward(self, input):
#     216     for module in self:
# --> 217         input = module(input)
#     218     return input
#
# File ~/Documents/Winter_Thesis/Coding_Learning/Master-Thesis/.venvn/lib/python3.9/site-packages/torch/nn/modules/module.py:1501, in Module._call_impl(self, *args, **kwargs)
#    1496 # If we don't have any hooks, we want to skip the rest of the logic in
#    1497 # this function, and just call forward.
#    1498 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1499         or _global_backward_pre_hooks or _global_backward_hooks
#    1500         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501     return forward_call(*args, **kwargs)
#    1502 # Do not call functions when jit is used
#    1503 full_backward_hooks, non_full_backward_hooks = [], []
#
# File ~/Documents/Winter_Thesis/Coding_Learning/Master-Thesis/.venvn/lib/python3.9/site-packages/torch/nn/modules/linear.py:114, in Linear.forward(self, input)
#     113 def forward(self, input: Tensor) -> Tensor:
# --> 114     return F.linear(input, self.weight, self.bias)
#
# RuntimeError: mat1 and mat2 shapes cannot be multiplied (640x130 and 6x128)

# %%
datasets[(1, 1, "Train")]["outputs"]
# Out:
# tensor([[ 0.9654,  1.2592],
#         [-0.7220, -0.0482],
#         [-0.3033, -0.1231],
#         ...,
#         [-0.5858, -0.2545],
#         [ 0.4649, -0.3712],
#         [-0.4296,  0.0278]])

# %%
datasets[(1, 1, "Train")]["inputs"].shape
# Out:
# torch.Size([12307, 128])

# %%
datasets[(1, 1, "Train")]["outputs"].shape
# Out:
# torch.Size([12307, 2])

# %%
len(config["experiments"]["input_vars"][1])
len(config["experiments"]["output_vars"][1])
# Out:
# 2

# %%
len(config["experiments"]["input_vars"][1])
# Out:
# 4

# %%
x_dim = len(datasets[(input_key,output_key, "Train")])

# %%
len(datasets[(input_key,output_key, "Train")])
# Out:
# 2

# %%
len(datasets[(1,1, "Train")])
# Out:
# 2

# %%
datasets[(1,1, "Train")]
# Out:
# {'inputs': tensor([[ 0.2875, -1.3133,  0.3943,  ...,  1.5133,  0.9654,  1.2592],
#          [ 0.2875, -1.3133,  0.3943,  ...,  1.5133, -0.7220, -0.0482],
#          [ 0.2875, -1.3133,  0.3943,  ...,  1.5133, -0.3033, -0.1231],
#          ...,
#          [ 0.2884, -1.3129,  0.3950,  ...,  1.5133, -0.5858, -0.2545],
#          [ 0.2884, -1.3129,  0.3950,  ...,  1.5133,  0.4649, -0.3712],
#          [ 0.2884, -1.3129,  0.3950,  ...,  1.5133, -0.4296,  0.0278]],
#         grad_fn=<CatBackward0>),
#  'outputs': tensor([[ 0.9654,  1.2592],
#          [-0.7220, -0.0482],
#          [-0.3033, -0.1231],
#          ...,
#          [-0.5858, -0.2545],
#          [ 0.4649, -0.3712],
#          [-0.4296,  0.0278]])}

# %%
datasets[(1,1, "Train")]["inputs"]
# Out:
# tensor([[ 0.2875, -1.3133,  0.3943,  ...,  1.5133,  0.9654,  1.2592],
#         [ 0.2875, -1.3133,  0.3943,  ...,  1.5133, -0.7220, -0.0482],
#         [ 0.2875, -1.3133,  0.3943,  ...,  1.5133, -0.3033, -0.1231],
#         ...,
#         [ 0.2884, -1.3129,  0.3950,  ...,  1.5133, -0.5858, -0.2545],
#         [ 0.2884, -1.3129,  0.3950,  ...,  1.5133,  0.4649, -0.3712],
#         [ 0.2884, -1.3129,  0.3950,  ...,  1.5133, -0.4296,  0.0278]],
#        grad_fn=<CatBackward0>)

# %%
len(datasets[(1,1, "Train")]["inputs"])
# Out:
# 12307

# %%
len(datasets[(1,1, "Train")]["inputs"][0])
# Out:
# 128

# %%
len(datasets[(1,1,"Train")]["outputs"])
# Out:
# 12307

# %%
len(datasets[(1,1,"Train")]["outputs"][0])
# Out:
# 2

# %%
for input_key in input_type:
    if input_key == "":
        print("Please check the input keys")
        continue
    for output_key in output_type:
        if output_key == "":
            print("Please check the output keys")
            continue
        print(f" Start Training of Input: {input_key} | Output : {output_key}")
        # the current inputs and current outputs are:
        current_inputs = config["experiments"]["input_vars"][input_key]
        in_name = "_".join(current_inputs)
        current_outputs = config["experiments"]["output_vars"][output_key]
        out_name = "_".join(current_outputs)
        # We can calculate the dimensions of the inputs and putputs to decide the number of model's layers.

        x_dim = len(datasets[(input_key,output_key, "Train")]["inputs"][0])
        y_dim = len(datasets[(1,1,"Train")]["outputs"][0])
        # In this model the inputs and outputs are.
        model = NeuralProcess(x_dim, y_dim, x_dim, y_dim, 128, 128).to("cpu")
        # Defining the current check points and log directories.
        current_log_dir = f"./Master-Thesis/cpu_logs/{in_name}_{out_name}"
        current_checkpoint_dir = f"./Master-Thesis/cpu_checkpoints/{in_name}_{out_name}"
        # defining the optimizer
        Optimizer = optim.Adam(model.parameters(), lr=float(config["train"]["lr"]))
        # Defining the training class
        Training = NPTrainer(
            model=model,
            optimizer=Optimizer,
            loss_fn=Loss,
            device="cpu",
            log_dir=current_log_dir,
            checkpoint_dir=current_checkpoint_dir,
        )
        # To check the model's accuracy in validation data set we will use this.
        best_val_loss = float("inf")
        # these are the training data sets

        NeuralProcess_Train_data = neural_process_data(
            datasets[(input_key, output_key, "Train")]["inputs"],
            datasets[(input_key, output_key, "Train")]["outputs"],
            num_points_per_task=200,
        )

        NeuralProcess_Train_dataloader = DataLoader(
            NeuralProcess_Train_data,
            batch_size=16,
            shuffle=True,
            num_workers=0,
        )
        # Now we will define the validation datasets as well as validation dataloasers
        # NeuralProcess_Val_datasets = {}
        NeuralProcess_Val_data = neural_process_data(
            datasets[(input_key, output_key, "Val")]["inputs"],
            datasets[(input_key, output_key, "Val")]["outputs"],
            num_points_per_task=200,
        )

        # NeuralProcess_Val_dataloaders = {}
        NeuralProcess_Val_dataloader = DataLoader(
            NeuralProcess_Val_data,
            batch_size=16,
            shuffle=False,
            num_workers=0,
        )
        

        for epoch in range(100):
            # Train
            train_loss = Training.train_epoch(NeuralProcess_Train_dataloader, epoch)
            val_loss = validation_function(
                model=model,
                val_dataloader=NeuralProcess_Val_dataloader,
                loss=Loss,
                device="cpu",
            )
            print(
                f"Epoch:{epoch} | Val_loss:{val_loss:.4f} | Train_loss:{train_loss:.4f}"
            )
            if val_loss < best_val_loss:
                best_val_loss = val_loss
                Training.save_checkpoint(epoch)
                print(f" >>> Saved New Best Model found! ")
# Out:
#  Start Training of Input: 1 | Output : 1
# Epoch 0: 100%|██████████| 770/770 [00:14<00:00, 51.41it/s, Loss=510.86]
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File /Users/pavankumar/Documents/Winter_Thesis/Coding_Learning/Master-Thesis/src/training/trainer_latlon_AOD_PM25.py:71
#      68 for epoch in range(100):
#      69     # Train
#      70     train_loss = Training.train_epoch(NeuralProcess_Train_dataloader, epoch)
# ---> 71     val_loss = validation_function(
#      72         model=model,
#      73         val_dataloader=NeuralProcess_Val_dataloader,
#      74         loss=Loss,
#      75         device="cpu",
#      76     )
#      77     print(
#      78         f"Epoch:{epoch} | Val_loss:{val_loss:.4f} | Train_loss:{train_loss:.4f}"
#      79     )
#      80     if val_loss < best_val_loss:
#
# TypeError: validation_function() got an unexpected keyword argument 'loss'

# %%
for input_key in input_type:
    if input_key == "":
        print("Please check the input keys")
        continue
    for output_key in output_type:
        if output_key == "":
            print("Please check the output keys")
            continue
        print(f" Start Training of Input: {input_key} | Output : {output_key}")
        # the current inputs and current outputs are:
        current_inputs = config["experiments"]["input_vars"][input_key]
        in_name = "_".join(current_inputs)
        current_outputs = config["experiments"]["output_vars"][output_key]
        out_name = "_".join(current_outputs)
        # We can calculate the dimensions of the inputs and putputs to decide the number of model's layers.

        x_dim = len(datasets[(input_key,output_key, "Train")]["inputs"][0])
        y_dim = len(datasets[(1,1,"Train")]["outputs"][0])
        # In this model the inputs and outputs are.
        model = NeuralProcess(x_dim, y_dim, x_dim, y_dim, 128, 128).to("cpu")
        # Defining the current check points and log directories.
        current_log_dir = f"./Master-Thesis/cpu_logs/{in_name}_{out_name}"
        current_checkpoint_dir = f"./Master-Thesis/cpu_checkpoints/{in_name}_{out_name}"
        # defining the optimizer
        Optimizer = optim.Adam(model.parameters(), lr=float(config["train"]["lr"]))
        # Defining the training class
        Training = NPTrainer(
            model=model,
            optimizer=Optimizer,
            loss_fn=Loss,
            device="cpu",
            log_dir=current_log_dir,
            checkpoint_dir=current_checkpoint_dir,
        )
        # To check the model's accuracy in validation data set we will use this.
        best_val_loss = float("inf")
        # these are the training data sets

        NeuralProcess_Train_data = neural_process_data(
            datasets[(input_key, output_key, "Train")]["inputs"],
            datasets[(input_key, output_key, "Train")]["outputs"],
            num_points_per_task=200,
        )

        NeuralProcess_Train_dataloader = DataLoader(
            NeuralProcess_Train_data,
            batch_size=16,
            shuffle=True,
            num_workers=0,
        )
        # Now we will define the validation datasets as well as validation dataloasers
        # NeuralProcess_Val_datasets = {}
        NeuralProcess_Val_data = neural_process_data(
            datasets[(input_key, output_key, "Val")]["inputs"],
            datasets[(input_key, output_key, "Val")]["outputs"],
            num_points_per_task=200,
        )

        # NeuralProcess_Val_dataloaders = {}
        NeuralProcess_Val_dataloader = DataLoader(
            NeuralProcess_Val_data,
            batch_size=16,
            shuffle=False,
            num_workers=0,
        )
        

        for epoch in range(100):
            # Train
            train_loss = Training.train_epoch(NeuralProcess_Train_dataloader, epoch)
            val_loss = validation_function(
                model=model,
                val_dataloader=NeuralProcess_Val_dataloader,
                loss_fn=Loss,
                device="cpu",
            )
            print(
                f"Epoch:{epoch} | Val_loss:{val_loss:.4f} | Train_loss:{train_loss:.4f}"
            )
            if val_loss < best_val_loss:
                best_val_loss = val_loss
                Training.save_checkpoint(epoch)
                print(f" >>> Saved New Best Model found! ")
# Out:
#  Start Training of Input: 1 | Output : 1
# Epoch 0: 100%|██████████| 770/770 [00:14<00:00, 54.57it/s, Loss=510.46]
# Epoch:0 | Val_loss:512.1335 | Train_loss:544.3824
# Checkpoint saved: ./Master-Thesis/cpu_checkpoints/latitude_longitude_AOD_PM2.5_AOD_PM2.5/model_epoch_0.pth
#  >>> Saved New Best Model found!
# Epoch 1: 100%|██████████| 770/770 [00:14<00:00, 54.02it/s, Loss=404.80]
# Epoch:1 | Val_loss:416.0558 | Train_loss:453.2867
# Checkpoint saved: ./Master-Thesis/cpu_checkpoints/latitude_longitude_AOD_PM2.5_AOD_PM2.5/model_epoch_1.pth
#  >>> Saved New Best Model found!
# Epoch 2: 100%|██████████| 770/770 [00:13<00:00, 55.40it/s, Loss=240.10]
# Epoch:2 | Val_loss:283.6771 | Train_loss:327.1481
# Checkpoint saved: ./Master-Thesis/cpu_checkpoints/latitude_longitude_AOD_PM2.5_AOD_PM2.5/model_epoch_2.pth
#  >>> Saved New Best Model found!
# Epoch 3: 100%|██████████| 770/770 [00:13<00:00, 57.37it/s, Loss=5.44]
# Epoch:3 | Val_loss:68.4017 | Train_loss:137.4494
# Checkpoint saved: ./Master-Thesis/cpu_checkpoints/latitude_longitude_AOD_PM2.5_AOD_PM2.5/model_epoch_3.pth
#  >>> Saved New Best Model found!
# Epoch 4: 100%|██████████| 770/770 [00:14<00:00, 54.58it/s, Loss=-381.31]
# Epoch:4 | Val_loss:-282.1249 | Train_loss:-163.8791
# Checkpoint saved: ./Master-Thesis/cpu_checkpoints/latitude_longitude_AOD_PM2.5_AOD_PM2.5/model_epoch_4.pth
#  >>> Saved New Best Model found!
# Epoch 5: 100%|██████████| 770/770 [00:13<00:00, 56.34it/s, Loss=-512.73]
# Epoch:5 | Val_loss:-395.1308 | Train_loss:-443.6119
# Checkpoint saved: ./Master-Thesis/cpu_checkpoints/latitude_longitude_AOD_PM2.5_AOD_PM2.5/model_epoch_5.pth
#  >>> Saved New Best Model found!
# Epoch 6: 100%|██████████| 770/770 [00:13<00:00, 55.67it/s, Loss=-591.49]
# Epoch:6 | Val_loss:-422.7802 | Train_loss:-499.7424
# Checkpoint saved: ./Master-Thesis/cpu_checkpoints/latitude_longitude_AOD_PM2.5_AOD_PM2.5/model_epoch_6.pth
#  >>> Saved New Best Model found!
# Epoch 7: 100%|██████████| 770/770 [00:13<00:00, 55.34it/s, Loss=-636.07]
# Epoch:7 | Val_loss:-472.4615 | Train_loss:-556.7548
# Checkpoint saved: ./Master-Thesis/cpu_checkpoints/latitude_longitude_AOD_PM2.5_AOD_PM2.5/model_epoch_7.pth
#  >>> Saved New Best Model found!
# Epoch 8: 100%|██████████| 770/770 [00:14<00:00, 54.41it/s, Loss=-645.64]
# Epoch:8 | Val_loss:-580.7077 | Train_loss:-432.3160
# Checkpoint saved: ./Master-Thesis/cpu_checkpoints/latitude_longitude_AOD_PM2.5_AOD_PM2.5/model_epoch_8.pth
#  >>> Saved New Best Model found!
# Epoch 9: 100%|██████████| 770/770 [00:14<00:00, 54.34it/s, Loss=-683.09]
# Epoch:9 | Val_loss:-611.2781 | Train_loss:-419.4564
# Checkpoint saved: ./Master-Thesis/cpu_checkpoints/latitude_longitude_AOD_PM2.5_AOD_PM2.5/model_epoch_9.pth
#  >>> Saved New Best Model found!
# Epoch 10: 100%|██████████| 770/770 [00:14<00:00, 54.44it/s, Loss=-644.07]
# Epoch:10 | Val_loss:-442.0055 | Train_loss:-482.3117
# Epoch 11: 100%|██████████| 770/770 [00:14<00:00, 53.94it/s, Loss=-215.98]
# Epoch:11 | Val_loss:-286.8561 | Train_loss:-468.6688
# Epoch 12: 100%|██████████| 770/770 [00:14<00:00, 54.01it/s, Loss=-608.97]
# Epoch:12 | Val_loss:-529.8653 | Train_loss:-498.4017
# Epoch 13: 100%|██████████| 770/770 [00:13<00:00, 56.58it/s, Loss=-383.66]
# Epoch:13 | Val_loss:-417.6765 | Train_loss:-520.8848
# Epoch 14: 100%|██████████| 770/770 [00:13<00:00, 55.94it/s, Loss=-609.81]
# Epoch:14 | Val_loss:-558.3783 | Train_loss:-541.2521
# Epoch 15: 100%|██████████| 770/770 [00:13<00:00, 56.35it/s, Loss=-512.76]
# Epoch:15 | Val_loss:-533.3727 | Train_loss:-563.2453
# Epoch 16: 100%|██████████| 770/770 [00:13<00:00, 56.51it/s, Loss=-793.14]
# Epoch:16 | Val_loss:-562.2308 | Train_loss:-603.4915
# Epoch 17: 100%|██████████| 770/770 [00:14<00:00, 54.42it/s, Loss=-684.98]
# Epoch:17 | Val_loss:-694.4539 | Train_loss:-720.1369
# Checkpoint saved: ./Master-Thesis/cpu_checkpoints/latitude_longitude_AOD_PM2.5_AOD_PM2.5/model_epoch_17.pth
#  >>> Saved New Best Model found!
# Epoch 18: 100%|██████████| 770/770 [00:13<00:00, 56.36it/s, Loss=-1252.14]
# Epoch:18 | Val_loss:-1228.5739 | Train_loss:-1048.6296
# Checkpoint saved: ./Master-Thesis/cpu_checkpoints/latitude_longitude_AOD_PM2.5_AOD_PM2.5/model_epoch_18.pth
#  >>> Saved New Best Model found!
# Epoch 19: 100%|██████████| 770/770 [00:13<00:00, 55.05it/s, Loss=-1180.11]
# Epoch:19 | Val_loss:-1343.2813 | Train_loss:-1218.4949
# Checkpoint saved: ./Master-Thesis/cpu_checkpoints/latitude_longitude_AOD_PM2.5_AOD_PM2.5/model_epoch_19.pth
#  >>> Saved New Best Model found!
# Epoch 20: 100%|██████████| 770/770 [00:15<00:00, 49.56it/s, Loss=-1084.62]
# Epoch:20 | Val_loss:-1405.4857 | Train_loss:-1258.0851
# Checkpoint saved: ./Master-Thesis/cpu_checkpoints/latitude_longitude_AOD_PM2.5_AOD_PM2.5/model_epoch_20.pth
#  >>> Saved New Best Model found!
# Epoch 21: 100%|██████████| 770/770 [00:13<00:00, 55.53it/s, Loss=-1548.45]
# Epoch:21 | Val_loss:-810.2968 | Train_loss:-1262.3772
# Epoch 22: 100%|██████████| 770/770 [00:13<00:00, 55.29it/s, Loss=-1470.56]
# Epoch:22 | Val_loss:-1280.1336 | Train_loss:-1277.7000
# Epoch 23: 100%|██████████| 770/770 [00:13<00:00, 56.67it/s, Loss=-618.75]
# Epoch:23 | Val_loss:-1411.7853 | Train_loss:-1214.9037
# Checkpoint saved: ./Master-Thesis/cpu_checkpoints/latitude_longitude_AOD_PM2.5_AOD_PM2.5/model_epoch_23.pth
#  >>> Saved New Best Model found!
# Epoch 24: 100%|██████████| 770/770 [00:13<00:00, 56.12it/s, Loss=-1525.66]
# Epoch:24 | Val_loss:-1504.6096 | Train_loss:-1319.8832
# Checkpoint saved: ./Master-Thesis/cpu_checkpoints/latitude_longitude_AOD_PM2.5_AOD_PM2.5/model_epoch_24.pth
#  >>> Saved New Best Model found!
# Epoch 25: 100%|██████████| 770/770 [00:14<00:00, 54.69it/s, Loss=-1233.13]
# Epoch:25 | Val_loss:-921.3020 | Train_loss:-1120.2184
# Epoch 26: 100%|██████████| 770/770 [00:13<00:00, 56.59it/s, Loss=-1381.36]
# Epoch:26 | Val_loss:-1564.6952 | Train_loss:-1360.2444
# Checkpoint saved: ./Master-Thesis/cpu_checkpoints/latitude_longitude_AOD_PM2.5_AOD_PM2.5/model_epoch_26.pth
#  >>> Saved New Best Model found!
# Epoch 27: 100%|██████████| 770/770 [00:13<00:00, 55.05it/s, Loss=-1254.66]
# Epoch:27 | Val_loss:-846.1109 | Train_loss:-1143.5331
# Epoch 28: 100%|██████████| 770/770 [00:13<00:00, 57.18it/s, Loss=-1489.21]
# Epoch:28 | Val_loss:-1522.8217 | Train_loss:-1482.2667
# Epoch 29: 100%|██████████| 770/770 [00:14<00:00, 53.74it/s, Loss=-1496.68]
# Epoch:29 | Val_loss:-1267.0186 | Train_loss:-1351.1211
# Epoch 30: 100%|██████████| 770/770 [00:14<00:00, 52.94it/s, Loss=-1268.78]
# Epoch:30 | Val_loss:-1504.4364 | Train_loss:-1120.7626
# Epoch 31: 100%|██████████| 770/770 [00:13<00:00, 55.58it/s, Loss=-1253.53]
# Epoch:31 | Val_loss:-1510.4970 | Train_loss:-1288.2529
# Epoch 32:  18%|█▊        | 142/770 [00:02<00:12, 50.12it/s, Loss=-1583.03]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# File /Users/pavankumar/Documents/Winter_Thesis/Coding_Learning/Master-Thesis/src/training/trainer_latlon_AOD_PM25.py:70
#      60 NeuralProcess_Val_dataloader = DataLoader(
#      61     NeuralProcess_Val_data,
#      62     batch_size=16,
#      63     shuffle=False,
#      64     num_workers=0,
#      65 )
#      68 for epoch in range(100):
#      69     # Train
# ---> 70     train_loss = Training.train_epoch(NeuralProcess_Train_dataloader, epoch)
#      71     val_loss = validation_function(
#      72         model=model,
#      73         val_dataloader=NeuralProcess_Val_dataloader,
#      74         loss_fn=Loss,
#      75         device="cpu",
#      76     )
#      77     print(
#      78         f"Epoch:{epoch} | Val_loss:{val_loss:.4f} | Train_loss:{train_loss:.4f}"
#      79     )
#
# File ~/Documents/Winter_Thesis/Coding_Learning/Master-Thesis/src/training/optimizer_utils.py:148, in NPTrainer.train_epoch(self, dataloader, epoch_idx)
#     143 mu_y, var_y, mu_zc, log_var_zc, mu_zct, log_var_zct = outs
#     145 # self, mu_y, var_y, y_target, mu_zc, mu_zct, log_var_zc, log_var_zct
#     146 # --- LOSS CALCULATION ---
# --> 148 loss, nll, kl = self.loss_fn(
#     149     mu_y, var_y, yt, mu_zc, mu_zct, log_var_zc, log_var_zct
#     150 )
#     152 # --- OPTIMIZATION ---
#     153 loss.backward()
#
# File ~/Documents/Winter_Thesis/Coding_Learning/Master-Thesis/.venvn/lib/python3.9/site-packages/torch/nn/modules/module.py:1501, in Module._call_impl(self, *args, **kwargs)
#    1496 # If we don't have any hooks, we want to skip the rest of the logic in
#    1497 # this function, and just call forward.
#    1498 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1499         or _global_backward_pre_hooks or _global_backward_hooks
#    1500         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501     return forward_call(*args, **kwargs)
#    1502 # Do not call functions when jit is used
#    1503 full_backward_hooks, non_full_backward_hooks = [], []
#
# File ~/Documents/Winter_Thesis/Coding_Learning/Master-Thesis/src/training/loss_functions.py:68, in LossFunctions.forward(self, mu_y, var_y, y_target, mu_zc, mu_zct, log_var_zc, log_var_zct)
#      67 def forward(self, mu_y, var_y, y_target, mu_zc, mu_zct, log_var_zc, log_var_zct):
# ---> 68     nll = self.negative_log_likelihood(mu_y, var_y, y_target)
#      69     kl = self.KL_divergence(mu_zc, log_var_zc, mu_zct, log_var_zct)
#      70     total_loss = nll + kl
#
# File ~/Documents/Winter_Thesis/Coding_Learning/Master-Thesis/src/training/loss_functions.py:35, in LossFunctions.negative_log_likelihood(self, mu_y, var_y, y_target)
#      31 eps = 1e-6
#      32 var_y = var_y + eps  # To have the stability in variance
#      34 NLL = 0.5 * (
# ---> 35     (torch.log(2 * torch.pi * var_y)) + ((y_target - mu_y) ** 2 / var_y)
#      36 )
#      37 NLL = NLL.sum(dim=[1, 2]).mean()
#      38 return NLL
#
# KeyboardInterrupt:

# %%
ROOT = Path(__file__).resolve().parents[2]  # tests/ -> project root
sys.path.insert(0, str(ROOT))
print(ROOT)
# Out:
# /Users/pavankumar/Documents/Winter_Thesis/Coding_Learning/Master-Thesis

# %%
for input_key in input_type:
    if input_key == "":
        print("Please check the input keys")
        continue
    for output_key in output_type:
        if output_key == "":
            print("Please check the output keys")
            continue
        print(f" Start Training of Input: {input_key} | Output : {output_key}")
        # the current inputs and current outputs are:
        current_inputs = config["experiments"]["input_vars"][input_key]
        in_name = "_".join(current_inputs)
        current_outputs = config["experiments"]["output_vars"][output_key]
        out_name = "_".join(current_outputs)
        foldername =f"{in_name}_{out_name}"
        # We can calculate the dimensions of the inputs and putputs to decide the number of model's layers.

        x_dim = len(datasets[(input_key,output_key, "Train")]["inputs"][0])
        y_dim = len(datasets[(1,1,"Train")]["outputs"][0])
        # In this model the inputs and outputs are.
        model = NeuralProcess(x_dim, y_dim, x_dim, y_dim, 128, 128).to("cpu")
        # Defining the current check points and log directories.
        current_log_dir = ROOT/"cpu_logs"/foldername
        current_checkpoint_dir = ROOT/"cpu_checkpoints"/foldername
        # defining the optimizer
        Optimizer = optim.Adam(model.parameters(), lr=float(config["train"]["lr"]))
        # Defining the training class
        Training = NPTrainer(
            model=model,
            optimizer=Optimizer,
            loss_fn=Loss,
            device="cpu",
            log_dir=current_log_dir,
            checkpoint_dir=current_checkpoint_dir,
        )
        # To check the model's accuracy in validation data set we will use this.
        best_val_loss = float("inf")
        # these are the training data sets

        NeuralProcess_Train_data = neural_process_data(
            datasets[(input_key, output_key, "Train")]["inputs"],
            datasets[(input_key, output_key, "Train")]["outputs"],
            num_points_per_task=200,
        )

        NeuralProcess_Train_dataloader = DataLoader(
            NeuralProcess_Train_data,
            batch_size=16,
            shuffle=True,
            num_workers=0,
        )
        # Now we will define the validation datasets as well as validation dataloasers
        # NeuralProcess_Val_datasets = {}
        NeuralProcess_Val_data = neural_process_data(
            datasets[(input_key, output_key, "Val")]["inputs"],
            datasets[(input_key, output_key, "Val")]["outputs"],
            num_points_per_task=200,
        )

        # NeuralProcess_Val_dataloaders = {}
        NeuralProcess_Val_dataloader = DataLoader(
            NeuralProcess_Val_data,
            batch_size=16,
            shuffle=False,
            num_workers=0,
        )
        

        for epoch in range(100):
            # Train
            train_loss = Training.train_epoch(NeuralProcess_Train_dataloader, epoch)
            val_loss = validation_function(
                model=model,
                val_dataloader=NeuralProcess_Val_dataloader,
                loss_fn=Loss,
                device="cpu",
            )
            print(
                f"Epoch:{epoch} | Val_loss:{val_loss:.4f} | Train_loss:{train_loss:.4f}"
            )
            if val_loss < best_val_loss:
                best_val_loss = val_loss
                Training.save_checkpoint(epoch)
                print(f" >>> Saved New Best Model found! ")
# Out:
#  Start Training of Input: 1 | Output : 1
# Epoch 0: 100%|██████████| 770/770 [00:15<00:00, 49.45it/s, Loss=525.86]
# Epoch:0 | Val_loss:528.8120 | Train_loss:548.7372
# Checkpoint saved: /Users/pavankumar/Documents/Winter_Thesis/Coding_Learning/Master-Thesis/cpu_checkpoints/latitude_longitude_AOD_PM2.5_AOD_PM2.5/model_epoch_0.pth
#  >>> Saved New Best Model found!
# Epoch 1: 100%|██████████| 770/770 [00:13<00:00, 58.69it/s, Loss=451.36]
# Epoch:1 | Val_loss:455.9821 | Train_loss:478.0804
# Checkpoint saved: /Users/pavankumar/Documents/Winter_Thesis/Coding_Learning/Master-Thesis/cpu_checkpoints/latitude_longitude_AOD_PM2.5_AOD_PM2.5/model_epoch_1.pth
#  >>> Saved New Best Model found!
# Epoch 2: 100%|██████████| 770/770 [00:12<00:00, 60.19it/s, Loss=317.80]
# Epoch:2 | Val_loss:358.1336 | Train_loss:377.2896
# Checkpoint saved: /Users/pavankumar/Documents/Winter_Thesis/Coding_Learning/Master-Thesis/cpu_checkpoints/latitude_longitude_AOD_PM2.5_AOD_PM2.5/model_epoch_2.pth
#  >>> Saved New Best Model found!
# Epoch 3: 100%|██████████| 770/770 [00:13<00:00, 58.17it/s, Loss=145.06]
# Epoch:3 | Val_loss:215.9899 | Train_loss:235.2975
# Checkpoint saved: /Users/pavankumar/Documents/Winter_Thesis/Coding_Learning/Master-Thesis/cpu_checkpoints/latitude_longitude_AOD_PM2.5_AOD_PM2.5/model_epoch_3.pth
#  >>> Saved New Best Model found!
# Epoch 4: 100%|██████████| 770/770 [00:12<00:00, 60.38it/s, Loss=-94.45]
# Epoch:4 | Val_loss:-29.2901 | Train_loss:26.7216
# Checkpoint saved: /Users/pavankumar/Documents/Winter_Thesis/Coding_Learning/Master-Thesis/cpu_checkpoints/latitude_longitude_AOD_PM2.5_AOD_PM2.5/model_epoch_4.pth
#  >>> Saved New Best Model found!
# Epoch 5: 100%|██████████| 770/770 [00:12<00:00, 59.25it/s, Loss=-486.96]
# Epoch:5 | Val_loss:-411.3320 | Train_loss:-295.8033
# Checkpoint saved: /Users/pavankumar/Documents/Winter_Thesis/Coding_Learning/Master-Thesis/cpu_checkpoints/latitude_longitude_AOD_PM2.5_AOD_PM2.5/model_epoch_5.pth
#  >>> Saved New Best Model found!
# Epoch 6: 100%|██████████| 770/770 [00:12<00:00, 60.18it/s, Loss=-741.58]
# Epoch:6 | Val_loss:-606.0277 | Train_loss:-631.3325
# Checkpoint saved: /Users/pavankumar/Documents/Winter_Thesis/Coding_Learning/Master-Thesis/cpu_checkpoints/latitude_longitude_AOD_PM2.5_AOD_PM2.5/model_epoch_6.pth
#  >>> Saved New Best Model found!
# Epoch 7: 100%|██████████| 770/770 [00:12<00:00, 63.76it/s, Loss=-767.20]
# Epoch:7 | Val_loss:-714.8945 | Train_loss:-745.6211
# Checkpoint saved: /Users/pavankumar/Documents/Winter_Thesis/Coding_Learning/Master-Thesis/cpu_checkpoints/latitude_longitude_AOD_PM2.5_AOD_PM2.5/model_epoch_7.pth
#  >>> Saved New Best Model found!
# Epoch 8: 100%|██████████| 770/770 [00:12<00:00, 59.60it/s, Loss=-708.49]
# Epoch:8 | Val_loss:-776.3028 | Train_loss:-782.3311
# Checkpoint saved: /Users/pavankumar/Documents/Winter_Thesis/Coding_Learning/Master-Thesis/cpu_checkpoints/latitude_longitude_AOD_PM2.5_AOD_PM2.5/model_epoch_8.pth
#  >>> Saved New Best Model found!
# Epoch 9: 100%|██████████| 770/770 [00:12<00:00, 60.17it/s, Loss=-759.56]
# Epoch:9 | Val_loss:-647.6065 | Train_loss:-805.9764
# Epoch 10: 100%|██████████| 770/770 [00:12<00:00, 63.46it/s, Loss=-854.24]
# Epoch:10 | Val_loss:-820.6843 | Train_loss:-828.7914
# Checkpoint saved: /Users/pavankumar/Documents/Winter_Thesis/Coding_Learning/Master-Thesis/cpu_checkpoints/latitude_longitude_AOD_PM2.5_AOD_PM2.5/model_epoch_10.pth
#  >>> Saved New Best Model found!
# Epoch 11: 100%|██████████| 770/770 [00:12<00:00, 61.07it/s, Loss=-822.18]
# Epoch:11 | Val_loss:-887.2435 | Train_loss:-856.8493
# Checkpoint saved: /Users/pavankumar/Documents/Winter_Thesis/Coding_Learning/Master-Thesis/cpu_checkpoints/latitude_longitude_AOD_PM2.5_AOD_PM2.5/model_epoch_11.pth
#  >>> Saved New Best Model found!
# Epoch 12: 100%|██████████| 770/770 [00:12<00:00, 61.08it/s, Loss=-887.61]
# Epoch:12 | Val_loss:-752.3038 | Train_loss:-896.6348
# Epoch 13: 100%|██████████| 770/770 [00:12<00:00, 61.95it/s, Loss=-1081.61]
# Epoch:13 | Val_loss:-1023.3833 | Train_loss:-967.2422
# Checkpoint saved: /Users/pavankumar/Documents/Winter_Thesis/Coding_Learning/Master-Thesis/cpu_checkpoints/latitude_longitude_AOD_PM2.5_AOD_PM2.5/model_epoch_13.pth
#  >>> Saved New Best Model found!
# Epoch 14: 100%|██████████| 770/770 [00:12<00:00, 62.08it/s, Loss=-1055.20]
# Epoch:14 | Val_loss:-1288.5131 | Train_loss:-1096.7401
# Checkpoint saved: /Users/pavankumar/Documents/Winter_Thesis/Coding_Learning/Master-Thesis/cpu_checkpoints/latitude_longitude_AOD_PM2.5_AOD_PM2.5/model_epoch_14.pth
#  >>> Saved New Best Model found!
# Epoch 15: 100%|██████████| 770/770 [00:12<00:00, 60.65it/s, Loss=-1351.02]
# Epoch:15 | Val_loss:-1326.4359 | Train_loss:-1104.9108
# Checkpoint saved: /Users/pavankumar/Documents/Winter_Thesis/Coding_Learning/Master-Thesis/cpu_checkpoints/latitude_longitude_AOD_PM2.5_AOD_PM2.5/model_epoch_15.pth
#  >>> Saved New Best Model found!
# Epoch 16: 100%|██████████| 770/770 [00:12<00:00, 61.23it/s, Loss=556.21]
# Epoch:16 | Val_loss:-821.7370 | Train_loss:-1215.1884
# Epoch 17: 100%|██████████| 770/770 [00:15<00:00, 48.40it/s, Loss=-995.78]
# Epoch:17 | Val_loss:-1491.7923 | Train_loss:-1319.5124
# Checkpoint saved: /Users/pavankumar/Documents/Winter_Thesis/Coding_Learning/Master-Thesis/cpu_checkpoints/latitude_longitude_AOD_PM2.5_AOD_PM2.5/model_epoch_17.pth
#  >>> Saved New Best Model found!
# Epoch 18: 100%|██████████| 770/770 [00:14<00:00, 53.29it/s, Loss=-967.19]
# Epoch:18 | Val_loss:-1248.7734 | Train_loss:-1308.4488
# Epoch 19: 100%|██████████| 770/770 [00:13<00:00, 58.93it/s, Loss=-1234.46]
# Epoch:19 | Val_loss:-1023.3517 | Train_loss:-1219.0467
# Epoch 20: 100%|██████████| 770/770 [00:13<00:00, 58.30it/s, Loss=-1414.34]
# Epoch:20 | Val_loss:-1447.2843 | Train_loss:-1331.9415
# Epoch 21: 100%|██████████| 770/770 [00:12<00:00, 62.35it/s, Loss=-1282.48]
# Epoch:21 | Val_loss:-960.2707 | Train_loss:-1034.8769
# Epoch 22: 100%|██████████| 770/770 [00:14<00:00, 52.96it/s, Loss=-1496.30]
# Epoch:22 | Val_loss:-1443.3029 | Train_loss:-1266.6237
# Epoch 23: 100%|██████████| 770/770 [00:13<00:00, 56.88it/s, Loss=-1444.55]
# Epoch:23 | Val_loss:-1318.5112 | Train_loss:-1303.7269
# Epoch 24: 100%|██████████| 770/770 [00:13<00:00, 55.01it/s, Loss=-1310.69]
# Epoch:24 | Val_loss:-1077.3518 | Train_loss:-1359.0201
# Epoch 25: 100%|██████████| 770/770 [00:13<00:00, 56.47it/s, Loss=-1502.99]
# Epoch:25 | Val_loss:-1463.8165 | Train_loss:-1373.5214
# Epoch 26: 100%|██████████| 770/770 [00:13<00:00, 58.43it/s, Loss=-1506.33]
# Epoch:26 | Val_loss:-1267.3983 | Train_loss:-1459.2257
# Epoch 27: 100%|██████████| 770/770 [00:12<00:00, 62.07it/s, Loss=-1476.78]
# Epoch:27 | Val_loss:-1498.3511 | Train_loss:-1223.4578
# Checkpoint saved: /Users/pavankumar/Documents/Winter_Thesis/Coding_Learning/Master-Thesis/cpu_checkpoints/latitude_longitude_AOD_PM2.5_AOD_PM2.5/model_epoch_27.pth
#  >>> Saved New Best Model found!
# Epoch 28: 100%|██████████| 770/770 [00:13<00:00, 55.43it/s, Loss=-911.74]
# Epoch:28 | Val_loss:-1592.7939 | Train_loss:-1441.2045
# Checkpoint saved: /Users/pavankumar/Documents/Winter_Thesis/Coding_Learning/Master-Thesis/cpu_checkpoints/latitude_longitude_AOD_PM2.5_AOD_PM2.5/model_epoch_28.pth
#  >>> Saved New Best Model found!
# Epoch 29: 100%|██████████| 770/770 [00:13<00:00, 58.44it/s, Loss=-1435.26]
# Epoch:29 | Val_loss:-1461.9439 | Train_loss:-923.1324
# Epoch 30:   4%|▍         | 31/770 [00:00<00:11, 62.03it/s, Loss=-1375.03]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# File /Users/pavankumar/Documents/Winter_Thesis/Coding_Learning/Master-Thesis/src/training/trainer_latlon_AOD_PM25.py:71
#      61 NeuralProcess_Val_dataloader = DataLoader(
#      62     NeuralProcess_Val_data,
#      63     batch_size=16,
#      64     shuffle=False,
#      65     num_workers=0,
#      66 )
#      69 for epoch in range(100):
#      70     # Train
# ---> 71     train_loss = Training.train_epoch(NeuralProcess_Train_dataloader, epoch)
#      72     val_loss = validation_function(
#      73         model=model,
#      74         val_dataloader=NeuralProcess_Val_dataloader,
#      75         loss_fn=Loss,
#      76         device="cpu",
#      77     )
#      78     print(
#      79         f"Epoch:{epoch} | Val_loss:{val_loss:.4f} | Train_loss:{train_loss:.4f}"
#      80     )
#
# File ~/Documents/Winter_Thesis/Coding_Learning/Master-Thesis/src/training/optimizer_utils.py:155, in NPTrainer.train_epoch(self, dataloader, epoch_idx)
#     153 loss.backward()
#     154 torch.nn.utils.clip_grad_norm_(self.model.parameters(), max_norm=5.0)
# --> 155 self.optimizer.step()
#     157 # --- METRICS ---
#     158 total_loss_avg += loss.item()
#
# File ~/Documents/Winter_Thesis/Coding_Learning/Master-Thesis/.venvn/lib/python3.9/site-packages/torch/optim/optimizer.py:280, in Optimizer.profile_hook_step.<locals>.wrapper(*args, **kwargs)
#     276         else:
#     277             raise RuntimeError(f"{func} must return None or a tuple of (new_args, new_kwargs),"
#     278                                f"but got {result}.")
# --> 280 out = func(*args, **kwargs)
#     281 self._optimizer_step_code()
#     283 # call optimizer step post hooks
#
# File ~/Documents/Winter_Thesis/Coding_Learning/Master-Thesis/.venvn/lib/python3.9/site-packages/torch/optim/optimizer.py:33, in _use_grad_for_differentiable.<locals>._use_grad(self, *args, **kwargs)
#      31 try:
#      32     torch.set_grad_enabled(self.defaults['differentiable'])
# ---> 33     ret = func(self, *args, **kwargs)
#      34 finally:
#      35     torch.set_grad_enabled(prev_grad)
#
# File ~/Documents/Winter_Thesis/Coding_Learning/Master-Thesis/.venvn/lib/python3.9/site-packages/torch/optim/adam.py:141, in Adam.step(self, closure)
#     130     beta1, beta2 = group['betas']
#     132     self._init_group(
#     133         group,
#     134         params_with_grad,
#    (...)
#     138         max_exp_avg_sqs,
#     139         state_steps)
# --> 141     adam(
#     142         params_with_grad,
#     143         grads,
#     144         exp_avgs,
#     145         exp_avg_sqs,
#     146         max_exp_avg_sqs,
#     147         state_steps,
#     148         amsgrad=group['amsgrad'],
#     149         beta1=beta1,
#     150         beta2=beta2,
#     151         lr=group['lr'],
#     152         weight_decay=group['weight_decay'],
#     153         eps=group['eps'],
#     154         maximize=group['maximize'],
#     155         foreach=group['foreach'],
#     156         capturable=group['capturable'],
#     157         differentiable=group['differentiable'],
#     158         fused=group['fused'],
#     159         grad_scale=getattr(self, "grad_scale", None),
#     160         found_inf=getattr(self, "found_inf", None),
#     161     )
#     163 return loss
#
# File ~/Documents/Winter_Thesis/Coding_Learning/Master-Thesis/.venvn/lib/python3.9/site-packages/torch/optim/adam.py:281, in adam(params, grads, exp_avgs, exp_avg_sqs, max_exp_avg_sqs, state_steps, foreach, capturable, differentiable, fused, grad_scale, found_inf, amsgrad, beta1, beta2, lr, weight_decay, eps, maximize)
#     278 else:
#     279     func = _single_tensor_adam
# --> 281 func(params,
#     282      grads,
#     283      exp_avgs,
#     284      exp_avg_sqs,
#     285      max_exp_avg_sqs,
#     286      state_steps,
#     287      amsgrad=amsgrad,
#     288      beta1=beta1,
#     289      beta2=beta2,
#     290      lr=lr,
#     291      weight_decay=weight_decay,
#     292      eps=eps,
#     293      maximize=maximize,
#     294      capturable=capturable,
#     295      differentiable=differentiable,
#     296      grad_scale=grad_scale,
#     297      found_inf=found_inf)
#
# File ~/Documents/Winter_Thesis/Coding_Learning/Master-Thesis/.venvn/lib/python3.9/site-packages/torch/optim/adam.py:391, in _single_tensor_adam(params, grads, exp_avgs, exp_avg_sqs, max_exp_avg_sqs, state_steps, grad_scale, found_inf, amsgrad, beta1, beta2, lr, weight_decay, eps, maximize, capturable, differentiable)
#     389     denom = (max_exp_avg_sqs[i].sqrt() / bias_correction2_sqrt).add_(eps)
#     390 else:
# --> 391     denom = (exp_avg_sq.sqrt() / bias_correction2_sqrt).add_(eps)
#     393 param.addcdiv_(exp_avg, denom, value=-step_size)
#
# KeyboardInterrupt:

# %%
for input_key in input_type:
    if input_key == "":
        print("Please check the input keys")
        continue
    for output_key in output_type:
        if output_key == "":
            print("Please check the output keys")
            continue
        print(f" Start Training of Input: {input_key} | Output : {output_key}")
        # the current inputs and current outputs are:
        current_inputs = config["experiments"]["input_vars"][input_key]
        in_name = "_".join(current_inputs)
        current_outputs = config["experiments"]["output_vars"][output_key]
        out_name = "_".join(current_outputs)
        foldername =f"{in_name}_{out_name}"
        # We can calculate the dimensions of the inputs and putputs to decide the number of model's layers.

        x_dim = len(datasets[(input_key,output_key, "Train")]["inputs"][0])
        y_dim = len(datasets[(1,1,"Train")]["outputs"][0])
        # In this model the inputs and outputs are.
        model = NeuralProcess(x_dim, y_dim, x_dim, y_dim, 128, 128).to("cpu")
        current_time = datetime.now().strftime("%Y%m%d-%H%M%S")
        # Defining the current check points and log directories.
        current_log_dir = ROOT/"cpu_logs"/foldername/{current_time}
        current_checkpoint_dir = ROOT/"cpu_checkpoints"/foldername/{current_time}
        # defining the optimizer
        Optimizer = optim.Adam(model.parameters(), lr=float(config["train"]["lr"]))
        # Defining the training class
        Training = NPTrainer(
            model=model,
            optimizer=Optimizer,
            loss_fn=Loss,
            device="cpu",
            log_dir=current_log_dir,
            checkpoint_dir=current_checkpoint_dir,
        )
        # To check the model's accuracy in validation data set we will use this.
        best_val_loss = float("inf")
        # these are the training data sets

        NeuralProcess_Train_data = neural_process_data(
            datasets[(input_key, output_key, "Train")]["inputs"],
            datasets[(input_key, output_key, "Train")]["outputs"],
            num_points_per_task=200,
        )

        NeuralProcess_Train_dataloader = DataLoader(
            NeuralProcess_Train_data,
            batch_size=16,
            shuffle=True,
            num_workers=0,
        )
        # Now we will define the validation datasets as well as validation dataloasers
        # NeuralProcess_Val_datasets = {}
        NeuralProcess_Val_data = neural_process_data(
            datasets[(input_key, output_key, "Val")]["inputs"],
            datasets[(input_key, output_key, "Val")]["outputs"],
            num_points_per_task=200,
        )

        # NeuralProcess_Val_dataloaders = {}
        NeuralProcess_Val_dataloader = DataLoader(
            NeuralProcess_Val_data,
            batch_size=16,
            shuffle=False,
            num_workers=0,
        )
        
        
        for epoch in range(100):
            # Train
            train_loss = Training.train_epoch(NeuralProcess_Train_dataloader, epoch)
            val_loss = validation_function(
                model=model,
                val_dataloader=NeuralProcess_Val_dataloader,
                loss_fn=Loss,
                device="cpu",
            )
            print(
                f"Epoch:{epoch} | Val_loss:{val_loss:.4f} | Train_loss:{train_loss:.4f}"
            )
            if val_loss < best_val_loss:
                best_val_loss = val_loss
                Training.save_checkpoint(epoch)
                print(f" >>> Saved New Best Model found! ")
# Out:
#  Start Training of Input: 1 | Output : 1
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File /Users/pavankumar/Documents/Winter_Thesis/Coding_Learning/Master-Thesis/src/training/trainer_latlon_AOD_PM25.py:24
#      22 current_time = datetime.now().strftime("%Y%m%d-%H%M%S")
#      23 # Defining the current check points and log directories.
# ---> 24 current_log_dir = ROOT/"cpu_logs"/foldername/{current_time}
#      25 current_checkpoint_dir = ROOT/"cpu_checkpoints"/foldername/{current_time}
#      26 # defining the optimizer
#
# TypeError: unsupported operand type(s) for /: 'PosixPath' and 'set'

# %%
for input_key in input_type:
    if input_key == "":
        print("Please check the input keys")
        continue
    for output_key in output_type:
        if output_key == "":
            print("Please check the output keys")
            continue
        print(f" Start Training of Input: {input_key} | Output : {output_key}")
        # the current inputs and current outputs are:
        current_inputs = config["experiments"]["input_vars"][input_key]
        in_name = "_".join(current_inputs)
        current_outputs = config["experiments"]["output_vars"][output_key]
        out_name = "_".join(current_outputs)
        foldername =f"{in_name}_{out_name}"
        # We can calculate the dimensions of the inputs and putputs to decide the number of model's layers.

        x_dim = len(datasets[(input_key,output_key, "Train")]["inputs"][0])
        y_dim = len(datasets[(1,1,"Train")]["outputs"][0])
        # In this model the inputs and outputs are.
        model = NeuralProcess(x_dim, y_dim, x_dim, y_dim, 128, 128).to("cpu")
        current_time = datetime.now().strftime("%Y%m%d-%H%M%S")
        # Defining the current check points and log directories.
        current_log_dir = ROOT/"cpu_logs"/foldername/current_time
        current_checkpoint_dir = ROOT/"cpu_checkpoints"/foldername/current_time
        # defining the optimizer
        Optimizer = optim.Adam(model.parameters(), lr=float(config["train"]["lr"]))
        # Defining the training class
        Training = NPTrainer(
            model=model,
            optimizer=Optimizer,
            loss_fn=Loss,
            device="cpu",
            log_dir=current_log_dir,
            checkpoint_dir=current_checkpoint_dir,
        )
        # To check the model's accuracy in validation data set we will use this.
        best_val_loss = float("inf")
        # these are the training data sets

        NeuralProcess_Train_data = neural_process_data(
            datasets[(input_key, output_key, "Train")]["inputs"],
            datasets[(input_key, output_key, "Train")]["outputs"],
            num_points_per_task=200,
        )

        NeuralProcess_Train_dataloader = DataLoader(
            NeuralProcess_Train_data,
            batch_size=16,
            shuffle=True,
            num_workers=0,
        )
        # Now we will define the validation datasets as well as validation dataloasers
        # NeuralProcess_Val_datasets = {}
        NeuralProcess_Val_data = neural_process_data(
            datasets[(input_key, output_key, "Val")]["inputs"],
            datasets[(input_key, output_key, "Val")]["outputs"],
            num_points_per_task=200,
        )

        # NeuralProcess_Val_dataloaders = {}
        NeuralProcess_Val_dataloader = DataLoader(
            NeuralProcess_Val_data,
            batch_size=16,
            shuffle=False,
            num_workers=0,
        )
        
        
        for epoch in range(100):
            # Train
            train_loss = Training.train_epoch(NeuralProcess_Train_dataloader, epoch)
            val_loss = validation_function(
                model=model,
                val_dataloader=NeuralProcess_Val_dataloader,
                loss_fn=Loss,
                device="cpu",
            )
            print(
                f"Epoch:{epoch} | Val_loss:{val_loss:.4f} | Train_loss:{train_loss:.4f}"
            )
            if val_loss < best_val_loss:
                best_val_loss = val_loss
                Training.save_checkpoint(epoch)
                print(f" >>> Saved New Best Model found! ")

# NeuraProcessData_latlon_PM25 = neural_process_data(
#     fnal_data_latlong_PM25[0],
#     fnal_data_latlong_PM25[1],
#     nm_points_per_task=200,
# )


#     dataloader_latlon_PM25 = DataLoader(
#     dataset=NeuralProcessData_latlon_PM25,
#     batch_size=16,
#     shuffle=True,
#     num_workers=0,
# )


# ##################################################################
# # -------------Training of Lat_Lon_PM25 data
# ##################################################################
# current_time = datetime.now().strftime("%Y%m%d-%H%M%S")
# unique_log_dir = f"./logs/
# Out:
#  Start Training of Input: 1 | Output : 1
# Epoch 0: 100%|██████████| 770/770 [00:12<00:00, 60.70it/s, Loss=517.83]
# Epoch:0 | Val_loss:519.2439 | Train_loss:544.3071
# Checkpoint saved: /Users/pavankumar/Documents/Winter_Thesis/Coding_Learning/Master-Thesis/cpu_checkpoints/latitude_longitude_AOD_PM2.5_AOD_PM2.5/20260102-184017/model_epoch_0.pth
#  >>> Saved New Best Model found!
# Epoch 1: 100%|██████████| 770/770 [00:12<00:00, 61.43it/s, Loss=392.10]
# Epoch:1 | Val_loss:435.7240 | Train_loss:456.7401
# Checkpoint saved: /Users/pavankumar/Documents/Winter_Thesis/Coding_Learning/Master-Thesis/cpu_checkpoints/latitude_longitude_AOD_PM2.5_AOD_PM2.5/20260102-184017/model_epoch_1.pth
#  >>> Saved New Best Model found!
# Epoch 2: 100%|██████████| 770/770 [00:13<00:00, 57.85it/s, Loss=260.89]
# Epoch:2 | Val_loss:331.0445 | Train_loss:335.6031
# Checkpoint saved: /Users/pavankumar/Documents/Winter_Thesis/Coding_Learning/Master-Thesis/cpu_checkpoints/latitude_longitude_AOD_PM2.5_AOD_PM2.5/20260102-184017/model_epoch_2.pth
#  >>> Saved New Best Model found!
# Epoch 3: 100%|██████████| 770/770 [00:12<00:00, 61.39it/s, Loss=60.04]
# Epoch:3 | Val_loss:170.6989 | Train_loss:171.4439
# Checkpoint saved: /Users/pavankumar/Documents/Winter_Thesis/Coding_Learning/Master-Thesis/cpu_checkpoints/latitude_longitude_AOD_PM2.5_AOD_PM2.5/20260102-184017/model_epoch_3.pth
#  >>> Saved New Best Model found!
# Epoch 4: 100%|██████████| 770/770 [00:13<00:00, 58.28it/s, Loss=-194.17]
# Epoch:4 | Val_loss:-103.4026 | Train_loss:-49.0179
# Checkpoint saved: /Users/pavankumar/Documents/Winter_Thesis/Coding_Learning/Master-Thesis/cpu_checkpoints/latitude_longitude_AOD_PM2.5_AOD_PM2.5/20260102
# Epoch:91 | Val_loss:-949.4809 | Train_loss:-1213.4387
# Epoch 92: 100%|██████████| 770/770 [00:13<00:00, 58.71it/s, Loss=-1583.92]
# Epoch:92 | Val_loss:-1564.1282 | Train_loss:-1461.5426
# Epoch 93: 100%|██████████| 770/770 [00:13<00:00, 57.07it/s, Loss=-1516.78]
# Epoch:93 | Val_loss:-1373.0505 | Train_loss:-1541.9420
# Epoch 94: 100%|██████████| 770/770 [00:13<00:00, 57.67it/s, Loss=-1566.50]
# Epoch:94 | Val_loss:-1514.7696 | Train_loss:-1494.0576
# Epoch 95: 100%|██████████| 770/770 [00:13<00:00, 58.49it/s, Loss=-1587.22]
# Epoch:95 | Val_loss:-1574.0099 | Train_loss:-1570.1538
# Epoch 96: 100%|██████████| 770/770 [00:13<00:00, 57.21it/s, Loss=-1600.41]
# Epoch:96 | Val_loss:-1560.0430 | Train_loss:-1584.3256
# Epoch 97: 100%|██████████| 770/770 [00:13<00:00, 55.88it/s, Loss=-1588.37]
# Epoch:97 | Val_loss:-1587.4779 | Train_loss:-1555.1822
# Epoch 98: 100%|██████████| 770/770 [00:13<00:00, 55.87it/s, Loss=-1602.78]
# Epoch:98 | Val_loss:-1118.9071 | Train_loss:-1531.7111
# Epoch 99: 100%|██████████| 770/770 [00:12<00:00, 61.14it/s, Loss=-1564.04]
# Epoch:99 | Val_loss:-1572.9045 | Train_loss:-1554.1134
#  Start Training of Input: 1 | Output : 2
# Epoch 0:   0%|          | 0/770 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[78], line 72
#      62 NeuralProcess_Val_dataloader = DataLoader(
#      63     NeuralProcess_Val_data,
#      64     batch_size=16,
#      65     shuffle=False,
#      66     num_workers=0,
#      67 )
#      70 for epoch in range(100):
#      71     # Train
# ---> 72     train_loss = Training.train_epoch(NeuralProcess_Train_dataloader, epoch)
#      73     val_loss = validation_function(
#      74         model=model,
#      75         val_dataloader=NeuralProcess_Val_dataloader,
#      76         loss_fn=Loss,
#      77         device="cpu",
#      78     )
#      79     print(
#      80         f"Epoch:{epoch} | Val_loss:{val_loss:.4f} | Train_loss:{train_loss:.4f}"
#      81     )
#
# File ~/Documents/Winter_Thesis/Coding_Learning/Master-Thesis/src/training/optimizer_utils.py:142, in NPTrainer.train_epoch(self, dataloader, epoch_idx)
#     135 self.optimizer.zero_grad()
#     137 # --- FORWARD PASS ---
#     138
#     139 # model inputs -->
#     140
#     141 # Returns: (mu_y, var_y, mu_zc, log_var_zc, mu_zct, log_var_zct)
# --> 142 outs = self.model(xc, yc, xt, yt)
#     143 mu_y, var_y, mu_zc, log_var_zc, mu_zct, log_var_zct = outs
#     145 # self, mu_y, var_y, y_target, mu_zc, mu_zct, log_var_zc, log_var_zct
#     146 # --- LOSS CALCULATION ---
#
# File ~/Documents/Winter_Thesis/Coding_Learning/Master-Thesis/.venvn/lib/python3.9/site-packages/torch/nn/modules/module.py:1501, in Module._call_impl(self, *args, **kwargs)
#    1496 # If we don't have any hooks, we want to skip the rest of the logic in
#    1497 # this function, and just call forward.
#    1498 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1499         or _global_backward_pre_hooks or _global_backward_hooks
#    1500         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501     return forward_call(*args, **kwargs)
#    1502 # Do not call functions when jit is used
#    1503 full_backward_hooks, non_full_backward_hooks = [], []
#
# File ~/Documents/Winter_Thesis/Coding_Learning/Master-Thesis/src/Models/neural_process.py:51, in NeuralProcess.forward(self, x_context, y_context, x_target, y_target)
#      49 def forward(self, x_context, y_context, x_target, y_target):
#      50     # Step 1: Pass the context points through the encoder to get r
# ---> 51     rc = self.encoder(x_context, y_context)
#      52     rt = self.encoder(x_target, y_target)
#      53     # here we are
#
# File ~/Documents/Winter_Thesis/Coding_Learning/Master-Thesis/.venvn/lib/python3.9/site-packages/torch/nn/modules/module.py:1501, in Module._call_impl(self, *args, **kwargs)
#    1496 # If we don't have any hooks, we want to skip the rest of the logic in
#    1497 # this function, and just call forward.
#    1498 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1499         or _global_backward_pre_hooks or _global_backward_hooks
#    1500         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501     return forward_call(*args, **kwargs)
#    1502 # Do not call functions when jit is used
#    1503 full_backward_hooks, non_full_backward_hooks = [], []
#
# File ~/Documents/Winter_Thesis/Coding_Learning/Master-Thesis/src/Models/Encoder.py:26, in Encoder.forward(self, x, y)
#      24 combined_input = torch.cat([x, y], dim=-1)
#      25 # Now we will pass this combined input through a linear layer to reduce its dimension.
# ---> 26 r_i = self.net(combined_input)
#      27 r = torch.mean(r_i, dim=1)
#      28 # vector of dim = hidden dimension
#
# File ~/Documents/Winter_Thesis/Coding_Learning/Master-Thesis/.venvn/lib/python3.9/site-packages/torch/nn/modules/module.py:1501, in Module._call_impl(self, *args, **kwargs)
#    1496 # If we don't have any hooks, we want to skip the rest of the logic in
#    1497 # this function, and just call forward.
#    1498 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1499         or _global_backward_pre_hooks or _global_backward_hooks
#    1500         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501     return forward_call(*args, **kwargs)
#    1502 # Do not call functions when jit is used
#    1503 full_backward_hooks, non_full_backward_hooks = [], []
#
# File ~/Documents/Winter_Thesis/Coding_Learning/Master-Thesis/.venvn/lib/python3.9/site-packages/torch/nn/modules/container.py:217, in Sequential.forward(self, input)
#     215 def forward(self, input):
#     216     for module in self:
# --> 217         input = module(input)
#     218     return input
#
# File ~/Documents/Winter_Thesis/Coding_Learning/Master-Thesis/.venvn/lib/python3.9/site-packages/torch/nn/modules/module.py:1501, in Module._call_impl(self, *args, **kwargs)
#    1496 # If we don't have any hooks, we want to skip the rest of the logic in
#    1497 # this function, and just call forward.
#    1498 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1499         or _global_backward_pre_hooks or _global_backward_hooks
#    1500         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501     return forward_call(*args, **kwargs)
#    1502 # Do not call functions when jit is used
#    1503 full_backward_hooks, non_full_backward_hooks = [], []
#
# File ~/Documents/Winter_Thesis/Coding_Learning/Master-Thesis/.venvn/lib/python3.9/site-packages/torch/nn/modules/linear.py:114, in Linear.forward(self, input)
#     113 def forward(self, input: Tensor) -> Tensor:
# --> 114     return F.linear(input, self.weight, self.bias)
#
# RuntimeError: mat1 and mat2 shapes cannot be multiplied (640x129 and 130x128)

# %%
for input_key in input_type:
    if input_key == "":
        print("Please check the input keys")
        continue
    for output_key in output_type:
        if output_key == "":
            print("Please check the output keys")
            continue
        print(f" Start Training of Input: {input_key} | Output : {output_key}")
        # the current inputs and current outputs are:
        current_inputs = config["experiments"]["input_vars"][input_key]
        in_name = "_".join(current_inputs)
        current_outputs = config["experiments"]["output_vars"][output_key]
        out_name = "_".join(current_outputs)
        foldername = f"{in_name}_{out_name}"
        # We can calculate the dimensions of the inputs and putputs to decide the number of model's layers.

        x_dim = len(datasets[(input_key, output_key, "Train")]["inputs"][0])
        y_dim = len(datasets[(input_key, output_key, "Train")]["outputs"][0])
        # In this model the inputs and outputs are.
        model = NeuralProcess(x_dim, y_dim, x_dim, y_dim, 128, 128).to("cpu")
        current_time = datetime.now().strftime("%Y%m%d-%H%M%S")
        # Defining the current check points and log directories.
        current_log_dir = ROOT / "cpu_logs" / foldername / current_time
        current_checkpoint_dir = ROOT / "cpu_checkpoints" / foldername / current_time
        # defining the optimizer
        Optimizer = optim.Adam(model.parameters(), lr=float(config["train"]["lr"]))
        # Defining the training class
        Training = NPTrainer(
            model=model,
            optimizer=Optimizer,
            loss_fn=Loss,
            device="cpu",
            log_dir=current_log_dir,
            checkpoint_dir=current_checkpoint_dir,
        )
        # To check the model's accuracy in validation data set we will use this.
        best_val_loss = float("inf")
        # these are the training data sets

        NeuralProcess_Train_data = neural_process_data(
            datasets[(input_key, output_key, "Train")]["inputs"],
            datasets[(input_key, output_key, "Train")]["outputs"],
            num_points_per_task=200,
        )

        NeuralProcess_Train_dataloader = DataLoader(
            NeuralProcess_Train_data,
            batch_size=16,
            shuffle=True,
            num_workers=0,
        )
        # Now we will define the validation datasets as well as validation dataloasers
        # NeuralProcess_Val_datasets = {}
        NeuralProcess_Val_data = neural_process_data(
            datasets[(input_key, output_key, "Val")]["inputs"],
            datasets[(input_key, output_key, "Val")]["outputs"],
            num_points_per_task=200,
        )

        # NeuralProcess_Val_dataloaders = {}
        NeuralProcess_Val_dataloader = DataLoader(
            NeuralProcess_Val_data,
            batch_size=16,
            shuffle=False,
            num_workers=0,
        )

        for epoch in range(100):
            # Train
            train_loss = Training.train_epoch(NeuralProcess_Train_dataloader, epoch)
            val_loss = validation_function(
                model=model,
                val_dataloader=NeuralProcess_Val_dataloader,
                loss_fn=Loss,
                device="cpu",
            )
            print(
                f"Epoch:{epoch} | Val_loss:{val_loss:.4f} | Train_loss:{train_loss:.4f}"
            )
            if val_loss < best_val_loss:
                best_val_loss = val_loss
                Training.save_checkpoint(epoch)
                print(f" >>> Saved New Best Model found! ")
# Out:
#  Start Training of Input: 1 | Output : 1
# Epoch 0: 100%|██████████| 770/770 [00:13<00:00, 57.66it/s, Loss=545.58]
# Epoch:0 | Val_loss:527.9524 | Train_loss:547.9417
# Checkpoint saved: /Users/pavankumar/Documents/Winter_Thesis/Coding_Learning/Master-Thesis/cpu_checkpoints/latitude_longitude_AOD_PM2.5_AOD_PM2.5/20260102-191354/model_epoch_0.pth
#  >>> Saved New Best Model found!
# Epoch 1: 100%|██████████| 770/770 [00:11<00:00, 66.24it/s, Loss=415.52]
# Epoch:1 | Val_loss:460.6958 | Train_loss:475.7797
# Checkpoint saved: /Users/pavankumar/Documents/Winter_Thesis/Coding_Learning/Master-Thesis/cpu_checkpoints/latitude_longitude_AOD_PM2.5_AOD_PM2.5/20260102-191354/model_epoch_1.pth
#  >>> Saved New Best Model found!
# Epoch 2: 100%|██████████| 770/770 [00:12<00:00, 64.07it/s, Loss=313.06]
# Epoch:2 | Val_loss:378.4232 | Train_loss:377.2530
# Checkpoint saved: /Users/pavankumar/Documents/Winter_Thesis/Coding_Learning/Master-Thesis/cpu_checkpoints/latitude_longitude_AOD_PM2.5_AOD_PM2.5/20260102-191354/model_epoch_2.pth
#  >>> Saved New Best Model found!
# Epoch 3: 100%|██████████| 770/770 [00:12<00:00, 63.99it/s, Loss=163.60]
# Epoch:3 | Val_loss:251.4893 | Train_loss:244.3448
# Checkpoint saved: /Users/pavankumar/Documents/Winter_Thesis/Coding_Learning/Master-Thesis/cpu_checkpoints/latitude_longitude_AOD_PM2.5_AOD_PM2.5/20260102-191354/model_epoch_3.pth
#  >>> Saved New Best Model found!
# Epoch 4: 100%|██████████| 770/770 [00:12<00:00, 64.14it/s, Loss=-83.04]
# Epoch:4 | Val_loss:27.8307 | Train_loss:58.0450
# Checkpoint saved: /Users/pavankumar/Documents/Winter_Thesis/Coding_Learning/Master-Thesis/cpu_checkpoints/latitude_longitude_AOD_PM2.5_AOD_PM2.5/20260102-191354/model_epoch_4.pth
#  >>> Saved New Best Model found!
# Epoch 5: 100%|██████████| 770/770 [00:11<00:00, 65.33it/s, Loss=-369.50]
# Epoch:5 | Val_loss:-269.2136 | Train_loss:-218.6179
# Checkpoint saved: /Users/pavankumar/Documents/Winter_Thesis/Coding_Learning/Master-Thesis/cpu_checkpoints/latitude_longitude_AOD_PM2.5_AOD_PM2.5/20260102-191354/model_epoch_5.pth
#  >>> Saved New Best Model found!
# Epoch 6: 100%|██████████| 770/770 [00:12<00:00, 61.25it/s, Loss=-237.09]
# Epoch:6 | Val_loss:-289.0168 | Train_loss:-381.4467
# Checkpoint saved: /Users/pavankumar/Documents/Winter_Thesis/Coding_Learning/Master-Thesis/cpu_checkpoints/latitude_longitude_AOD_PM2.5_AOD_PM2.5/20260102-191354/model_epoch_6.pth
#  >>> Saved New Best Model found!
# Epoch 7: 100%|██████████| 770/770 [00:12<00:00, 60.95it/s, Loss=-431.40]
# Epoch:7 | Val_loss:-360.0515 | Train_loss:-404.1340
# Checkpoint saved: /Users/pavankumar/Documents/Winter_Thesis/Coding_Learning/Master-Thesis/cpu_checkpoints/latitude_longitude_AOD_PM2.5_AOD_PM2.5/20260102-191354/model_epoch_7.pth
#  >>> Saved New Best Model found!
# Epoch 8: 100%|██████████| 770/770 [00:11<00:00, 64.46it/s, Loss=-350.52]
# Epoch:8 | Val_loss:-308.3875 | Train_loss:-407.6385
# Epoch 9: 100%|██████████| 770/770 [00:12<00:00, 61.73it/s, Loss=-492.93]
# Epoch:9 | Val_loss:-369.9624 | Train_loss:-412.6574
# Checkpoint saved: /Users/pavankumar/Documents/Winter_Thesis/Coding_Learning/Master-Thesis/cpu_checkpoints/latitude_longitude_AOD_PM2.5_AOD_PM2.5/20260102-191354/model_epoch_9.pth
#  >>> Saved New Best Model found!
# Epoch 10:  87%|████████▋ | 672/770 [00:11<00:01, 57.39it/s, Loss=-501.13]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# File /Users/pavankumar/Documents/Winter_Thesis/Coding_Learning/Master-Thesis/src/training/trainer_latlon_AOD_PM25.py:71
#      62 NeuralProcess_Val_dataloader = DataLoader(
#      63     NeuralProcess_Val_data,
#      64     batch_size=16,
#      65     shuffle=False,
#      66     num_workers=0,
#      67 )
#      69 for epoch in range(100):
#      70     # Train
# ---> 71     train_loss = Training.train_epoch(NeuralProcess_Train_dataloader, epoch)
#      72     val_loss = validation_function(
#      73         model=model,
#      74         val_dataloader=NeuralProcess_Val_dataloader,
#      75         loss_fn=Loss,
#      76         device="cpu",
#      77     )
#      78     print(
#      79         f"Epoch:{epoch} | Val_loss:{val_loss:.4f} | Train_loss:{train_loss:.4f}"
#      80     )
#
# File ~/Documents/Winter_Thesis/Coding_Learning/Master-Thesis/src/training/optimizer_utils.py:153, in NPTrainer.train_epoch(self, dataloader, epoch_idx)
#     148 loss, nll, kl = self.loss_fn(
#     149     mu_y, var_y, yt, mu_zc, mu_zct, log_var_zc, log_var_zct
#     150 )
#     152 # --- OPTIMIZATION ---
# --> 153 loss.backward()
#     154 torch.nn.utils.clip_grad_norm_(self.model.parameters(), max_norm=5.0)
#     155 self.optimizer.step()
#
# File ~/Documents/Winter_Thesis/Coding_Learning/Master-Thesis/.venvn/lib/python3.9/site-packages/torch/_tensor.py:487, in Tensor.backward(self, gradient, retain_graph, create_graph, inputs)
#     477 if has_torch_function_unary(self):
#     478     return handle_torch_function(
#     479         Tensor.backward,
#     480         (self,),
#    (...)
#     485         inputs=inputs,
#     486     )
# --> 487 torch.autograd.backward(
#     488     self, gradient, retain_graph, create_graph, inputs=inputs
#     489 )
#
# File ~/Documents/Winter_Thesis/Coding_Learning/Master-Thesis/.venvn/lib/python3.9/site-packages/torch/autograd/__init__.py:200, in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     195     retain_graph = create_graph
#     197 # The reason we repeat same the comment below is that
#     198 # some Python versions print out the first line of a multi-line function
#     199 # calls in the traceback and some print out the last line
# --> 200 Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#     201     tensors, grad_tensors_, retain_graph, create_graph, inputs,
#     202     allow_unreachable=True, accumulate_grad=True)
#
# KeyboardInterrupt:

# %%
"""
Importing the necessary packages.............
"""

import os
import torch
import numpy as np
import pandas as pd
import sys
from pathlib import Path
import os
import matplotlib.pyplot as plt
from glob import glob
from tqdm import tqdm
import arrow
from datetime import datetime
from torch import optim

# from utils.config import config
from torch.utils.data import DataLoader

ROOT = Path(__file__).resolve().parents[2]  # tests/ -> project root
sys.path.insert(0, str(ROOT))
print(ROOT)

from configs.utils import config

# -------------************---------------------------------
# loading all the data loaders here we will load the final data in torch.
from Dataloader.Modis_Data_loader.PM25_data_loader_analysis import Modis_data_loader
from Dataloader.Modis_Data_loader.PM25_data_loader_analysis import PM_25_dataloader
from Dataloader.Modis_Data_loader.PM25_data_loader_analysis import (
    combine_the_data_frames,
)
from Dataloader.Modis_Data_loader.PM25_data_loader_analysis import (
    Training_data_loader,
)
from locationencoder.final_location_encoder import Geospatial_Encoder

geospatial_encoder = Geospatial_Encoder(
    config["Geo_spatial_Encoder"]["dim_in"],
    config["Geo_spatial_Encoder"]["dim_hidden"],
    config["Geo_spatial_Encoder"]["dim_out"],
    config["Geo_spatial_Encoder"]["num_layers"],
)
from Dataloader.Modis_Data_loader.torch_data_loader import Airqualitydataset
from Dataloader.Modis_Data_loader.final_loader import Final_Air_Quality_Dataset_pipeline
from src.Models.neural_process import NeuralProcess
from loss_functions import LossFunctions

Loss = LossFunctions()
from optimizer_utils import NPTrainer
from optimizer_utils import neural_process_data
from optimizer_utils import validation_function

# importing the packages for the optimization.
from Dataloader.Modis_Data_loader.torch_data_loader import Airqualitydataset
from Dataloader.Modis_Data_loader.final_loader import Final_Air_Quality_Dataset_pipeline
from src.Models.neural_process import NeuralProcess
# Out:
# /Users/pavankumar/Documents/Winter_Thesis/Coding_Learning/Master-Thesis

# %%
from loss_functions import LossFunctions

Loss = LossFunctions()
from optimizer_utils import NPTrainer
from optimizer_utils import neural_process_data
from optimizer_utils import validation_function

# importing the packages for the optimization.
from Dataloader.Modis_Data_loader.torch_data_loader import Airqualitydataset
from Dataloader.Modis_Data_loader.final_loader import Final_Air_Quality_Dataset_pipeline
from src.Models.neural_process import NeuralProcess

# %%
len(config["experiments"]["input_vars"][1])
len(config["experiments"]["output_vars"][1])

float(config["train"]["lr"])
len(datasets[(1, 1, "Train")]["inputs"][0])
len(datasets[(1, 1, "Train")]["outputs"][0])
# Out:
# 2

# %%
len(datasets[(1, 1, "Train")]["inputs"][0])
# Out:
# 128

# %%
for input_key in input_type:
    if input_key == "":
        print("Please check the input keys")
        continue
    for output_key in output_type:
        if output_key == "":
            print("Please check the output keys")
            continue
        print(f" Start Training of Input: {input_key} | Output : {output_key}")
        # the current inputs and current outputs are:
        current_inputs = config["experiments"]["input_vars"][input_key]
        in_name = "_".join(current_inputs)
        current_outputs = config["experiments"]["output_vars"][output_key]
        out_name = "_".join(current_outputs)
        foldername = f"{in_name}_{out_name}"
        # We can calculate the dimensions of the inputs and putputs to decide the number of model's layers.

        x_dim = len(datasets[(input_key, output_key, "Train")]["inputs"][0])
        y_dim = len(datasets[(input_key, output_key, "Train")]["outputs"][0])
        # In this model the inputs and outputs are.
        model = NeuralProcess(x_dim, y_dim, x_dim, y_dim, 128, 128).to("cpu")
        current_time = datetime.now().strftime("%Y%m%d-%H%M%S")
        # Defining the current check points and log directories.
        current_log_dir = ROOT / "cpu_logs" / foldername / current_time
        current_checkpoint_dir = ROOT / "cpu_checkpoints" / foldername / current_time
        # defining the optimizer
        Optimizer = optim.Adam(model.parameters(), lr=float(config["train"]["lr"]))
        # Defining the training class
        Training = NPTrainer(
            model=model,
            optimizer=Optimizer,
            loss_fn=Loss,
            device="cpu",
            log_dir=current_log_dir,
            checkpoint_dir=current_checkpoint_dir,
        )
        # To check the model's accuracy in validation data set we will use this.
        best_val_loss = float("inf")
        # these are the training data sets

        NeuralProcess_Train_data = neural_process_data(
            datasets[(input_key, output_key, "Train")]["inputs"],
            datasets[(input_key, output_key, "Train")]["outputs"],
            num_points_per_task=200,
        )

        NeuralProcess_Train_dataloader = DataLoader(
            NeuralProcess_Train_data,
            batch_size=16,
            shuffle=True,
            num_workers=0,
        )
        # Now we will define the validation datasets as well as validation dataloasers
        # NeuralProcess_Val_datasets = {}
        NeuralProcess_Val_data = neural_process_data(
            datasets[(input_key, output_key, "Val")]["inputs"],
            datasets[(input_key, output_key, "Val")]["outputs"],
            num_points_per_task=200,
        )

        # NeuralProcess_Val_dataloaders = {}
        NeuralProcess_Val_dataloader = DataLoader(
            NeuralProcess_Val_data,
            batch_size=16,
            shuffle=False,
            num_workers=0,
        )

        for epoch in range(100):
            # Train
            train_loss = Training.train_epoch(NeuralProcess_Train_dataloader, epoch)
            val_loss = validation_function(
                model=model,
                val_dataloader=NeuralProcess_Val_dataloader,
                loss_fn=Loss,
                device="cpu",
            )
            print(
                f"Epoch:{epoch} | Val_loss:{val_loss:.4f} | Train_loss:{train_loss:.4f}"
            )
            if val_loss < best_val_loss:
                best_val_loss = val_loss
                Training.save_checkpoint(epoch)
                print(f" >>> Saved New Best Model found! ")
# Out:
#  Start Training of Input: 1 | Output : 1
# Epoch 0: 100%|██████████| 770/770 [00:12<00:00, 61.40it/s, Loss=511.83]
# Epoch:0 | Val_loss:532.9938 | Train_loss:549.3186
# Checkpoint saved: /Users/pavankumar/Documents/Winter_Thesis/Coding_Learning/Master-Thesis/cpu_checkpoints/latitude_longitude_AOD_PM2.5_AOD_PM2.5/20260102-191651/model_epoch_0.pth
#  >>> Saved New Best Model found!
# Epoch 1: 100%|██████████| 770/770 [00:12<00:00, 63.26it/s, Loss=437.57]
# Epoch:1 | Val_loss:468.0218 | Train_loss:476.1998
# Checkpoint saved: /Users/pavankumar/Documents/Winter_Thesis/Coding_Learning/Master-Thesis/cpu_checkpoints/latitude_longitude_AOD_PM2.5_AOD_PM2.5/20260102-191651/model_epoch_1.pth
#  >>> Saved New Best Model found!
# Epoch 2: 100%|██████████| 770/770 [00:12<00:00, 62.97it/s, Loss=296.49]
# Epoch:2 | Val_loss:390.4968 | Train_loss:375.0298
# Checkpoint saved: /Users/pavankumar/Documents/Winter_Thesis/Coding_Learning/Master-Thesis/cpu_checkpoints/latitude_longitude_AOD_PM2.5_AOD_PM2.5/20260102-191651/model_epoch_2.pth
#  >>> Saved New Best Model found!
# Epoch 3: 100%|██████████| 770/770 [00:12<00:00, 62.75it/s, Loss=178.05]
# Epoch:3 | Val_loss:268.5330 | Train_loss:243.7428
# Checkpoint saved: /Users/pavankumar/Documents/Winter_Thesis/Coding_Learning/Master-Thesis/cpu_checkpoints/latitude_longitude_AOD_PM2.5_AOD_PM2.5/20260102-191651/model_epoch_3.pth
#  >>> Saved New Best Model found!
# Epoch 4: 100%|██████████| 770/770 [00:12<00:00, 61.74it/s, Loss=-47.93]
# Epoch:4 | Val_loss:71.5384 | Train_loss:67.8049
# Checkpoint saved: /Users/pavankumar/Documents/Winter_Thesis/Coding_Learning/Master-Thesis/cpu_checkpoints/latitude_longitude_AOD_PM2.5_AOD_PM2.5/20260102-191651/model_epoch_4.pth
#  >>> Saved New Best Model found!
# Epoch 5: 100%|██████████| 770/770 [00:12<00:00, 61.88it/s, Loss=-278.48]
# Epoch:5 | Val_loss:-174.1246 | Train_loss:-164.8933
# Checkpoint saved: /Users/pavankumar/Documents/Winter_Thesis/Coding_Learning/Master-Thesis/cpu_checkpoints/latitude_longitude_AOD_PM2.5_AOD_PM2.5/20260102
# Epoch 91: 100%|██████████| 770/770 [00:10<00:00, 73.81it/s, Loss=-1462.17]
# Epoch:91 | Val_loss:-1490.3439 | Train_loss:-1405.9426
# Epoch 92: 100%|██████████| 770/770 [00:10<00:00, 73.34it/s, Loss=-1551.46]
# Epoch:92 | Val_loss:-1535.9832 | Train_loss:-1390.6625
# Epoch 93: 100%|██████████| 770/770 [00:10<00:00, 73.38it/s, Loss=-1541.62]
# Epoch:93 | Val_loss:-1488.2595 | Train_loss:-1552.9606
# Epoch 94: 100%|██████████| 770/770 [00:10<00:00, 74.26it/s, Loss=-1567.18]
# Epoch:94 | Val_loss:-1549.7033 | Train_loss:-1547.0832
# Epoch 95: 100%|██████████| 770/770 [00:10<00:00, 73.64it/s, Loss=-1544.03]
# Epoch:95 | Val_loss:-1548.2588 | Train_loss:-1509.5223
# Epoch 96: 100%|██████████| 770/770 [00:10<00:00, 74.26it/s, Loss=-1556.29]
# Epoch:96 | Val_loss:-1565.2107 | Train_loss:-1545.8647
# Epoch 97: 100%|██████████| 770/770 [00:10<00:00, 71.89it/s, Loss=-1535.12]
# Epoch:97 | Val_loss:-1544.4068 | Train_loss:-1546.5741
# Epoch 98: 100%|██████████| 770/770 [00:10<00:00, 73.82it/s, Loss=-1560.37]
# Epoch:98 | Val_loss:-1563.8978 | Train_loss:-1560.7946
# Epoch 99: 100%|██████████| 770/770 [00:10<00:00, 73.56it/s, Loss=-1529.66]
# Epoch:99 | Val_loss:-1448.4660 | Train_loss:-1406.1753
#  Start Training of Input: 1 | Output : 2
# Epoch 0: 100%|██████████| 770/770 [00:10<00:00, 74.52it/s, Loss=256.13]
# Epoch:0 | Val_loss:251.3427 | Train_loss:269.3300
# Checkpoint saved: /Users/pavankumar/Documents/Winter_Thesis/Coding_Learning/Master-Thesis/cpu_checkpoints/latitude_longitude_AOD_PM2.5_AOD/20260102-193758/model_epoch_0.pth
#  >>> Saved New Best Model found!
# Epoch 1: 100%|██████████| 770/770 [00:10<00:00, 75.44it/s, Loss=181.17]
# Epoch:1 | Val_loss:191.8906 | Train_loss:216.3535
# Checkpoint saved: /Users/pavankumar/Documents/Winter_Thesis/Coding_Learning/Master-Thesis/cpu_checkpoints/latitude_longitude_AOD_PM2.5_AOD/20260102-193758/model_epoch_1.pth
#  >>> Saved New Best Model found!
# Epoch 2: 100%|██████████| 770/770 [00:10<00:00, 72.77it/s, Loss=62.02]
# Epoch:2 | Val_loss:78.0609 | Train_loss:131.1807
# Checkpoint saved: /Users/pavankumar/Documents/Winter_Thesis/Coding_Learning/Master-Thesis/cpu_checkpoints/latitude_longitude_AOD_PM2.5_AOD/20260102-193758/model_epoch_2.pth
#  >>> Saved New Best Model found!
# Epoch 3: 100%|██████████| 770/770 [00:10<00:00, 73.57it/s, Loss=-146.86]
# Epoch:3 | Val_loss:-140.5005 | Train_loss:-29.1336
# Checkpoint saved: /Users/pavankumar/Documents/Winter_Thesis/Coding_Learning/Master-Thesis/cpu_checkpoints/latitude_longitude_AOD_PM2.5_AOD/20260102-193758/model_epoch_3.pth
#  >>> Saved New Best Model found!
# Epoch 4: 100%|██████████| 770/770 [00:10<00:00, 74.50it/s, Loss=-490.39]
# Epoch:4 | Val_loss:-463.9172 | Train_loss:-305.6094
# Checkpoint saved: /Users/pavankumar/Documents/Winter_Thesis/Coding_Learning/Master-Thesis/cpu_checkpoints/latitude_longitude_AOD_PM2.5_AOD/20260102-193758/model_epoch_4.pth
#  >>> Saved New Best Model found!
# Epoch 5: 100%|██████████| 770/770 [00:10<00:00, 75.03it/s, Loss=-279.78]
# Epoch:5 | Val_loss:-562.1180 | Train_loss:-481.6929
# Checkpoint saved: /Users/pavankumar/Documents/Winter_Thesis/Coding_Learning/Master-Thesis/cpu_checkpoints/latitude_longitude_AOD_PM2.5_AOD/20260102-193758/model_epoch_5.pth
#  >>> Saved New Best Model found!
# Epoch 6: 100%|██████████| 770/770 [00:10<00:00, 74.94it/s, Loss=-595.41]
# Epoch:6 | Val_loss:-379.0826 | Train_loss:-470.9659
# Epoch 7: 100%|██████████| 770/770 [00:10<00:00, 75.20it/s, Loss=-514.71]
# Epoch:7 | Val_loss:-584.9116 | Train_loss:-491.3085
# Checkpoint saved: /Users/pavankumar/Documents/Winter_Thesis/Coding_Learning/Master-Thesis/cpu_checkpoints/latitude_longitude_AOD_PM2.5_AO

# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# File /Users/pavankumar/Documents/Winter_Thesis/Coding_Learning/Master-Thesis/src/training/trainer_latlon_AOD_PM25.py:71
#      62 NeuralProcess_Val_dataloader = DataLoader(
#      63     NeuralProcess_Val_data,
#      64     batch_size=16,
#      65     shuffle=False,
#      66     num_workers=0,
#      67 )
#      69 for epoch in range(100):
#      70     # Train
# ---> 71     train_loss = Training.train_epoch(NeuralProcess_Train_dataloader, epoch)
#      72     val_loss = validation_function(
#      73         model=model,
#      74         val_dataloader=NeuralProcess_Val_dataloader,
#      75         loss_fn=Loss,
#      76         device="cpu",
#      77     )
#      78     print(
#      79         f"Epoch:{epoch} | Val_loss:{val_loss:.4f} | Train_loss:{train_loss:.4f}"
#      80     )
#
# File ~/Documents/Winter_Thesis/Coding_Learning/Master-Thesis/src/training/optimizer_utils.py:123, in NPTrainer.train_epoch(self, dataloader, epoch_idx)
#     119 kl_avg = 0
#     121 pbar = tqdm(dataloader, desc=f"Epoch {epoch_idx}")
# --> 123 for batch_idx, (x_batch, y_batch) in enumerate(pbar):
#     124     # Move to device
#     125     x_batch = x_batch.clone().detach()
#     126     y_batch = y_batch.clone().detach()
#
# File ~/Documents/Winter_Thesis/Coding_Learning/Master-Thesis/.venvn/lib/python3.9/site-packages/tqdm/std.py:1181, in tqdm.__iter__(self)
#    1178 time = self._time
#    1180 try:
# -> 1181     for obj in iterable:
#    1182         yield obj
#    1183         # Update and possibly print the progressbar.
#    1184         # Note: does not call self.update(1) for speed optimisation.
#
# File ~/Documents/Winter_Thesis/Coding_Learning/Master-Thesis/.venvn/lib/python3.9/site-packages/torch/utils/data/dataloader.py:633, in _BaseDataLoaderIter.__next__(self)
#     630 if self._sampler_iter is None:
#     631     # TODO(https://github.com/pytorch/pytorch/issues/76750)
#     632     self._reset()  # type: ignore[call-arg]
# --> 633 data = self._next_data()
#     634 self._num_yielded += 1
#     635 if self._dataset_kind == _DatasetKind.Iterable and \
#     636         self._IterableDataset_len_called is not None and \
#     637         self._num_yielded > self._IterableDataset_len_called:
#
# File ~/Documents/Winter_Thesis/Coding_Learning/Master-Thesis/.venvn/lib/python3.9/site-packages/torch/utils/data/dataloader.py:677, in _SingleProcessDataLoaderIter._next_data(self)
#     675 def _next_data(self):
#     676     index = self._next_index()  # may raise StopIteration
# --> 677     data = self._dataset_fetcher.fetch(index)  # may raise StopIteration
#     678     if self._pin_memory:
#     679         data = _utils.pin_memory.pin_memory(data, self._pin_memory_device)
#
# File ~/Documents/Winter_Thesis/Coding_Learning/Master-Thesis/.venvn/lib/python3.9/site-packages/torch/utils/data/_utils/fetch.py:51, in _MapDatasetFetcher.fetch(self, possibly_batched_index)
#      49         data = self.dataset.__getitems__(possibly_batched_index)
#      50     else:
# ---> 51         data = [self.dataset[idx] for idx in possibly_batched_index]
#      52 else:
#      53     data = self.dataset[possibly_batched_index]
#
# File ~/Documents/Winter_Thesis/Coding_Learning/Master-Thesis/.venvn/lib/python3.9/site-packages/torch/utils/data/_utils/fetch.py:51, in <listcomp>(.0)
#      49         data = self.dataset.__getitems__(possibly_batched_index)
#      50     else:
# ---> 51         data = [self.dataset[idx] for idx in possibly_batched_index]
#      52 else:
#      53     data = self.dataset[possibly_batched_index]
#
# File ~/Documents/Winter_Thesis/Coding_Learning/Master-Thesis/src/training/optimizer_utils.py:85, in neural_process_data.__getitem__(self, index)
#      82 def __getitem__(self, index):
#      83     idxs = torch.randperm(self.N)[: self.num_points_per_task]
# ---> 85     X = self.X_full[idxs].clone().detach()
#      86     Y = self.Y_full[idxs].clone().detach()
#      87     return X, Y
#
# KeyboardInterrupt:

# %%
"""
Importing the necessary packages.............
"""

import os
import torch
import numpy as np
import pandas as pd
import sys
from pathlib import Path
import os
import matplotlib.pyplot as plt
from glob import glob
from tqdm import tqdm
import arrow
from datetime import datetime
from torch import optim

# from utils.config import config
from torch.utils.data import DataLoader

ROOT = Path(__file__).resolve().parents[2]  # tests/ -> project root
sys.path.insert(0, str(ROOT))
print(ROOT)

from configs.utils import config

# -------------************---------------------------------
# loading all the data loaders here we will load the final data in torch.
from Dataloader.Modis_Data_loader.PM25_data_loader_analysis import Modis_data_loader
from Dataloader.Modis_Data_loader.PM25_data_loader_analysis import PM_25_dataloader
from Dataloader.Modis_Data_loader.PM25_data_loader_analysis import (
    combine_the_data_frames,
)
from Dataloader.Modis_Data_loader.PM25_data_loader_analysis import (
    Training_data_loader,
)
from locationencoder.final_location_encoder import Geospatial_Encoder

geospatial_encoder = Geospatial_Encoder(
    config["Geo_spatial_Encoder"]["dim_in"],
    config["Geo_spatial_Encoder"]["dim_hidden"],
    config["Geo_spatial_Encoder"]["dim_out"],
    config["Geo_spatial_Encoder"]["num_layers"],
)
from Dataloader.Modis_Data_loader.torch_data_loader import Airqualitydataset
from Dataloader.Modis_Data_loader.final_loader import Final_Air_Quality_Dataset_pipeline
from src.Models.neural_process import NeuralProcess
from loss_functions import LossFunctions

Loss = LossFunctions()
from optimizer_utils import NPTrainer
from optimizer_utils import neural_process_data
from optimizer_utils import validation_function

# importing the packages for the optimization.
from Dataloader.Modis_Data_loader.torch_data_loader import Airqualitydataset
from Dataloader.Modis_Data_loader.final_loader import Final_Air_Quality_Dataset_pipeline
from src.Models.neural_process import NeuralProcess

""" In the belowmethod it is hard to make these many types of combinations so we will make a loop of input, output types and flags to create the final datasets."""


"""
  input_vars:
    1: ['latitude', 'longitude','AOD', 'PM2.5']
    2: ['latitude', 'longitude','AOD']
    3: ['latitude', 'longitude','PM2.5']
    4: ['latitude', 'longitude']

# feature_sets

  output_vars:
    1: ['AOD', 'PM2.5']
    2: ['AOD']
    3: ['PM2.5']

"""
# Out:
# /Users/pavankumar/Documents/Winter_Thesis/Coding_Learning/Master-Thesis
# "\n  input_vars:\n    1: ['latitude', 'longitude','AOD', 'PM2.5']\n    2: ['latitude', 'longitude','AOD']\n    3: ['latitude', 'longitude','PM2.5']\n    4: ['latitude', 'longitude']\n\n# feature_sets\n\n  output_vars:\n    1: ['AOD', 'PM2.5']\n    2: ['AOD']\n    3: ['PM2.5']\n\n"

# %%
datasets[(1, 2, "Train")]["inputs"].shape
# Out:
# torch.Size([12307, 128])

# %%
from loss_functions import LossFunctions

Loss = LossFunctions()
from optimizer_utils import NPTrainer
from optimizer_utils import neural_process_data
from optimizer_utils import validation_function

# importing the packages for the optimization.
from Dataloader.Modis_Data_loader.torch_data_loader import Airqualitydataset
from Dataloader.Modis_Data_loader.final_loader import Final_Air_Quality_Dataset_pipeline
from src.Models.neural_process import NeuralProcess

len(config["experiments"]["input_vars"][1])
len(config["experiments"]["output_vars"][1])

float(config["train"]["lr"])
len(datasets[(1, 1, "Train")]["inputs"][0])
len(datasets[(1, 1, "Train")]["outputs"][0])

for input_key in input_type:
    if input_key == "":
        print("Please check the input keys")
        continue
    for output_key in output_type:
        if output_key == "":
            print("Please check the output keys")
            continue
        print(f" Start Training of Input: {input_key} | Output : {output_key}")
        # the current inputs and current outputs are:
        current_inputs = config["experiments"]["input_vars"][input_key]
        in_name = "_".join(current_inputs)
        current_outputs = config["experiments"]["output_vars"][output_key]
        out_name = "_".join(current_outputs)
        foldername = f"{in_name}____{out_name}"
        # We can calculate the dimensions of the inputs and putputs to decide the number of model's layers.

        x_dim = len(datasets[(input_key, output_key, "Train")]["inputs"][0])
        y_dim = len(datasets[(input_key, output_key, "Train")]["outputs"][0])
        # In this model the inputs and outputs are.
        model = NeuralProcess(x_dim, y_dim, x_dim, y_dim, 128, 128).to("cpu")
        current_time = datetime.now().strftime("%Y%m%d-%H%M%S")
        # Defining the current check points and log directories.
        current_log_dir = ROOT / "cpu_logs" / foldername / current_time
        current_checkpoint_dir = ROOT / "cpu_checkpoints" / foldername / current_time
        # defining the optimizer
        Optimizer = optim.Adam(model.parameters(), lr=float(config["train"]["lr"]))
        # Defining the training class
        Training = NPTrainer(
            model=model,
            optimizer=Optimizer,
            loss_fn=Loss,
            device="cpu",
            log_dir=current_log_dir,
            checkpoint_dir=current_checkpoint_dir,
        )
        # To check the model's accuracy in validation data set we will use this.
        best_val_loss = float("inf")
        # these are the training data sets

        NeuralProcess_Train_data = neural_process_data(
            datasets[(input_key, output_key, "Train")]["inputs"],
            datasets[(input_key, output_key, "Train")]["outputs"],
            num_points_per_task=200,
        )

        NeuralProcess_Train_dataloader = DataLoader(
            NeuralProcess_Train_data,
            batch_size=16,
            shuffle=True,
            num_workers=0,
        )
        # Now we will define the validation datasets as well as validation dataloasers
        # NeuralProcess_Val_datasets = {}
        NeuralProcess_Val_data = neural_process_data(
            datasets[(input_key, output_key, "Val")]["inputs"],
            datasets[(input_key, output_key, "Val")]["outputs"],
            num_points_per_task=200,
        )

        # NeuralProcess_Val_dataloaders = {}
        NeuralProcess_Val_dataloader = DataLoader(
            NeuralProcess_Val_data,
            batch_size=16,
            shuffle=False,
            num_workers=0,
        )

        for epoch in range(100):
            # Train
            train_loss = Training.train_epoch(NeuralProcess_Train_dataloader, epoch)
            val_loss = validation_function(
                model=model,
                val_dataloader=NeuralProcess_Val_dataloader,
                loss_fn=Loss,
                device="cpu",
            )
            print(
                f"Epoch:{epoch} | Val_loss:{val_loss:.4f} | Train_loss:{train_loss:.4f}"
            )
            if val_loss < best_val_loss:
                best_val_loss = val_loss
                Training.save_checkpoint(epoch)
                print(f" >>> Saved New Best Model found! ")

# NeuraProcessData_latlon_PM25 = neural_process_data(
#     fnal_data_latlong_PM25[0],
#     fnal_data_latlong_PM25[1],
#     nm_points_per_task=200,
# )
# Out:
#  Start Training of Input: 1 | Output : 1
# Epoch 0: 100%|██████████| 770/770 [00:16<00:00, 46.67it/s, Loss=509.69]
# Epoch:0 | Val_loss:524.2528 | Train_loss:547.5113
# Checkpoint saved: /Users/pavankumar/Documents/Winter_Thesis/Coding_Learning/Master-Thesis/cpu_checkpoints/latitude_longitude_AOD_PM2.5____AOD_PM2.5/20260102-200253/model_epoch_0.pth
#  >>> Saved New Best Model found!
# Epoch 1: 100%|██████████| 770/770 [00:12<00:00, 60.60it/s, Loss=439.43]
# Epoch:1 | Val_loss:440.4771 | Train_loss:468.3829
# Checkpoint saved: /Users/pavankumar/Documents/Winter_Thesis/Coding_Learning/Master-Thesis/cpu_checkpoints/latitude_longitude_AOD_PM2.5____AOD_PM2.5/20260102-200253/model_epoch_1.pth
#  >>> Saved New Best Model found!
# Epoch 2: 100%|██████████| 770/770 [00:13<00:00, 55.42it/s, Loss=286.44]
# Epoch:2 | Val_loss:328.4937 | Train_loss:358.1517
# Checkpoint saved: /Users/pavankumar/Documents/Winter_Thesis/Coding_Learning/Master-Thesis/cpu_checkpoints/latitude_longitude_AOD_PM2.5____AOD_PM2.5/20260102-200253/model_epoch_2.pth
#  >>> Saved New Best Model found!
# Epoch 3: 100%|██████████| 770/770 [00:14<00:00, 52.50it/s, Loss=86.82]
# Epoch:3 | Val_loss:144.1063 | Train_loss:194.7249
# Checkpoint saved: /Users/pavankumar/Documents/Winter_Thesis/Coding_Learning/Master-Thesis/cpu_checkpoints/latitude_longitude_AOD_PM2.5____AOD_PM2.5/20260102-200253/model_epoch_3.pth
#  >>> Saved New Best Model found!
# Epoch 4: 100%|██████████| 770/770 [00:10<00:00, 72.86it/s, Loss=-257.83]
# Epoch:4 | Val_loss:-196.0710 | Train_loss:-75.2374
# Checkpoint saved: /Users/pavankumar/Documents/Winter_Thesis/Coding_Learning/Master-Thesis/cpu_checkpoints/latitude_longitude_AOD_PM2.5____AOD_PM2.5/20260102-200253/model_epoch_4.pth
#  >>> Saved New Best Model found!
# Epoch 5: 100%|██████████| 770/770 [00:10<00:00, 75.66it/s, Loss=-448.67]
# Epoch:5 | Val_loss:-386.3428 | Train_loss:-352.5652
# Checkpoint saved: /Users/pavankumar/Documents/Winter_Thesis/Coding_Learning/Master-Thesis/cpu_checkpoints/latitude_longitude_AOD_PM2.5____AOD_PM2.5/20260102-200253/model_epoch_5.pth
#  >>> Saved New Best Model found!
# Epoch 6: 100%|██████████| 770/770 [00:11<00:00, 68.88it/s, Loss=-460.21]
# Epoch:6 | Val_loss:-496.1859 | Train_loss:-464.3624
# Checkpoint saved: /Users/pavankumar/Documents/Winter_Thesis/Coding_Learning/Master-Thesis/cpu_checkpoints/latitude_longitude_AOD_PM2.5____AOD_PM2.5/20260102-200253/model_epoch_6.pth
#  >>> Saved New Best Model found!
# Epoch 7: 100%|██████████| 770/770 [00:11<00:00, 68.95it/s, Loss=-380.20]
# Epoch:7 | Val_loss:-477.6338 | Train_loss:-493.3083
# Epoch 8: 100%|██████████| 770/770 [00:11<00:00, 65.97it/s, Loss=-405.98]
# Epoch:8 | Val_loss:-351.0130 | Train_loss:-504.4951
# Epoch 9: 100%|██████████| 770/770 [00:10<00:00, 72.81it/s, Loss=-525.69]
# Epoch:9 | Val_loss:-514.3392 | Train_loss:-503.5744
# Checkpoint saved: /Users/pavankumar/Documents/Winter_Thesis/Coding_Learning/Master-Thesis/cpu_checkpoints/latitude_longitude_AOD_PM2.5____AOD_PM2.5/20260102-200253/model_epoch_9.pth
#  >>> Saved New Best Model found!
# Epoch 10: 100%|██████████| 770/770 [00:10<00:00, 71.99it/s, Loss=-492.71]
# Epoch:10 | Val_loss:-588.3018 | Train_loss:-108.0275
# Checkpoint saved: /Users/pavankumar/Documents/Winter_Thesis/Coding_Learning/Master-Thesis/cpu_checkpoints/latitude_longitude_AOD_PM2.5____AOD_PM2.5/20260102-200253/model_epoch_10.pth
#  >>> Saved New Best Model found!
# Epoch 11: 100%|██████████| 770/770 [00:10<00:00, 71.36it/s, Loss=-470.12]
# Epoch:11 | Val_loss:-40.0874 | Train_loss:-420.9011
# Epoch 12: 100%|██████████| 770/770 [00:10<00:00, 72.10it/s, Loss=96.18]
# Epoch:12 | Val_loss:-421.3647 | Train_loss:-322.8498
# Epoch 13: 100%|██████████| 770/770 [00:10<00:00, 71.91it/s, Loss=-202.83]
# Epoch:13 | Val_loss:588.2741 | Train_loss:-428.9612
# Epoch 14: 100%|██████████| 770/770 [00:10<00:00, 73.60it/s, Loss=-422.38]
# Epoch:14 | Val_loss:-630.1039 | Train_loss:-400.4335
# Checkpoint saved: /Users/pavankumar/Documents/Winter_Thesis/Coding_Learning/Master-Thesis/cpu_checkpoints/latitude_longitude_AOD_PM2.5____AOD_PM2.5/20260102-200253/model_epoch_14.pth
#  >>> Saved New Best Model found!
# Epoch 15: 100%|██████████| 770/770 [00:10<00:00, 72.02it/s, Loss=-453.80]
# Epoch:15 | Val_loss:-659.8175 | Train_loss:-450.3939
# Checkpoint saved: /Users/pavankumar/Documents/Winter_Thesis/Coding_Learning/Master-Thesis/cpu_checkpoints/latitude_longitude_AOD_PM2.5____AOD_PM2.5/20260102-200253/model_epoch_15.pth
#  >>> Saved New Best Model found!
# Epoch 16: 100%|██████████| 770/770 [00:10<00:00, 71.87it/s, Loss=-226.74]
# Epoch:16 | Val_loss:-60.1758 | Train_loss:-476.0070
# Epoch 17: 100%|██████████| 770/770 [00:11<00:00, 69.05it/s, Loss=-555.80]
# Epoch:17 | Val_loss:-631.0211 | Train_loss:-509.7832
# Epoch 18: 100%|██████████| 770/770 [00:10<00:00, 72.46it/s, Loss=-590.10]
# Epoch:18 | Val_loss:-662.8739 | Train_loss:-549.1679
# Checkpoint saved: /Users/pavankumar/Documents/Winter_Thesis/Coding_Learning/Master-Thesis/cpu_checkpoints/latitude_longitude_AOD_PM2.5____AOD_PM2.5/20260102-200253/model_epoch_18.pth
#  >>> Saved New Best Model found!
# Epoch 19: 100%|██████████| 770/770 [00:10<00:00, 71.79it/s, Loss=-567.11]
# Epoch:19 | Val_loss:-366.2818 | Train_loss:-596.7897
# Epoch 20: 100%|██████████| 770/770 [00:10<00:00, 71.94it/s, Loss=-755.94]
# Epoch:20 | Val_loss:-699.0286 | Train_loss:-658.8352
# Checkpoint saved: /Users/pavankumar/Documents/Winter_Thesis/Coding_Learning/Master-Thesis/cpu_checkpoints/latitude_longitude_AOD_PM2.5____AOD_PM2.5/20260102-200253/model_epoch_20.pth
#  >>> Saved New Best Model found!
# Epoch 21: 100%|██████████| 770/770 [00:11<00:00, 68.54it/s, Loss=-876.09]
# Epoch:21 | Val_loss:-924.1009 | Train_loss:-787.9289
# Checkpoint saved: /Users/pavankumar/Documents/Winter_Thesis/Coding_Learning/Master-Thesis/cpu_checkpoints/latitude_longitude_AOD_PM2.5____AOD_PM2.5/20260102-200253/model_epoch_21.pth
#  >>> Saved New Best Model found!
# Epoch 22: 100%|██████████| 770/770 [00:11<00:00, 65.66it/s, Loss=-1231.91]
# Epoch:22 | Val_loss:-1326.5668 | Train_loss:-1110.9534
# Checkpoint saved: /Users/pavankumar/Documents/Winter_Thesis/Coding_Learning/Master-Thesis/cpu_checkpoints/latitude_longitude_AOD_PM2.5____AOD_PM2.5/20260102-200253/model_epoch_22.pth
#  >>> Saved New Best Model found!
# Epoch 23: 100%|██████████| 770/770 [00:10<00:00, 74.65it/s, Loss=-1400.48]
# Epoch:23 | Val_loss:-1287.5201 | Train_loss:-1193.6910
# Epoch 24: 100%|██████████| 770/770 [00:10<00:00, 72.43it/s, Loss=-1424.61]
# Epoch:24 | Val_loss:-1394.3785 | Train_loss:-1302.9111
# Checkpoint saved: /Users/pavankumar/Documents/Winter_Thesis/Coding_Learning/Master-Thesis/cpu_checkpoints/latitude_longitude_AOD_PM2.5____AOD_PM2.5/20260102-200253/model_epoch_24.pth
#  >>> Saved New Best Model found!
# Epoch 25: 100%|██████████| 770/770 [00:11<00:00, 66.94it/s, Loss=-1498.42]
# Epoch:25 | Val_loss:-1412.2542 | Train_loss:-1252.7426
# Checkpoint saved: /Users/pavankumar/Documents/Winter_Thesis/Coding_Learning/Master-Thesis/cpu_checkpoints/latitude_longitude_AOD_PM2.5____AOD_PM2.5/20260102-200253/model_epoch_25.pth
#  >>> Saved New Best Model found!
# Epoch 26: 100%|██████████| 770/770 [00:11<00:00, 67.64it/s, Loss=-1491.22]
# Epoch:26 | Val_loss:-1399.7070 | Train_loss:-1323.1295
# Epoch 27: 100%|██████████| 770/770 [00:10<00:00, 72.01it/s, Loss=-1486.04]
# Epoch:27 | Val_loss:-1471.9889 | Train_loss:-1350.0193
# Checkpoint saved: /Users/pavankumar/Documents/Winter_Thesis/Coding_Learning/Master-Thesis/cpu_checkpoints/latitude_longitude_AOD_PM2.5____AOD_PM2.5/20260102-200253/model_epoch_27.pth
#  >>> Saved New Best Model found!
# Epoch 28: 100%|██████████| 770/770 [00:10<00:00, 73.32it/s, Loss=-1515.46]
# Epoch:28 | Val_loss:-1497.1358 | Train_loss:-1391.6590
# Checkpoint saved: /Users/pavankumar/Documents/Winter_Thesis/Coding_Learning/Master-Thesis/cpu_checkpoints/latitude_longitude_AOD_PM2.5____AOD_PM2.5/20260102-200253/model_epoch_28.pth
#  >>> Saved New Best Model found!
# Epoch 29: 100%|██████████| 770/770 [00:10<00:00, 72.02it/s, Loss=-1516.34]
# Epoch:29 | Val_loss:-1467.8346 | Train_loss:-1486.0471
# Epoch 30: 100%|██████████| 770/770 [00:10<00:00, 71.93it/s, Loss=-1427.62]
# Epoch:30 | Val_loss:-1152.8629 | Train_loss:-1107.5384
# Epoch 31: 100%|██████████| 770/770 [00:10<00:00, 72.01it/s, Loss=-1500.26]
# Epoch:31 | Val_loss:-1436.7376 | Train_loss:-1481.8014
# Epoch 32: 100%|██████████| 770/770 [00:10<00:00, 71.50it/s, Loss=-1385.85]
# Epoch:32 | Val_loss:-1485.4476 | Train_loss:-1375.7049
# Epoch 33: 100%|██████████| 770/770 [00:10<00:00, 71.53it/s, Loss=-313.91]
# Epoch:33 | Val_loss:-676.2886 | Train_loss:-1248.4340
# Epoch 34: 100%|██████████| 770/770 [00:10<00:00, 71.06it/s, Loss=-1511.46]
# Epoch:34 | Val_loss:-1515.6640 | Train_loss:-1346.8918
# Checkpoint saved: /Users/pavankumar/Documents/Winter_Thesis/Coding_Learning/Master-Thesis/cpu_checkpoints/latitude_longitude_AOD_PM2.5____AOD_PM2.5/20260102-200253/model_epoch_34.pth
#  >>> Saved New Best Model found!
# Epoch 35: 100%|██████████| 770/770 [00:10<00:00, 71.37it/s, Loss=-1500.25]
# Epoch:35 | Val_loss:-1516.6808 | Train_loss:-1413.9541
# Checkpoint saved: /Users/pavankumar/Documents/Winter_Thesis/Coding_Learning/Master-Thesis/cpu_checkpoints/latitude_longitude_AOD_PM2.5____AOD_PM2.5/20260102-200253/model_epoch_35.pth
#  >>> Saved New Best Model found!
# Epoch 36: 100%|██████████| 770/770 [00:10<00:00, 72.16it/s, Loss=-1516.06]
# Epoch:36 | Val_loss:-1384.3654 | Train_loss:-1372.9496
# Epoch 37: 100%|██████████| 770/770 [00:10<00:00, 73.50it/s, Loss=-1528.22]
# Epoch:37 | Val_loss:-1500.0534 | Train_loss:-1401.0401
# Epoch 38: 100%|██████████| 770/770 [00:13<00:00, 57.80it/s, Loss=-1565.72]
# Epoch:38 | Val_loss:-1449.9233 | Train_loss:-1531.7414
# Epoch 39: 100%|██████████| 770/770 [00:17<00:00, 43.76it/s, Loss=-1435.39]
# Epoch:39 | Val_loss:-1436.0964 | Train_loss:-1339.4396
# Epoch 40: 100%|██████████| 770/770 [00:14<00:00, 53.79it/s, Loss=-1004.64]
# Checkpoint saved: /Users/pavankumar/Documents/Winter_Thesis/Coding_Learning/Master-Thesis/cpu_checkpoints/latitude_longitude_AOD_PM2.5____AOD/20260102-202544/model_epoch_96.pth
#  >>> Saved New Best Model found!
# Epoch 97: 100%|██████████| 770/770 [00:14<00:00, 54.01it/s, Loss=-714.67]
# Epoch:97 | Val_loss:-720.7209 | Train_loss:-765.5268
# Epoch 98: 100%|██████████| 770/770 [00:14<00:00, 51.94it/s, Loss=-813.00]
# Epoch:98 | Val_loss:-813.5096 | Train_loss:-765.8064
# Epoch 99: 100%|██████████| 770/770 [00:14<00:00, 51.48it/s, Loss=-729.59]
# Epoch:99 | Val_loss:-735.0502 | Train_loss:-767.6232
#  Start Training of Input: 1 | Output : 3
# Epoch 0: 100%|██████████| 770/770 [00:16<00:00, 47.92it/s, Loss=253.51]
# Epoch:0 | Val_loss:251.0004 | Train_loss:266.9975
# Checkpoint saved: /Users/pavankumar/Documents/Winter_Thesis/Coding_Learning/Master-Thesis/cpu_checkpoints/latitude_longitude_AOD_PM2.5____PM2.5/20260102-205057/model_epoch_0.pth
#  >>> Saved New Best Model found!
# Epoch 1: 100%|██████████| 770/770 [00:14<00:00, 52.71it/s, Loss=167.61]
# Epoch:1 | Val_loss:193.6131 | Train_loss:202.6074
# Checkpoint saved: /Users/pavankumar/Documents/Winter_Thesis/Coding_Learning/Master-Thesis/cpu_checkpoints/latitude_longitude_AOD_PM2.5____PM2.5/20260102-205057/model_epoch_1.pth
#  >>> Saved New Best Model found!
# Epoch 2: 100%|██████████| 770/770 [00:15<00:00, 49.95it/s, Loss=39.05]
# Epoch:2 | Val_loss:97.6855 | Train_loss:109.3367
# Checkpoint saved: /Users/pavankumar/Documents/Winter_Thesis/Coding_Learning/Master-Thesis/cpu_checkpoints/latitude_longitude_AOD_PM2.5____PM2.5/20260102-205057/model_epoch_2.pth
#  >>> Saved New Best Model found!
# Epoch 3: 100%|██████████| 770/770 [00:13<00:00, 55.86it/s, Loss=-140.40]
# Epoch:3 | Val_loss:-86.0425 | Train_loss:-39.8416
# Checkpoint saved: /Users/pavankumar/Documents/Winter_Thesis/Coding_Learning/Master-Thesis/cpu_checkpoints/latitude_longitude_AOD_PM2.5____PM2.5/20260102-205057/model_epoch_3.pth
#  >>> Saved New Best Model found!
# Epoch 4: 100%|██████████| 770/770 [00:15<00:00, 49.67it/s, Loss=-421.29]
# Epoch:4 | Val_loss:-368.3484 | Train_loss:-268.0100
# Checkpoint saved: /Users/pavankumar/Documents/Winter_Thesis/Coding_Learning/Master-Thesis/cpu_checkpoints/latitude_longitude_AOD_PM2.5____PM2.5/20260102-205057/model_epoch_4.pth
#  >>> Saved New Best Model found!
# Epoch 5: 100%|██████████| 770/770 [00:14<00:00, 53.30it/s, Loss=-530.51]
# Epoch:5 | Val_loss:-545.1054 | Train_loss:-480.8977
# Checkpoint saved: /Users/pavankumar/Documents/Winter_Thesis/Coding_Learning/Master-Thesis/cpu_checkpoints/latitude_longitude_AOD_PM2.5____PM2.5/20260102-205057/model_epoch_5.pth
#  >>> Saved New Best Model found!
# Epoch 6: 100%|██████████| 770/770 [00:10<00:00, 71.03it/s, Loss=-617.94]
# Epoch:6 | Val_loss:-534.9104 | Train_loss:-550.6457
# Epoch 7: 100%|██████████| 770/770 [00:10<00:00, 70.07it/s, Loss=-529.06]
# Epoch:7 | Val_loss:-568.2765 | Train_loss:-572.2988
# Checkpoint saved: /Users/pavankumar/Documents/Winter_Thesis/Coding_Learning/Master-Thesis/cpu_checkpoints/latitude_longitude_AOD_PM2.5____PM2.5/20260102-205057/model_epoch_7.pth
#  >>> Saved New Best Model found!
# Epoch 8: 100%|██████████| 770/770 [00:10<00:00, 71.13it/s, Loss=-674.50]
# Epoch:8 | Val_loss:-550.6460 | Train_loss:-575.4391
# Epoch 9: 100%|██████████| 770/770 [00:11<00:00, 68.75it/s, Loss=-665.40]
# Epoch:9 | Val_loss:-524.9442 | Train_loss:-582.0869
# Epoch 10: 100%|██████████| 770/770 [00:10<00:00, 71.67it/s, Loss=-539.00]
# Epoch:10 | Val_loss:-575.4596 | Train_loss:-585.5415
# Checkpoint saved: /Users/pavankumar/Documents/Winter_Thesis/Coding_Learning/Master-Thesis/cpu_checkpoints/latitude_longitude_AOD_PM2.5