# %% [markdown]
# Connected to venv (Python 3.9.25)

# %%
import pandas as pd

path = "Eval_Run_11-03-2026_13-23/final_results_summery.csv"
results = pd.read_csv(path)

results
# Out:
#                                         Experiment  Variable           RMSE  \
# 0   latitude_longitude_AOD_nn_PM2.5_nn____AOD_PM2.5        AOD     1.950297
# 1   latitude_longitude_AOD_nn_PM2.5_nn____AOD_PM2.5      PM2.5  1738.982389
# 2         latitude_longitude_AOD_nn_PM2.5_nn____AOD        AOD     0.629668
# 3       latitude_longitude_AOD_nn_PM2.5_nn____PM2.5      PM2.5  1527.450736
# 4            latitude_longitude_AOD_nn____AOD_PM2.5        AOD     0.458591
# 5            latitude_longitude_AOD_nn____AOD_PM2.5      PM2.5    43.594583
# 6                  latitude_longitude_AOD_nn____AOD        AOD     0.461370
# 7                latitude_longitude_AOD_nn____PM2.5      PM2.5    35.254498
# 8          latitude_longitude_PM2.5_nn____AOD_PM2.5        AOD     0.362282
# 9          latitude_longitude_PM2.5_nn____AOD_PM2.5      PM2.5  1727.103717
# 10               latitude_longitude_PM2.5_nn____AOD        AOD     0.535650
# ...

# %%
import pandas as pd

path = "Eval_Run_11-03-2026_14-47/final_results_summery.csv"
results = pd.read_csv(path)

results
# Out:
#                        Experiment  Variable         RMSE        R2       NLL  \
# 0  latitude_longitude____AOD_PM2.5        AOD   0.392441 -0.032780  1.390707
# 1  latitude_longitude____AOD_PM2.5      PM2.5  52.098104 -2.572429  0.929395
# 2        latitude_longitude____AOD        AOD   0.385701 -0.015859  1.387599
# 3      latitude_longitude____PM2.5      PM2.5  46.662189 -1.908323  0.816146
#
#    95 %_Coverage
# 0       0.974058
# 1       0.974058
# 2       0.956329
# 3       0.998493

# %%
import pandas as pd

path = "Eval_Run_11-03-2026_15-01/final_results_summery.csv"
results = pd.read_csv(path)

results
# Out:
#                                           Experiment  Variable           RMSE  \
# 0   latitude_longitude_AOD_idw_PM2.5_idw____AOD_PM2.5        AOD     1.655571
# 1   latitude_longitude_AOD_idw_PM2.5_idw____AOD_PM2.5      PM2.5  2486.335858
# 2         latitude_longitude_AOD_idw_PM2.5_idw____AOD        AOD     0.538196
# 3       latitude_longitude_AOD_idw_PM2.5_idw____PM2.5      PM2.5  2198.402829
# 4             latitude_longitude_AOD_idw____AOD_PM2.5        AOD     0.378270
# 5             latitude_longitude_AOD_idw____AOD_PM2.5      PM2.5    59.002338
# 6                   latitude_longitude_AOD_idw____AOD        AOD     0.377013
# 7                 latitude_longitude_AOD_idw____PM2.5      PM2.5    41.488806
# 8           latitude_longitude_PM2.5_idw____AOD_PM2.5        AOD     0.367400
# 9           latitude_longitude_PM2.5_idw____AOD_PM2.5      PM2.5  2497.089105
# 10                latitude_longitude_PM2.5_idw____AOD        AOD     0.530764
# ...

# %%
import pandas as pd

path = "Eval_Run_11-03-2026_15-33/final_results_summery.csv"
results = pd.read_csv(path)

results
# Out:
#                                           Experiment  Variable           RMSE  \
# 0   latitude_longitude_AOD_idw_PM2.5_idw____AOD_PM2.5        AOD     1.698249
# 1   latitude_longitude_AOD_idw_PM2.5_idw____AOD_PM2.5      PM2.5  2456.666746
# 2         latitude_longitude_AOD_idw_PM2.5_idw____AOD        AOD     0.560506
# 3       latitude_longitude_AOD_idw_PM2.5_idw____PM2.5      PM2.5  2172.735258
# 4             latitude_longitude_AOD_idw____AOD_PM2.5        AOD     0.393674
# 5             latitude_longitude_AOD_idw____AOD_PM2.5      PM2.5    58.582876
# 6                   latitude_longitude_AOD_idw____AOD        AOD     0.392455
# 7                 latitude_longitude_AOD_idw____PM2.5      PM2.5    41.515224
# 8           latitude_longitude_PM2.5_idw____AOD_PM2.5        AOD     0.364207
# 9           latitude_longitude_PM2.5_idw____AOD_PM2.5      PM2.5  2459.680467
# 10                latitude_longitude_PM2.5_idw____AOD        AOD     0.524437
# ...

# %%
import pandas as pd

path = "Eval_Run_11-03-2026_15-57/final_results_summery.csv"
results = pd.read_csv(path)

results
# Out:
#                                           Experiment  Variable           RMSE  \
# 0   latitude_longitude_AOD_idw_PM2.5_idw____AOD_PM2.5        AOD     1.698249
# 1   latitude_longitude_AOD_idw_PM2.5_idw____AOD_PM2.5      PM2.5  2456.666746
# 2         latitude_longitude_AOD_idw_PM2.5_idw____AOD        AOD     0.560506
# 3       latitude_longitude_AOD_idw_PM2.5_idw____PM2.5      PM2.5  2172.735258
# 4             latitude_longitude_AOD_idw____AOD_PM2.5        AOD     0.393674
# 5             latitude_longitude_AOD_idw____AOD_PM2.5      PM2.5    58.582876
# 6                   latitude_longitude_AOD_idw____AOD        AOD     0.392455
# 7                 latitude_longitude_AOD_idw____PM2.5      PM2.5    41.515224
# 8           latitude_longitude_PM2.5_idw____AOD_PM2.5        AOD     0.364207
# 9           latitude_longitude_PM2.5_idw____AOD_PM2.5      PM2.5  2459.680467
# 10                latitude_longitude_PM2.5_idw____AOD        AOD     0.524437
# ...

# %%
import pandas as pd

path = "Eval_Run_11-03-2026_21-11/final_results_summery.csv"
results = pd.read_csv(path)

results
# Out:
#                                           Experiment  Variable         RMSE  \
# 0                     latitude_longitude____AOD_PM2.5        AOD   0.387108
# 1                     latitude_longitude____AOD_PM2.5      PM2.5  51.447697
# 2                           latitude_longitude____AOD        AOD   0.385105
# 3                         latitude_longitude____PM2.5      PM2.5  46.056669
# 4   latitude_longitude_AOD_idw_PM2.5_idw____AOD_PM2.5        AOD   0.102805
# 5   latitude_longitude_AOD_idw_PM2.5_idw____AOD_PM2.5      PM2.5  15.485785
# 6         latitude_longitude_AOD_idw_PM2.5_idw____AOD        AOD   0.103054
# 7       latitude_longitude_AOD_idw_PM2.5_idw____PM2.5      PM2.5  15.768426
# 8             latitude_longitude_AOD_idw____AOD_PM2.5        AOD   0.102780
# 9             latitude_longitude_AOD_idw____AOD_PM2.5      PM2.5  68.707650
# 10                  latitude_longitude_AOD_idw____AOD        AOD   0.103928
# ...

# %%
path = "Eval_Run_11-03-2026_21-11/final_results_summery.csv"
results = pd.read_csv(path)

results
# Out:
#                                           Experiment  Variable         RMSE  \
# 0                     latitude_longitude____AOD_PM2.5        AOD   0.387108
# 1                     latitude_longitude____AOD_PM2.5      PM2.5  51.447697
# 2                           latitude_longitude____AOD        AOD   0.385105
# 3                         latitude_longitude____PM2.5      PM2.5  46.056669
# 4   latitude_longitude_AOD_idw_PM2.5_idw____AOD_PM2.5        AOD   0.102805
# 5   latitude_longitude_AOD_idw_PM2.5_idw____AOD_PM2.5      PM2.5  15.485785
# 6         latitude_longitude_AOD_idw_PM2.5_idw____AOD        AOD   0.103054
# 7       latitude_longitude_AOD_idw_PM2.5_idw____PM2.5      PM2.5  15.768426
# 8             latitude_longitude_AOD_idw____AOD_PM2.5        AOD   0.102780
# 9             latitude_longitude_AOD_idw____AOD_PM2.5      PM2.5  68.707650
# 10                  latitude_longitude_AOD_idw____AOD        AOD   0.103928
# ...

# %%
import pandas as pd

path = "Eval_Run_11-03-2026_21-11/final_results_summery.csv"
results = pd.read_csv(path)

results
# Out:
#                                           Experiment  Variable         RMSE  \
# 0                     latitude_longitude____AOD_PM2.5        AOD   0.387108
# 1                     latitude_longitude____AOD_PM2.5      PM2.5  51.447697
# 2                           latitude_longitude____AOD        AOD   0.385105
# 3                         latitude_longitude____PM2.5      PM2.5  46.056669
# 4   latitude_longitude_AOD_idw_PM2.5_idw____AOD_PM2.5        AOD   0.102805
# 5   latitude_longitude_AOD_idw_PM2.5_idw____AOD_PM2.5      PM2.5  15.485785
# 6         latitude_longitude_AOD_idw_PM2.5_idw____AOD        AOD   0.103054
# 7       latitude_longitude_AOD_idw_PM2.5_idw____PM2.5      PM2.5  15.768426
# 8             latitude_longitude_AOD_idw____AOD_PM2.5        AOD   0.102780
# 9             latitude_longitude_AOD_idw____AOD_PM2.5      PM2.5  68.707650
# 10                  latitude_longitude_AOD_idw____AOD        AOD   0.103928
# ...

# %%
import pandas as pd

path = "Eval_Run_11-03-2026_21-11/final_results_summery.csv"
results = pd.read_csv(path)

results
# Out:
#                                           Experiment  Variable         RMSE  \
# 0                     latitude_longitude____AOD_PM2.5        AOD   0.387108
# 1                     latitude_longitude____AOD_PM2.5      PM2.5  51.447697
# 2                           latitude_longitude____AOD        AOD   0.385105
# 3                         latitude_longitude____PM2.5      PM2.5  46.056669
# 4   latitude_longitude_AOD_idw_PM2.5_idw____AOD_PM2.5        AOD   0.102805
# 5   latitude_longitude_AOD_idw_PM2.5_idw____AOD_PM2.5      PM2.5  15.485785
# 6         latitude_longitude_AOD_idw_PM2.5_idw____AOD        AOD   0.103054
# 7       latitude_longitude_AOD_idw_PM2.5_idw____PM2.5      PM2.5  15.768426
# 8             latitude_longitude_AOD_idw____AOD_PM2.5        AOD   0.102780
# 9             latitude_longitude_AOD_idw____AOD_PM2.5      PM2.5  68.707650
# 10                  latitude_longitude_AOD_idw____AOD        AOD   0.103928
# ...

# %%
import pandas as pd

path = "Eval_Run_11-03-2026_21-11/final_results_summery.csv"
results = pd.read_csv(path)

results
# Out:
#                                           Experiment  Variable         RMSE  \
# 0                     latitude_longitude____AOD_PM2.5        AOD   0.387108
# 1                     latitude_longitude____AOD_PM2.5      PM2.5  51.447697
# 2                           latitude_longitude____AOD        AOD   0.385105
# 3                         latitude_longitude____PM2.5      PM2.5  46.056669
# 4   latitude_longitude_AOD_idw_PM2.5_idw____AOD_PM2.5        AOD   0.102805
# 5   latitude_longitude_AOD_idw_PM2.5_idw____AOD_PM2.5      PM2.5  15.485785
# 6         latitude_longitude_AOD_idw_PM2.5_idw____AOD        AOD   0.103054
# 7       latitude_longitude_AOD_idw_PM2.5_idw____PM2.5      PM2.5  15.768426
# 8             latitude_longitude_AOD_idw____AOD_PM2.5        AOD   0.102780
# 9             latitude_longitude_AOD_idw____AOD_PM2.5      PM2.5  68.707650
# 10                  latitude_longitude_AOD_idw____AOD        AOD   0.103928
# ...

# %%
import pandas as pd

path = "Eval_Run_12-03-2026_13-30/final_results_summery.csv"
results = pd.read_csv(path)

results
# Out:
#                                           Experiment  Variable         RMSE  \
# 0                     latitude_longitude____AOD_PM2.5        AOD   0.387108
# 1                     latitude_longitude____AOD_PM2.5      PM2.5  51.447697
# 2                           latitude_longitude____AOD        AOD   0.385105
# 3                         latitude_longitude____PM2.5      PM2.5  46.056669
# 4   latitude_longitude_AOD_idw_PM2.5_idw____AOD_PM2.5        AOD   0.104006
# 5   latitude_longitude_AOD_idw_PM2.5_idw____AOD_PM2.5      PM2.5  16.535202
# 6         latitude_longitude_AOD_idw_PM2.5_idw____AOD        AOD   0.105540
# 7       latitude_longitude_AOD_idw_PM2.5_idw____PM2.5      PM2.5  16.490399
# 8             latitude_longitude_AOD_idw____AOD_PM2.5        AOD   0.105008
# 9             latitude_longitude_AOD_idw____AOD_PM2.5      PM2.5  68.127913
# 10                  latitude_longitude_AOD_idw____AOD        AOD   0.104234
# ...

# %%
import pandas as pd

path = "Eval_Run_11-03-2026_15-57/final_results_summery.csv"
results = pd.read_csv(path)

results
# Out:
#                                           Experiment  Variable           RMSE  \
# 0   latitude_longitude_AOD_idw_PM2.5_idw____AOD_PM2.5        AOD     1.698249
# 1   latitude_longitude_AOD_idw_PM2.5_idw____AOD_PM2.5      PM2.5  2456.666746
# 2         latitude_longitude_AOD_idw_PM2.5_idw____AOD        AOD     0.560506
# 3       latitude_longitude_AOD_idw_PM2.5_idw____PM2.5      PM2.5  2172.735258
# 4             latitude_longitude_AOD_idw____AOD_PM2.5        AOD     0.393674
# 5             latitude_longitude_AOD_idw____AOD_PM2.5      PM2.5    58.582876
# 6                   latitude_longitude_AOD_idw____AOD        AOD     0.392455
# 7                 latitude_longitude_AOD_idw____PM2.5      PM2.5    41.515224
# 8           latitude_longitude_PM2.5_idw____AOD_PM2.5        AOD     0.364207
# 9           latitude_longitude_PM2.5_idw____AOD_PM2.5      PM2.5  2459.680467
# 10                latitude_longitude_PM2.5_idw____AOD        AOD     0.524437
# ...

# %% [markdown]
# No kernel connected

# %% [markdown]
# No kernel connected

# %% [markdown]
# No kernel connected

# %% [markdown]
# No kernel connected
