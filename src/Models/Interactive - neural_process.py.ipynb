# %% [markdown]
# Connected to .venv39 (3.9.22) (Python 3.9.22)

# %%
# Importing all the necessary libraries

import torch.nn as nn
import torch
import torch.nn.functional as F
from Encoder import Encoder
from Latent_encoder import Latent_Encoder
from Decoder import Decoder
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# File /Users/pavankumar/Documents/Winter_Thesis/Coding_Learning/Master-Thesis/src/Models/neural_process.py:7
#       5 import torch.nn.functional as F
#       6 from Encoder import Encoder
# ----> 7 from Latent_encoder import Latent_Encoder
#       8 from Decoder import Decoder
#
# File ~/Documents/Winter_Thesis/Coding_Learning/Master-Thesis/src/Models/Latent_encoder.py:2
#       1 import torch
# ----> 2 from torch.nn import nn
#       3 import torch.functionals as F
#       5 """
#       6 From here as we can see that the input to this module will be the output of the Encoder module which is r.
#       7 """
#
# ImportError: cannot import name 'nn' from 'torch.nn' (/Users/pavankumar/Documents/Winter_Thesis/Coding_Learning/Master-Thesis/.venv39/lib/python3.9/site-packages/torch/nn/__init__.py)

# %%
import torch.nn as nn

# %%
import torch.nn as nn
import torch
import torch.nn.functional as F
from Encoder import Encoder
from Latent_encoder import Latent_Encoder
from Decoder import Decoder
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# File /Users/pavankumar/Documents/Winter_Thesis/Coding_Learning/Master-Thesis/src/Models/neural_process.py:5
#       3 import torch.nn.functional as F
#       4 from Encoder import Encoder
# ----> 5 from Latent_encoder import Latent_Encoder
#       6 from Decoder import Decoder
#
# File ~/Documents/Winter_Thesis/Coding_Learning/Master-Thesis/src/Models/Latent_encoder.py:2
#       1 import torch
# ----> 2 from torch.nn import nn
#       3 import torch.functionals as F
#       5 """
#       6 From here as we can see that the input to this module will be the output of the Encoder module which is r.
#       7 """
#
# ImportError: cannot import name 'nn' from 'torch.nn' (/Users/pavankumar/Documents/Winter_Thesis/Coding_Learning/Master-Thesis/.venv39/lib/python3.9/site-packages/torch/nn/__init__.py)

# %%
import torch.nn.functional as F
